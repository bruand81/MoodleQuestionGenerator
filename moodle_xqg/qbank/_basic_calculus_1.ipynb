# %% [markdown]
# Moodle XML Question Generator, (C) 2020 Kosaku Nagasaka (Kobe University)

# %% [markdown]
# ## モジュールファイルの生成

# %%
if __name__ == "__main__":
    import subprocess
    subprocess.run(['jupyter', 'nbconvert', '--to', 'python', '_basic_calculus_1.ipynb','--output','basic_calculus_1.py'])

# %% [markdown]
# # Basic Calculus 1 (differencial calculus for univariate function)

# %%
if __name__ == "__main__":
    from inspect import getsourcefile
    import os.path
    import sys
    current_path = os.path.abspath(getsourcefile(lambda:0))
    current_dir = os.path.dirname(current_path)
    parent_dir = current_dir[:current_dir.rfind(os.path.sep)]
    sys.path.insert(0, parent_dir)
    import core
    import common
    core._force_to_this_lang = 'ja'
else:
    from .. import core
    from . import common

# %%
import sympy
import random
import IPython
import itertools
import copy

# %% [markdown]
# ## minor helpers

# %%
def nonzero_randint(imin, imax):
    if 0 < imin or imax < 0:
        return random.randint(imin, imax)
    else:
        return random.choice(list(set(range(imin,imax+1)).difference(set([0]))))

# %%
def nonone_randpint(imin, imax):
    if 1 < imin:
        return random.randint(imin, imax)
    else:
        return abs(random.choice(list(set(range(imin,imax+1)).difference(set([0,-1,1])))))

# %% [markdown]
# ## composite function

# %%
class composite_function(core.Question):
    name = '合成関数（初等関数）'
    _function_types = ['polynomial', 'polynomial','polynomial', 'rational', 'rational', 'sin', 'cos', 'tan', 'exp', 'log']
    def __init__(self, emin=-2, emax=2):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
    def _function_generate(self, _var):
        _type = random.choice(self._function_types)
        if _type == 'polynomial':
            return sum([nonzero_randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
        elif _type == 'rational':
            return sum([nonzero_randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(1,2))]) / sum([nonzero_randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(1,2))])
        elif _type == 'sin':
            return nonzero_randint(self.elem_min, self.elem_max)*sympy.sin(nonzero_randint(self.elem_min, self.elem_max)*_var+random.randint(self.elem_min, self.elem_max))
        elif _type == 'cos':
            return nonzero_randint(self.elem_min, self.elem_max)*sympy.cos(nonzero_randint(self.elem_min, self.elem_max)*_var+random.randint(self.elem_min, self.elem_max))
        elif _type == 'tan':
            return nonzero_randint(self.elem_min, self.elem_max)*sympy.tan(nonzero_randint(self.elem_min, self.elem_max)*_var+random.randint(self.elem_min, self.elem_max))
        elif _type == 'exp':
            return nonzero_randint(self.elem_min, self.elem_max)*sympy.exp(nonzero_randint(self.elem_min, self.elem_max)*_var+random.randint(self.elem_min, self.elem_max))
        elif _type == 'log':
            return nonzero_randint(self.elem_min, self.elem_max)*sympy.log(abs(nonzero_randint(self.elem_min, self.elem_max))*_var+abs(random.randint(self.elem_min, self.elem_max)))
        else:
            return 0
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='合成関数', quiz_number=_quiz_number)
        _var = sympy.Symbol('x')
        _f = self._function_generate(_var)
        _g = self._function_generate(_var)
        _is_fog = random.choice([True, False])
        if _is_fog is True:
            _composite = _f.subs(_var, _g)
        else:
            _composite = _g.subs(_var, _f)        
        quiz.quiz_identifier = hash(str(_f) + str(_g) + str(_composite))
        # 正答の選択肢の生成
        quiz.data = [_var, _f, _g, _is_fog, _composite]
        ans = { 'fraction': 100, 'data': _composite }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_var, _f, _g, _is_fog, _composite] = quiz.data
        if _is_fog is False:
            _incorrect = _f.subs(_var, _g)
        else:
            _incorrect = _g.subs(_var, _f)
        if sympy.simplify(_incorrect - _composite) != 0:
            ans['feedback'] = r'合成関数では適用順序が重要です。それが逆になっています。'
            ans['data'] = _incorrect
            answers.append(dict(ans))          
        _incorrect = _f + _g
        if sympy.simplify(_incorrect - _composite) != 0:
            ans['feedback'] = r'合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の加減算ではありません。'
            ans['data'] = _incorrect
            answers.append(dict(ans))        
        _incorrect = _f - _g     
        if sympy.simplify(_incorrect - _composite) != 0:
            ans['feedback'] = r'合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の加減算ではありません。'
            ans['data'] = _incorrect
            answers.append(dict(ans))              
        _incorrect = _f * _g     
        if sympy.simplify(_incorrect - _composite) != 0:
            ans['feedback'] = r'合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の乗除算ではありません。'
            ans['data'] = _incorrect
            answers.append(dict(ans))                    
        _incorrect = _f / _g     
        if sympy.simplify(_incorrect - _composite) != 0:
            ans['feedback'] = r'合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の乗除算ではありません。'
            ans['data'] = _incorrect
            answers.append(dict(ans))     
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_var, _f, _g, _is_fog, _composite] = quiz.data
        _text = r'次の関数\( f(x), g(x) \)に対し，合成関数'
        if _is_fog is True:
            _text += r'\( f\circ g \)'
        else:
            _text += r'\( g\circ f \)'
        _text += r'を選択してください。<br />'
        _text += r'\( f(x)=' + sympy.latex(_f, order='lex') + r',\;g(x)=' + sympy.latex(_g, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = composite_function()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=5)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x), g(x) \)に対し，合成関数\( g\circ f \)を選択してください。<br />\( f(x)=- 2 x + 2,\;g(x)=-1 \)<div style="text-align:right;font-size:smaller">（問題整理番号:039）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:合成関数では適用順序が重要です。それが逆になっています。"><input type="radio" name="preview39">\( 4 \)</li><li title="点数:100"><input type="radio" name="preview39">\( -1 \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の乗除算ではありません。"><input type="radio" name="preview39">\( 2 x - 2 \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の加減算ではありません。"><input type="radio" name="preview39">\( - 2 x + 1 \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の加減算ではありません。"><input type="radio" name="preview39">\( - 2 x + 3 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x), g(x) \)に対し，合成関数\( f\circ g \)を選択してください。<br />\( f(x)=- \frac{2}{x - 2},\;g(x)=2 \sin{\left(x + 1 \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:118）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の乗除算ではありません。"><input type="radio" name="preview118">\( - \frac{4 \sin{\left(x + 1 \right)}}{x - 2} \)</li><li title="点数:0
# フィードバック:合成関数では適用順序が重要です。それが逆になっています。"><input type="radio" name="preview118">\( 2 \sin{\left(1 - \frac{2}{x - 2} \right)} \)</li><li title="点数:100"><input type="radio" name="preview118">\( - \frac{2}{2 \sin{\left(x + 1 \right)} - 2} \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の加減算ではありません。"><input type="radio" name="preview118">\( 2 \sin{\left(x + 1 \right)} - \frac{2}{x - 2} \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の加減算ではありません。"><input type="radio" name="preview118">\( - 2 \sin{\left(x + 1 \right)} - \frac{2}{x - 2} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x), g(x) \)に対し，合成関数\( g\circ f \)を選択してください。<br />\( f(x)=- \log{\left(2 x \right)},\;g(x)=x^{2} - 2 x + 1 \)<div style="text-align:right;font-size:smaller">（問題整理番号:070）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の加減算ではありません。"><input type="radio" name="preview70">\( - x^{2} + 2 x - \log{\left(2 x \right)} - 1 \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の加減算ではありません。"><input type="radio" name="preview70">\( x^{2} - 2 x - \log{\left(2 x \right)} + 1 \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の乗除算ではありません。"><input type="radio" name="preview70">\( - \left(x^{2} - 2 x + 1\right) \log{\left(2 x \right)} \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の乗除算ではありません。"><input type="radio" name="preview70">\( - \frac{\log{\left(2 x \right)}}{x^{2} - 2 x + 1} \)</li><li title="点数:100"><input type="radio" name="preview70">\( \log{\left(2 x \right)}^{2} + 2 \log{\left(2 x \right)} + 1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x), g(x) \)に対し，合成関数\( g\circ f \)を選択してください。<br />\( f(x)=- \log{\left(2 x \right)},\;g(x)=2 \cos{\left(2 x + 2 \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:125）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview125">\( 2 \cos{\left(2 \log{\left(2 x \right)} - 2 \right)} \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の乗除算ではありません。"><input type="radio" name="preview125">\( - 2 \log{\left(2 x \right)} \cos{\left(2 x + 2 \right)} \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の乗除算ではありません。"><input type="radio" name="preview125">\( - \frac{\log{\left(2 x \right)}}{2 \cos{\left(2 x + 2 \right)}} \)</li><li title="点数:0
# フィードバック:合成関数では適用順序が重要です。それが逆になっています。"><input type="radio" name="preview125">\( - \log{\left(4 \cos{\left(2 x + 2 \right)} \right)} \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の加減算ではありません。"><input type="radio" name="preview125">\( - \log{\left(2 x \right)} + 2 \cos{\left(2 x + 2 \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x), g(x) \)に対し，合成関数\( f\circ g \)を選択してください。<br />\( f(x)=2 x^{2} + 2 x - 2,\;g(x)=\frac{1}{2 x + 1} \)<div style="text-align:right;font-size:smaller">（問題整理番号:024）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview24">\( -2 + \frac{2}{2 x + 1} + \frac{2}{\left(2 x + 1\right)^{2}} \)</li><li title="点数:0
# フィードバック:合成関数では適用順序が重要です。それが逆になっています。"><input type="radio" name="preview24">\( \frac{1}{4 x^{2} + 4 x - 3} \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の加減算ではありません。"><input type="radio" name="preview24">\( 2 x^{2} + 2 x - 2 - \frac{1}{2 x + 1} \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の加減算ではありません。"><input type="radio" name="preview24">\( 2 x^{2} + 2 x - 2 + \frac{1}{2 x + 1} \)</li><li title="点数:0
# フィードバック:合成関数は，順番に関数を適用した結果の対応を表す関数です。関数の乗除算ではありません。"><input type="radio" name="preview24">\( \left(2 x + 1\right) \left(2 x^{2} + 2 x - 2\right) \)</li></ol></div></div>

# %%
if __name__ == "__main__":
    pass
    #qz.save('composite_function.xml')

# %% [markdown]
# ## limit of polynomial or rational function

# %%
class limit_of_polynomial_or_rational_function(core.Question):
    name = '多項式又は有理関数の極限（両側極限）'
    _function_types = ['polynomial', 'rational']
    def __init__(self, emin=-3, emax=3, amin=-1, amax=1):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 極限を求めるxの値の範囲
        self.a_min = amin
        self.a_max = amax
    def _function_generate(self, _var):
        _type = random.choice(self._function_types)
        if _type == 'polynomial':
            return sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,4))])
        else:
            _den = 0
            while _den == 0:
                _den = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            return sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(1,3))]) / _den
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='多項式又は有理関数の極限', quiz_number=_quiz_number)
        _var = sympy.Symbol('x')
        while True:
            _f = self._function_generate(_var)
            _a = random.choice(list(range(self.a_min, self.a_max)) + [sympy.S.Infinity, -sympy.S.Infinity])
            _limit = sympy.limit(_f, _var, _a, dir="+")
            _limit_left = sympy.limit(_f, _var, _a, dir="-")
            if _limit == _limit_left:
                break        
        quiz.quiz_identifier = hash(str(_f) + str(_a) + str(_limit))
        # 正答の選択肢の生成
        quiz.data = [_var, _f, _a, _limit]
        ans = { 'fraction': 100, 'data': _limit }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_var, _f, _a, _limit] = quiz.data
        _incorrect = (-1)*_limit
        if _incorrect != _limit:
            ans['feedback'] = r'符号を間違えています。計算を丁寧に行ってください。'
            ans['data'] = _incorrect
            answers.append(dict(ans))   
        _incorrect = sympy.limit(_f, _var, (-1)*_a, dir="+")
        if _incorrect != _limit:
            ans['feedback'] = r'符号を間違えています。計算を丁寧に行ってください。'
            ans['data'] = _incorrect
            answers.append(dict(ans))   
        for _possible_a in list(range(self.a_min, self.a_max)) + [sympy.S.Infinity, -sympy.S.Infinity]:
            _incorrect = sympy.limit(_f, _var, _possible_a, dir="+")
            if _incorrect != _limit:
                ans['feedback'] = r'近づける先が間違っています。計算を丁寧に行ってください。'
                ans['data'] = _incorrect
                answers.append(dict(ans))
        answers = common.answer_union(answers)
        while len(answers) < size:
            _incorrect = random.randint(-size, size)
            if _incorrect != _limit:
                ans['feedback'] = r'計算を丁寧に行ってください。'
                ans['data'] = _incorrect
                answers.append(dict(ans))
                answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_var, _f, _a, _limit] = quiz.data
        _text = r'次の極限を選択してください。<br />'
        _text += r'\( \lim_{x\rightarrow' + sympy.latex(_a) + r'}' + sympy.latex(_f, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = limit_of_polynomial_or_rational_function()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=5)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow0}3 x^{3} - 3 x^{2} + 1 \)<div style="text-align:right;font-size:smaller">（問題整理番号:067）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview67">\( \infty \)</li><li title="点数:0
# フィードバック:符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview67">\( -1 \)</li><li title="点数:100"><input type="radio" name="preview67">\( 1 \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview67">\( -\infty \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview67">\( -5 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow-\infty}\frac{1}{2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:133）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:計算を丁寧に行ってください。"><input type="radio" name="preview133">\( 0 \)</li><li title="点数:0
# フィードバック:計算を丁寧に行ってください。"><input type="radio" name="preview133">\( 3 \)</li><li title="点数:100"><input type="radio" name="preview133">\( \frac{1}{2} \)</li><li title="点数:0
# フィードバック:符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview133">\( - \frac{1}{2} \)</li><li title="点数:0
# フィードバック:計算を丁寧に行ってください。"><input type="radio" name="preview133">\( -1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow-1}\frac{3}{- x - 3} \)<div style="text-align:right;font-size:smaller">（問題整理番号:156）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview156">\( - \frac{3}{2} \)</li><li title="点数:0
# フィードバック:符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview156">\( \frac{3}{2} \)</li><li title="点数:0
# フィードバック:符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview156">\( - \frac{3}{4} \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview156">\( -1 \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview156">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow\infty}\frac{2 x^{2} + 2 x - 2}{- 2 x - 1} \)<div style="text-align:right;font-size:smaller">（問題整理番号:079）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview79">\( 2 \)</li><li title="点数:0
# フィードバック:符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview79">\( \infty \)</li><li title="点数:100"><input type="radio" name="preview79">\( -\infty \)</li><li title="点数:0
# フィードバック:計算を丁寧に行ってください。"><input type="radio" name="preview79">\( 4 \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview79">\( -2 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow-1}- 3 x - 2 \)<div style="text-align:right;font-size:smaller">（問題整理番号:053）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview53">\( -1 \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview53">\( -2 \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview53">\( -\infty \)</li><li title="点数:0
# フィードバック:符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview53">\( -5 \)</li><li title="点数:100"><input type="radio" name="preview53">\( 1 \)</li></ol></div></div>

# %%
if __name__ == "__main__":
    pass
    #qz.save('limit_of_polynomial_or_rational_function.xml')

# %% [markdown]
# ## limit of polynomial or rational function with no limit

# %%
class limit_of_polynomial_or_rational_function_with_nolimit(core.Question):
    name = '多項式又は有理関数の極限（両側極限がないのも含む）'
    _function_types = ['polynomial', 'rational']
    def __init__(self, emin=-3, emax=3, amin=-1, amax=1):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 極限を求めるxの値の範囲
        self.a_min = amin
        self.a_max = amax
    def _function_generate(self, _var):
        _type = random.choice(self._function_types)
        if _type == 'polynomial':
            return sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,4))])
        else:
            _den = 0
            while _den == 0:
                _den = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            return sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(1,3))]) / _den
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='多項式又は有理関数の極限（なしも含む）', quiz_number=_quiz_number)
        _var = sympy.Symbol('x')
        _f = self._function_generate(_var)
        _a = random.choice(list(range(self.a_min, self.a_max)) + [sympy.S.Infinity, -sympy.S.Infinity])
        _limit = sympy.limit(_f, _var, _a, dir="+")
        _limit_left = sympy.limit(_f, _var, _a, dir="-")
        if _limit != _limit_left:
            _limit = r'極限は存在しない'
            _type = r''
        elif _limit is sympy.S.Infinity or _limit is -sympy.S.Infinity:
            _type = r'発散'
        else:
            _type = r'収束'
        quiz.quiz_identifier = hash(str(_f) + str(_a) + str(_limit))
        # 正答の選択肢の生成
        quiz.data = [_var, _f, _a, _limit, _type]
        ans = { 'fraction': 100, 'data': [_limit, _type] }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_var, _f, _a, _limit, _type] = quiz.data
        _incorrect = r'極限は存在しない'
        if _incorrect != _limit:
            ans['feedback'] = r'無限大へ近づけているか，または右側極限と左側極限は一致しますので，極限は存在します。'
            ans['data'] = [_incorrect, r'']
            answers.append(dict(ans))
            if _type == r'発散':
                _wrong_type = r'収束'
            else:
                _wrong_type = r'発散'
            ans['feedback'] = r'発散とは正か負の無限大へ近づくことで，収束とはそれ以外に近づくことです。確認しましょう。'
            ans['data'] = [_limit, _wrong_type]
            answers.append(dict(ans))            
        _incorrect = (-1)*_limit
        if _incorrect != _limit:
            ans['feedback'] = r'少なくとも極限値に関して符号を間違えています。計算を丁寧に行ってください。'
            ans['data'] = [_incorrect, r'収束']
            answers.append(dict(ans))   
            ans['feedback'] = r'少なくとも極限値に関して符号を間違えています。計算を丁寧に行ってください。'
            ans['data'] = [_incorrect, r'発散']
            answers.append(dict(ans))   
        _incorrect = sympy.limit(_f, _var, (-1)*_a, dir="+")
        if _incorrect != _limit:
            ans['feedback'] = r'少なくとも極限値に関して符号を間違えています。計算を丁寧に行ってください。'
            ans['data'] = [_incorrect, r'収束']
            answers.append(dict(ans))   
            ans['feedback'] = r'少なくとも極限値に関して符号を間違えています。計算を丁寧に行ってください。'
            ans['data'] = [_incorrect, r'発散']
            answers.append(dict(ans))   
        for _possible_a in list(range(self.a_min, self.a_max)) + [sympy.S.Infinity, -sympy.S.Infinity]:
            _incorrect = sympy.limit(_f, _var, _possible_a, dir="+")
            if _incorrect != _limit:
                ans['feedback'] = r'近づける先が間違っています。計算を丁寧に行ってください。'
                ans['data'] = [_incorrect, r'収束']
                answers.append(dict(ans))
                ans['feedback'] = r'近づける先が間違っています。計算を丁寧に行ってください。'
                ans['data'] = [_incorrect, r'発散']
                answers.append(dict(ans))
        answers = common.answer_union(answers)
        while len(answers) < size:
            _incorrect = random.randint(-size, size)
            if _incorrect != _limit:
                ans['feedback'] = r'少なくとも極限値に関して計算を丁寧に行ってください。'
                ans['data'] = [_incorrect, r'収束']
                answers.append(dict(ans))
                ans['feedback'] = r'少なくとも極限値に関して計算を丁寧に行ってください。'
                ans['data'] = [_incorrect, r'発散']
                answers.append(dict(ans))
                answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_var, _f, _a, _limit, _type] = quiz.data
        _text = r'次の極限を選択してください。<br />'
        _text += r'\( \lim_{x\rightarrow' + sympy.latex(_a) + r'}' + sympy.latex(_f, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        if isinstance(ans['data'][0], str):
            return ans['data'][0]
        else:
            return ans['data'][1] + r'し極限値は，\( ' +  sympy.latex(ans['data'][0], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = limit_of_polynomial_or_rational_function_with_nolimit()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=5)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow-1}- x - 1 \)<div style="text-align:right;font-size:smaller">（問題整理番号:180）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview180">収束し極限値は，\( 0 \)</li><li title="点数:0
# フィードバック:少なくとも極限値に関して符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview180">発散し極限値は，\( -2 \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview180">収束し極限値は，\( \infty \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview180">発散し極限値は，\( -1 \)</li><li title="点数:0
# フィードバック:発散とは正か負の無限大へ近づくことで，収束とはそれ以外に近づくことです。確認しましょう。"><input type="radio" name="preview180">発散し極限値は，\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow-1}3 x - 3 \)<div style="text-align:right;font-size:smaller">（問題整理番号:026）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview26">収束し極限値は，\( -3 \)</li><li title="点数:0
# フィードバック:少なくとも極限値に関して符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview26">発散し極限値は，\( 0 \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview26">発散し極限値は，\( -3 \)</li><li title="点数:100"><input type="radio" name="preview26">収束し極限値は，\( -6 \)</li><li title="点数:0
# フィードバック:発散とは正か負の無限大へ近づくことで，収束とはそれ以外に近づくことです。確認しましょう。"><input type="radio" name="preview26">発散し極限値は，\( -6 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow\infty}- 3 x^{2} - x - 3 \)<div style="text-align:right;font-size:smaller">（問題整理番号:087）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:発散とは正か負の無限大へ近づくことで，収束とはそれ以外に近づくことです。確認しましょう。"><input type="radio" name="preview87">収束し極限値は，\( -\infty \)</li><li title="点数:0
# フィードバック:少なくとも極限値に関して符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview87">発散し極限値は，\( \infty \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview87">発散し極限値は，\( -3 \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview87">収束し極限値は，\( -3 \)</li><li title="点数:100"><input type="radio" name="preview87">発散し極限値は，\( -\infty \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow0}\frac{x - 3}{- 3 x - 3} \)<div style="text-align:right;font-size:smaller">（問題整理番号:036）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:発散とは正か負の無限大へ近づくことで，収束とはそれ以外に近づくことです。確認しましょう。"><input type="radio" name="preview36">発散し極限値は，\( 1 \)</li><li title="点数:100"><input type="radio" name="preview36">収束し極限値は，\( 1 \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview36">発散し極限値は，\( - \frac{1}{3} \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview36">収束し極限値は，\( - \frac{1}{3} \)</li><li title="点数:0
# フィードバック:少なくとも極限値に関して符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview36">収束し極限値は，\( -1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow-\infty}\frac{x^{2}}{2} - x + \frac{3}{2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:115）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:少なくとも極限値に関して符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview115">収束し極限値は，\( -\infty \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview115">収束し極限値は，\( 3 \)</li><li title="点数:100"><input type="radio" name="preview115">発散し極限値は，\( \infty \)</li><li title="点数:0
# フィードバック:発散とは正か負の無限大へ近づくことで，収束とはそれ以外に近づくことです。確認しましょう。"><input type="radio" name="preview115">収束し極限値は，\( \infty \)</li><li title="点数:0
# フィードバック:少なくとも極限値に関して符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview115">発散し極限値は，\( -\infty \)</li></ol></div></div>

# %%
if __name__ == "__main__":
    pass
    #qz.save('limit_of_polynomial_or_rational_function_with_nolimit.xml')

# %% [markdown]
# ## directional limit of rational function

# %%
class directional_limit_of_rational_function(core.Question):
    name = '有理関数の片側極限（基本的に分母の根への片側極限）'
    def __init__(self, emin=-3, emax=3, amin=-3, amax=3):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 極限を求めるxの値の範囲
        self.a_min = amin
        self.a_max = amax
    def _function_generate(self, _var, _a):
        _den = 0
        while _den == 0:
            _den = sympy.expand((_var - _a)*sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(1,2))]))
        if random.random() < 0.25:
            _num = abs(_var - _a) + nonzero_randint(self.elem_min, self.elem_max)*(_var - _a)
        elif random.random() < 0.25:
            _num = abs(sympy.expand((_var - _a)*(_var + _a))) + nonzero_randint(self.elem_min, self.elem_max)*(_var - _a)
        else:
            _num = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(1,3))])
        return _num / _den
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='有理関数の片側極限', quiz_number=_quiz_number)
        _var = sympy.Symbol('x')
        while True:
            _a = random.choice(list(range(self.a_min, self.a_max)))
            _f = self._function_generate(_var, _a)
            _limit_right = sympy.limit(_f, _var, _a, dir="+")
            _limit_left = sympy.limit(_f, _var, _a, dir="-")
            if _limit_right != _limit_left:
                break        
        if random.random() < 0.5:
            _direction = "+"
            _limit = _limit_right
        else:
            _direction = "-"
            _limit = _limit_left
        quiz.quiz_identifier = hash(str(_f) + str(_a) + str(_limit))
        # 正答の選択肢の生成
        quiz.data = [_var, _f, _a, _direction, _limit]
        ans = { 'fraction': 100, 'data': _limit }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_var, _f, _a, _direction, _limit] = quiz.data
        if _direction == "+":
            _incorrect = sympy.limit(_f, _var, _a, dir="-")
        else:
            _incorrect = sympy.limit(_f, _var, _a, dir="+")
        if _incorrect != _limit:
            ans['feedback'] = r'右側極限と左側極限を取り違えている可能性があります。'
            ans['data'] = _incorrect
            answers.append(dict(ans))   
        _incorrect = (-1)*_limit
        if _incorrect != _limit:
            ans['feedback'] = r'符号を間違えています。計算を丁寧に行ってください。'
            ans['data'] = _incorrect
            answers.append(dict(ans))   
        _incorrect = sympy.limit(_f, _var, (-1)*_a, dir=_direction)
        if _incorrect != _limit:
            ans['feedback'] = r'符号を間違えています。計算を丁寧に行ってください。'
            ans['data'] = _incorrect
            answers.append(dict(ans))   
        for _possible_a in list(range(self.a_min, self.a_max)) + [sympy.S.Infinity, -sympy.S.Infinity]:
            _incorrect = sympy.limit(_f, _var, _possible_a, dir=_direction)
            if _incorrect != _limit:
                ans['feedback'] = r'近づける先が間違っています。計算を丁寧に行ってください。'
                ans['data'] = _incorrect
                answers.append(dict(ans))
        answers = common.answer_union(answers)
        while len(answers) < size:
            _incorrect = random.randint(-size, size)
            if _incorrect != _limit:
                ans['feedback'] = r'計算を丁寧に行ってください。'
                ans['data'] = _incorrect
                answers.append(dict(ans))
                answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_var, _f, _a, _direction, _limit] = quiz.data
        _text = r'次の極限を選択してください。<br />'
        _text += r'\( \lim_{x\rightarrow' + sympy.latex(_a)
        if _direction == "+":
            _text += r'+0'
        else:
            _text += r'-0'
        _text += r'}' + sympy.latex(_f, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = directional_limit_of_rational_function()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=5)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow1-0}\frac{3 x + \left|{x^{2} - 1}\right| - 3}{- 3 x^{2} + x + 2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:112）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview112">\( \frac{1}{2} \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview112">\( - \frac{3}{4} \)</li><li title="点数:100"><input type="radio" name="preview112">\( - \frac{1}{5} \)</li><li title="点数:0
# フィードバック:符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview112">\( 3 \)</li><li title="点数:0
# フィードバック:符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview112">\( \frac{1}{5} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow0-0}\frac{x + \left|{x}\right|}{3 x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:150）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:計算を丁寧に行ってください。"><input type="radio" name="preview150">\( 2 \)</li><li title="点数:100"><input type="radio" name="preview150">\( 0 \)</li><li title="点数:0
# フィードバック:計算を丁寧に行ってください。"><input type="radio" name="preview150">\( -2 \)</li><li title="点数:0
# フィードバック:右側極限と左側極限を取り違えている可能性があります。"><input type="radio" name="preview150">\( \frac{2}{3} \)</li><li title="点数:0
# フィードバック:計算を丁寧に行ってください。"><input type="radio" name="preview150">\( -1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow-3+0}\frac{- x + \left|{x + 3}\right| - 3}{x + 3} \)<div style="text-align:right;font-size:smaller">（問題整理番号:046）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:計算を丁寧に行ってください。"><input type="radio" name="preview46">\( -1 \)</li><li title="点数:0
# フィードバック:計算を丁寧に行ってください。"><input type="radio" name="preview46">\( 2 \)</li><li title="点数:0
# フィードバック:計算を丁寧に行ってください。"><input type="radio" name="preview46">\( -3 \)</li><li title="点数:0
# フィードバック:右側極限と左側極限を取り違えている可能性があります。"><input type="radio" name="preview46">\( -2 \)</li><li title="点数:100"><input type="radio" name="preview46">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow-2+0}\frac{3 x - 1}{- 3 x - 6} \)<div style="text-align:right;font-size:smaller">（問題整理番号:184）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview184">\( - \frac{10}{3} \)</li><li title="点数:100"><input type="radio" name="preview184">\( \infty \)</li><li title="点数:0
# フィードバック:符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview184">\( - \frac{5}{12} \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview184">\( \frac{1}{6} \)</li><li title="点数:0
# フィードバック:右側極限と左側極限を取り違えている可能性があります。"><input type="radio" name="preview184">\( -\infty \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow-2-0}\frac{x + \left|{x + 2}\right| + 2}{- 3 x^{2} - 7 x - 2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:113）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:右側極限と左側極限を取り違えている可能性があります。"><input type="radio" name="preview113">\( \frac{2}{5} \)</li><li title="点数:100"><input type="radio" name="preview113">\( 0 \)</li><li title="点数:0
# フィードバック:符号を間違えています。計算を丁寧に行ってください。"><input type="radio" name="preview113">\( - \frac{2}{7} \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview113">\( -2 \)</li><li title="点数:0
# フィードバック:近づける先が間違っています。計算を丁寧に行ってください。"><input type="radio" name="preview113">\( - \frac{1}{2} \)</li></ol></div></div>

# %%
if __name__ == "__main__":
    pass
    #qz.save('directional_limit_of_rational_function.xml')

# %% [markdown]
# ## asymptotic behavior of limit

# %%
class asymptotic_behavior_of_limit(core.Question):
    name = '無限小・無限大（収束・発散の速さ）'
    _problem_types = ['lower_infty', 'higher_infty', 'higher_zero', 'same_infty', 'same_zero']
    def __init__(self, emin=-3, emax=3, dmax=3):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 位数の最大
        self.deg_max = dmax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='無限小・無限大', quiz_number=_quiz_number)
        _var = sympy.Symbol('x')
        _deg = sympy.Rational(random.randint(1,self.deg_max*2),2)
        _type = random.choice(self._problem_types)
        quiz.quiz_identifier = hash(str(_deg) + str(_type) + str(random.random()))
        # 正答の選択肢の生成
        quiz.data = [_var, _deg, _type]
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        [_var, _deg, _type] = quiz.data
        if _type == 'lower_infty':
            _a = sympy.S.Infinity
            _lim_f = sympy.S.Infinity
            _lim_x = sympy.S.Infinity
            _lim_fx = 0
            _lim_xf = sympy.S.Infinity
        elif _type == 'higher_infty':
            _a = sympy.S.Infinity
            _lim_f = sympy.S.Infinity
            _lim_x = sympy.S.Infinity
            _lim_fx = sympy.S.Infinity
            _lim_xf = 0
        elif _type == 'same_infty':
            _a = sympy.S.Infinity
            _lim_f = sympy.S.Infinity
            _lim_x = sympy.S.Infinity
            _lim_fx = abs(nonzero_randint(self.elem_min, self.elem_max))
            _lim_xf = sympy.Rational(1, _lim_fx)
        elif _type == 'higher_zero':
            _a = 0
            _lim_f = 0
            _lim_x = 0
            _lim_fx = 0
            _lim_xf = sympy.S.Infinity
        else: #'same_zero'
            _a = 0
            _lim_f = 0
            _lim_x = 0
            _lim_fx = abs(nonzero_randint(self.elem_min, self.elem_max))
            _lim_xf = sympy.Rational(1, _lim_fx)        
        ans = { 'fraction': 100, 'data': [_a, _var, _deg, _lim_f, _lim_x, _lim_fx, _lim_xf] }
        return [ans]
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_var, _deg, _type] = quiz.data
        if _type != 'lower_infty':
            _a = sympy.S.Infinity
            _lim_f = sympy.S.Infinity
            _lim_x = sympy.S.Infinity
            _lim_fx = 0
            _lim_xf = sympy.S.Infinity
            ans['feedback'] = r'この条件では，低位の無限大が適切になります。'
            ans['data'] = [_a, _var, _deg, _lim_f, _lim_x, _lim_fx, _lim_xf]
            answers.append(dict(ans))
        if _type != 'higher_infty':
            _a = sympy.S.Infinity
            _lim_f = sympy.S.Infinity
            _lim_x = sympy.S.Infinity
            _lim_fx = sympy.S.Infinity
            _lim_xf = 0
            ans['feedback'] = r'この条件では，高位の無限大が適切になります。'
            ans['data'] = [_a, _var, _deg, _lim_f, _lim_x, _lim_fx, _lim_xf]
            answers.append(dict(ans))
        if _type != 'same_infty':
            _a = sympy.S.Infinity
            _lim_f = sympy.S.Infinity
            _lim_x = sympy.S.Infinity
            _lim_fx = abs(nonzero_randint(self.elem_min, self.elem_max))
            _lim_xf = sympy.Rational(1, _lim_fx)
            ans['feedback'] = r'この条件では，同位の無限大が適切になります。'
            ans['data'] = [_a, _var, _deg, _lim_f, _lim_x, _lim_fx, _lim_xf]
            answers.append(dict(ans))
        if _type != 'higher_zero':
            _a = 0
            _lim_f = 0
            _lim_x = 0
            _lim_fx = 0
            _lim_xf = sympy.S.Infinity
            ans['feedback'] = r'この条件では，高位の無限小が適切になります。'
            ans['data'] = [_a, _var, _deg, _lim_f, _lim_x, _lim_fx, _lim_xf]
            answers.append(dict(ans))
        if _type != 'same_zero':
            _a = 0
            _lim_f = 0
            _lim_x = 0
            _lim_fx = abs(nonzero_randint(self.elem_min, self.elem_max))
            _lim_xf = sympy.Rational(1, _lim_fx)  
            ans['feedback'] = r'この条件では，同位の無限小が適切になります。'
            ans['data'] = [_a, _var, _deg, _lim_f, _lim_x, _lim_fx, _lim_xf]
            answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers
    def question_text(self, quiz):
        [_var, _deg, _type] = quiz.data
        _text = r'無限小や無限大という観点から次に最も該当する条件を選択してください。<br />『'
        if _type == 'lower_infty':
            if random.random() < 0.5:
                _text += r'\( f(x) \)は\( ' + sympy.latex(_var**_deg) + r' \)より低位の無限大'
            else:
                _text += r'\( f(x)=o(' + sympy.latex(_var**_deg) + r')\;(x\rightarrow\infty) \)'
        elif _type == 'higher_infty':
            _text += r'\( f(x) \)は\( ' + sympy.latex(_var**_deg) + r' \)より高位の無限大'
        elif _type == 'same_infty':
            if random.random() < 0.34:
                _text += r'\( f(x) \)は\( x \)に対して\( ' + sympy.latex(_deg) + r' \)位の無限大'
            elif random.random() < 0.5:
                _text += r'\( f(x)=O(' + sympy.latex(_var**_deg) + r')\;(x\rightarrow\infty) \) かつ '
                _text += r'\( ' + sympy.latex(_var**_deg) + r'=O(f(x))\;(x\rightarrow\infty) \)'
            else:
                _text += r'\( f(x) \)と\( ' + sympy.latex(_var**_deg) + r' \)は同位の無限大'                
        elif _type == 'higher_zero':
            if random.random() < 0.5:
                _text += r'\( f(x) \)は\( ' + sympy.latex(_var**_deg) + r' \)より高位の無限小'
            else:
                _text += r'\( f(x)=o(' + sympy.latex(_var**_deg) + r')\;(x\rightarrow 0) \)'            
        else: #'same_zero'
            if random.random() < 0.34:
                _text += r'\( f(x) \)は\( x \)に対して\( ' + sympy.latex(_deg) + r' \)位の無限小'
            elif random.random() < 0.5:
                _text += r'\( f(x)=O(' + sympy.latex(_var**_deg) + r')\;(x\rightarrow 0) \) かつ '
                _text += r'\( ' + sympy.latex(_var**_deg) + r'=O(f(x))\;(x\rightarrow 0) \)'
            else:
                _text += r'\( f(x) \)と\( ' + sympy.latex(_var**_deg) + r' \)は同位の無限小'
        _text += r'』'
        return _text
    def answer_text(self, ans):
        [_a, _var, _deg, _lim_f, _lim_x, _lim_fx, _lim_xf] = ans['data']
        _text = r'\( \lim_{x\rightarrow ' + sympy.latex(_a) + r'}f(x)=' + sympy.latex(_lim_f) + r',\;'
        _text += r'\lim_{x\rightarrow ' + sympy.latex(_a) + r'}' + sympy.latex(_var**_deg) + r'=' + sympy.latex(_lim_x) + r',\;'
        _text += r'\lim_{x\rightarrow ' + sympy.latex(_a) + r'}\frac{f(x)}{' + sympy.latex(_var**_deg) + r'}=' + sympy.latex(_lim_fx) + r',\;'
        _text += r'\lim_{x\rightarrow ' + sympy.latex(_a) + r'}\frac{' + sympy.latex(_var**_deg) + r'}{f(x)}=' + sympy.latex(_lim_xf) + r' \)'
        return _text

# %%
if __name__ == "__main__":
    q = asymptotic_behavior_of_limit()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=5)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">無限小や無限大という観点から次に最も該当する条件を選択してください。<br />『\( f(x)=O(x^{3})\;(x\rightarrow\infty) \) かつ \( x^{3}=O(f(x))\;(x\rightarrow\infty) \)』<div style="text-align:right;font-size:smaller">（問題整理番号:110）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:この条件では，低位の無限大が適切になります。"><input type="radio" name="preview110">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x^{3}=\infty,\;\lim_{x\rightarrow \infty}\frac{f(x)}{x^{3}}=0,\;\lim_{x\rightarrow \infty}\frac{x^{3}}{f(x)}=\infty \)</li><li title="点数:0
# フィードバック:この条件では，高位の無限大が適切になります。"><input type="radio" name="preview110">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x^{3}=\infty,\;\lim_{x\rightarrow \infty}\frac{f(x)}{x^{3}}=\infty,\;\lim_{x\rightarrow \infty}\frac{x^{3}}{f(x)}=0 \)</li><li title="点数:0
# フィードバック:この条件では，高位の無限小が適切になります。"><input type="radio" name="preview110">\( \lim_{x\rightarrow 0}f(x)=0,\;\lim_{x\rightarrow 0}x^{3}=0,\;\lim_{x\rightarrow 0}\frac{f(x)}{x^{3}}=0,\;\lim_{x\rightarrow 0}\frac{x^{3}}{f(x)}=\infty \)</li><li title="点数:0
# フィードバック:この条件では，同位の無限小が適切になります。"><input type="radio" name="preview110">\( \lim_{x\rightarrow 0}f(x)=0,\;\lim_{x\rightarrow 0}x^{3}=0,\;\lim_{x\rightarrow 0}\frac{f(x)}{x^{3}}=2,\;\lim_{x\rightarrow 0}\frac{x^{3}}{f(x)}=\frac{1}{2} \)</li><li title="点数:100"><input type="radio" name="preview110">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x^{3}=\infty,\;\lim_{x\rightarrow \infty}\frac{f(x)}{x^{3}}=2,\;\lim_{x\rightarrow \infty}\frac{x^{3}}{f(x)}=\frac{1}{2} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">無限小や無限大という観点から次に最も該当する条件を選択してください。<br />『\( f(x) \)は\( x^{\frac{5}{2}} \)より低位の無限大』<div style="text-align:right;font-size:smaller">（問題整理番号:121）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:この条件では，高位の無限大が適切になります。"><input type="radio" name="preview121">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x^{\frac{5}{2}}=\infty,\;\lim_{x\rightarrow \infty}\frac{f(x)}{x^{\frac{5}{2}}}=\infty,\;\lim_{x\rightarrow \infty}\frac{x^{\frac{5}{2}}}{f(x)}=0 \)</li><li title="点数:0
# フィードバック:この条件では，同位の無限大が適切になります。"><input type="radio" name="preview121">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x^{\frac{5}{2}}=\infty,\;\lim_{x\rightarrow \infty}\frac{f(x)}{x^{\frac{5}{2}}}=1,\;\lim_{x\rightarrow \infty}\frac{x^{\frac{5}{2}}}{f(x)}=1 \)</li><li title="点数:0
# フィードバック:この条件では，同位の無限小が適切になります。"><input type="radio" name="preview121">\( \lim_{x\rightarrow 0}f(x)=0,\;\lim_{x\rightarrow 0}x^{\frac{5}{2}}=0,\;\lim_{x\rightarrow 0}\frac{f(x)}{x^{\frac{5}{2}}}=2,\;\lim_{x\rightarrow 0}\frac{x^{\frac{5}{2}}}{f(x)}=\frac{1}{2} \)</li><li title="点数:100"><input type="radio" name="preview121">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x^{\frac{5}{2}}=\infty,\;\lim_{x\rightarrow \infty}\frac{f(x)}{x^{\frac{5}{2}}}=0,\;\lim_{x\rightarrow \infty}\frac{x^{\frac{5}{2}}}{f(x)}=\infty \)</li><li title="点数:0
# フィードバック:この条件では，高位の無限小が適切になります。"><input type="radio" name="preview121">\( \lim_{x\rightarrow 0}f(x)=0,\;\lim_{x\rightarrow 0}x^{\frac{5}{2}}=0,\;\lim_{x\rightarrow 0}\frac{f(x)}{x^{\frac{5}{2}}}=0,\;\lim_{x\rightarrow 0}\frac{x^{\frac{5}{2}}}{f(x)}=\infty \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">無限小や無限大という観点から次に最も該当する条件を選択してください。<br />『\( f(x)=O(x)\;(x\rightarrow 0) \) かつ \( x=O(f(x))\;(x\rightarrow 0) \)』<div style="text-align:right;font-size:smaller">（問題整理番号:052）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:この条件では，高位の無限小が適切になります。"><input type="radio" name="preview52">\( \lim_{x\rightarrow 0}f(x)=0,\;\lim_{x\rightarrow 0}x=0,\;\lim_{x\rightarrow 0}\frac{f(x)}{x}=0,\;\lim_{x\rightarrow 0}\frac{x}{f(x)}=\infty \)</li><li title="点数:0
# フィードバック:この条件では，低位の無限大が適切になります。"><input type="radio" name="preview52">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x=\infty,\;\lim_{x\rightarrow \infty}\frac{f(x)}{x}=0,\;\lim_{x\rightarrow \infty}\frac{x}{f(x)}=\infty \)</li><li title="点数:0
# フィードバック:この条件では，高位の無限大が適切になります。"><input type="radio" name="preview52">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x=\infty,\;\lim_{x\rightarrow \infty}\frac{f(x)}{x}=\infty,\;\lim_{x\rightarrow \infty}\frac{x}{f(x)}=0 \)</li><li title="点数:100"><input type="radio" name="preview52">\( \lim_{x\rightarrow 0}f(x)=0,\;\lim_{x\rightarrow 0}x=0,\;\lim_{x\rightarrow 0}\frac{f(x)}{x}=3,\;\lim_{x\rightarrow 0}\frac{x}{f(x)}=\frac{1}{3} \)</li><li title="点数:0
# フィードバック:この条件では，同位の無限大が適切になります。"><input type="radio" name="preview52">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x=\infty,\;\lim_{x\rightarrow \infty}\frac{f(x)}{x}=1,\;\lim_{x\rightarrow \infty}\frac{x}{f(x)}=1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">無限小や無限大という観点から次に最も該当する条件を選択してください。<br />『\( f(x) \)は\( x \)より高位の無限大』<div style="text-align:right;font-size:smaller">（問題整理番号:142）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:この条件では，同位の無限小が適切になります。"><input type="radio" name="preview142">\( \lim_{x\rightarrow 0}f(x)=0,\;\lim_{x\rightarrow 0}x=0,\;\lim_{x\rightarrow 0}\frac{f(x)}{x}=2,\;\lim_{x\rightarrow 0}\frac{x}{f(x)}=\frac{1}{2} \)</li><li title="点数:0
# フィードバック:この条件では，低位の無限大が適切になります。"><input type="radio" name="preview142">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x=\infty,\;\lim_{x\rightarrow \infty}\frac{f(x)}{x}=0,\;\lim_{x\rightarrow \infty}\frac{x}{f(x)}=\infty \)</li><li title="点数:0
# フィードバック:この条件では，高位の無限小が適切になります。"><input type="radio" name="preview142">\( \lim_{x\rightarrow 0}f(x)=0,\;\lim_{x\rightarrow 0}x=0,\;\lim_{x\rightarrow 0}\frac{f(x)}{x}=0,\;\lim_{x\rightarrow 0}\frac{x}{f(x)}=\infty \)</li><li title="点数:100"><input type="radio" name="preview142">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x=\infty,\;\lim_{x\rightarrow \infty}\frac{f(x)}{x}=\infty,\;\lim_{x\rightarrow \infty}\frac{x}{f(x)}=0 \)</li><li title="点数:0
# フィードバック:この条件では，同位の無限大が適切になります。"><input type="radio" name="preview142">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x=\infty,\;\lim_{x\rightarrow \infty}\frac{f(x)}{x}=1,\;\lim_{x\rightarrow \infty}\frac{x}{f(x)}=1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">無限小や無限大という観点から次に最も該当する条件を選択してください。<br />『\( f(x)=o(x^{3})\;(x\rightarrow\infty) \)』<div style="text-align:right;font-size:smaller">（問題整理番号:088）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:この条件では，同位の無限小が適切になります。"><input type="radio" name="preview88">\( \lim_{x\rightarrow 0}f(x)=0,\;\lim_{x\rightarrow 0}x^{3}=0,\;\lim_{x\rightarrow 0}\frac{f(x)}{x^{3}}=1,\;\lim_{x\rightarrow 0}\frac{x^{3}}{f(x)}=1 \)</li><li title="点数:0
# フィードバック:この条件では，高位の無限小が適切になります。"><input type="radio" name="preview88">\( \lim_{x\rightarrow 0}f(x)=0,\;\lim_{x\rightarrow 0}x^{3}=0,\;\lim_{x\rightarrow 0}\frac{f(x)}{x^{3}}=0,\;\lim_{x\rightarrow 0}\frac{x^{3}}{f(x)}=\infty \)</li><li title="点数:0
# フィードバック:この条件では，同位の無限大が適切になります。"><input type="radio" name="preview88">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x^{3}=\infty,\;\lim_{x\rightarrow \infty}\frac{f(x)}{x^{3}}=2,\;\lim_{x\rightarrow \infty}\frac{x^{3}}{f(x)}=\frac{1}{2} \)</li><li title="点数:0
# フィードバック:この条件では，高位の無限大が適切になります。"><input type="radio" name="preview88">\( \lim_{x\rightarrow \infty}f(x)=\infty,\;\lim_{x\rightarrow \infty}x^{3}=\infty,\;\lim_{x\rightarrow \

# %%
if __name__ == "__main__":
    pass
    #qz.save('asymptotic_behavior_of_limit.xml')

# %% [markdown]
# ## limit of trigonometric function

# %%
class limit_of_trigonometric_function(core.Question):
    name = '三角関数の極限（両側極限がないのも含む）'
    _a = sympy.Symbol('a') # non-zero
    _b = sympy.Symbol('b') # non-zero
    _c = sympy.Symbol('c') # non-zero
    _s = sympy.Symbol('s') # positive
    _t = sympy.Symbol('t') # positive
    _q = sympy.Symbol('q') # poly with zero-constant
    _p = sympy.Symbol('p') # poly with zero-constant
    _x = sympy.Symbol('x')
    _major_angles = [sympy.pi/i for i in [-6,-4,-3,-2,2,3,4,6]] + [0]
    _major_angles_for_tan = [sympy.pi/i for i in [-6,-4,-3,3,4,6]] + [0]
    _skeletons = [[_a*sympy.sin(_c*_x), [sympy.S.Infinity, -sympy.S.Infinity], False], 
                  [_a*sympy.cos(_c*_x), [sympy.S.Infinity, -sympy.S.Infinity], False], 
                  [_a*sympy.sin(_c/_x), [0], False], 
                  [_a*sympy.cos(_c/_x), [0], False], 
                  [_a*sympy.sin(_x), _major_angles, True], 
                  [_a*sympy.cos(_x), _major_angles, True], 
                  [_a*sympy.tan(_x), _major_angles_for_tan, True], 
                  [_a*sympy.sin(_c/_x), [sympy.S.Infinity, -sympy.S.Infinity], True], 
                  [_a*sympy.cos(_c/_x), [sympy.S.Infinity, -sympy.S.Infinity], True], 
                  [_a*sympy.tan(_c/_x), [sympy.S.Infinity, -sympy.S.Infinity], True], 
                  [_a*_x*sympy.sin(_c/_x), [0], True], 
                  [_a*_x*sympy.cos(_c/_x), [0], True], 
                  [(_a/_x)*sympy.sin(_c*_x), [sympy.S.Infinity, -sympy.S.Infinity], True], 
                  [(_a/_x)*sympy.cos(_c*_x), [sympy.S.Infinity, -sympy.S.Infinity], True], 
                  [sympy.sin(_b*_x)/(_a*_x), [0], True], 
                  [sympy.sin(_b*_x)/(sympy.sin(_a*_x)), [0], True], 
                  [sympy.tan(_b*_x)/(_a*_x), [0], True], 
                  [sympy.sin(_b*_x**_s)/(_a*_x**_t), [0], True], 
                  [sympy.sin(_q)/(_p), [0], True]]
    def __init__(self, emin=-5, emax=5, dmax=3):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 多項式の次数の最大
        self.deg_max = dmax
    def _function_generate(self, _func):
        _func = _func.subs(self._a, nonzero_randint(self.elem_min, self.elem_max))
        _func = _func.subs(self._b, nonzero_randint(self.elem_min, self.elem_max))
        _func = _func.subs(self._c, nonzero_randint(self.elem_min, self.elem_max))
        _func = _func.subs(self._s, abs(nonzero_randint(self.elem_min, self.elem_max)))
        _func = _func.subs(self._t, abs(nonzero_randint(self.elem_min, self.elem_max)))
        _poly = 0
        while _poly == 0:
            _poly = sum([random.randint(self.elem_min, self.elem_max)*self._x**i for i in range(1,random.randint(1,self.deg_max))])
        _func = _func.subs(self._p, _poly)
        _poly = 0
        while _poly == 0:
            _poly = sum([random.randint(self.elem_min, self.elem_max)*self._x**i for i in range(1,random.randint(1,self.deg_max))])
        _func = _func.subs(self._q, _poly)
        return _func
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='三角関数の極限（なしも含む）', quiz_number=_quiz_number)
        [_func, _alist, _exists] = random.choice(self._skeletons)
        _func = self._function_generate(_func)
        _a = random.choice(_alist)
        _limit = r'not exist'
        if _exists:
            _limit = sympy.limit(_func, self._x, _a, dir="+")
            _limit_left = sympy.limit(_func, self._x, _a, dir="-")
            if _limit != _limit_left:
                _exists = False
        quiz.quiz_identifier = hash(str(_func) + str(_a) + str(_limit))
        # 正答の選択肢の生成
        quiz.data = [_func, _a, _exists, _limit]
        ans = { 'fraction': 100, 'data': [_exists, _limit] }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_func, _a, _exists, _limit] = quiz.data
        if _exists:
            _incorrect = [False, _limit]
            ans['feedback'] = r'無限大へ近づけているか，または右側極限と左側極限は一致しますので，極限は存在します。'
            ans['data'] = _incorrect
            answers.append(dict(ans))
        ans['data'] = [True, sympy.S.Infinity]
        if not _exists:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif abs(_limit) != sympy.S.Infinity:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif _limit != sympy.S.Infinity:
            ans['feedback'] = r'極限を求める場合，符号のミスは起こりやすいものの1つです。よく確認しましょう。'
            answers.append(dict(ans))    
        ans['data'] = [True, -sympy.S.Infinity]
        if not _exists:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif abs(_limit) != sympy.S.Infinity:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif _limit != -sympy.S.Infinity:
            ans['feedback'] = r'極限を求める場合，符号のミスは起こりやすいものの1つです。よく確認しましょう。'
            answers.append(dict(ans))    
        ans['data'] = [True, 0]
        if not _exists:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif abs(_limit) == sympy.S.Infinity:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif _limit != 0:
            ans['feedback'] = r'極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。'
            answers.append(dict(ans))
        for i in range(2):
            _incorrect_limit = nonzero_randint(self.elem_min, self.elem_max)
            ans['data'] = [True, _incorrect_limit]
            if not _exists:
                ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。'
                answers.append(dict(ans))    
            elif abs(_limit) == sympy.S.Infinity:
                ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。'
                answers.append(dict(ans))    
            elif _limit != _incorrect_limit:
                ans['feedback'] = r'極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。'
                answers.append(dict(ans))  
        for i in range(2):  
            _incorrect_limit = sympy.Rational(nonzero_randint(self.elem_min, self.elem_max), nonzero_randint(self.elem_min, self.elem_max))
            ans['data'] = [True, _incorrect_limit]
            if not _exists:
                ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。'
                answers.append(dict(ans))    
            elif abs(_limit) == sympy.S.Infinity:
                ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。'
                answers.append(dict(ans))    
            elif _limit != _incorrect_limit:
                ans['feedback'] = r'極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。'
                answers.append(dict(ans))    
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_func, _a, _exists, _limit] = quiz.data
        _text = r'次の極限を選択してください。<br />'
        _text += r'\( \lim_{' + sympy.latex(self._x) + r'\rightarrow' + sympy.latex(_a) + r'}' + sympy.latex(_func, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        if ans['data'][0]:
            return r'\( ' +  sympy.latex(ans['data'][1], order='lex') + r' \)'
        else:
            return r'極限は存在しない'

# %%
if __name__ == "__main__":
    q = limit_of_trigonometric_function()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=5)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow0}- 3 x \sin{\left(\frac{2}{x} \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:081）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview81">\( - \frac{5}{4} \)</li><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview81">\( -4 \)</li><li title="点数:100"><input type="radio" name="preview81">\( 0 \)</li><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview81">\( 2 \)</li><li title="点数:0
# フィードバック:無限大へ近づけているか，または右側極限と左側極限は一致しますので，極限は存在します。"><input type="radio" name="preview81">極限は存在しない</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow-\infty}5 \tan{\left(\frac{2}{x} \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:101）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview101">\( -1 \)</li><li title="点数:100"><input type="radio" name="preview101">\( 0 \)</li><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview101">\( - \frac{2}{3} \)</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。"><input type="radio" name="preview101">\( \infty \)</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。"><input type="radio" name="preview101">\( -\infty \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow\infty}4 \cos{\left(4 x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:131）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。"><input type="radio" name="preview131">\( -\infty \)</li><li title="点数:100"><input type="radio" name="preview131">極限は存在しない</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。"><input type="radio" name="preview131">\( 5 \)</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。"><input type="radio" name="preview131">\( 0 \)</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。"><input type="radio" name="preview131">\( \infty \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow-\infty}3 \sin{\left(4 x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:026）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。"><input type="radio" name="preview26">\( 0 \)</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。"><input type="radio" name="preview26">\( \frac{5}{2} \)</li><li title="点数:100"><input type="radio" name="preview26">極限は存在しない</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。"><input type="radio" name="preview26">\( \infty \)</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。"><input type="radio" name="preview26">\( -3 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow-\infty}- \sin{\left(\frac{4}{x} \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:022）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview22">\( - \frac{2}{5} \)</li><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview22">\( -1 \)</li><li title="点数:100"><input type="radio" name="preview22">\( 0 \)</li><li title="点数:0
# フィードバック:無限大へ近づけているか，または右側極限と左側極限は一致しますので，極限は存在します。"><input type="radio" name="preview22">極限は存在しない</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。"><input type="radio" name="preview22">\( -\infty \)</li></ol></div></div>

# %%
if __name__ == "__main__":
    pass
    #qz.save('limit_of_trigonometric_function.xml')

# %% [markdown]
# ## limit of exponential and logarithmic function

# %%
class limit_of_exponential_and_logarithmic_function(core.Question):
    name = '指数関数と対数関数の極限'
    _a = sympy.Symbol('a') # non-ONE positive rational (could be less than 1) or integer (larger than 1)
    _b = sympy.Symbol('b') # non-zero integer
    _c = sympy.Symbol('c') # positive integer
    _d = sympy.Symbol('d') # non-ONE positive rational (could be less than 1) or integer (larger than 1)
    _e = sympy.Symbol('e') # non-zero integer
    _f = sympy.Symbol('f') # positive integer
    _x = sympy.Symbol('x')
    # [expression, [x tends to, direction], [tex form of expresion: string or expression]]
    _skeletons = [[_a**(_b*_x), [[sympy.S.Infinity,0], [-sympy.S.Infinity,0], [0,0]], [_a**(_b*_x)]], 
                  [sympy.log(_c*_x, _a), [[sympy.S.Infinity,0], [0,+1]], [r'\log_{', _a, r'}(', _c*_x, r')']], 
                  [_a**(_b*_x)-_d**(_e*_x), [[sympy.S.Infinity,0], [-sympy.S.Infinity,0], [0,0]], [_a**(_b*_x)-_d**(_e*_x)]], 
#                  [sympy.log(_c*_x+_b, _a)-sympy.log(_f*_x+_e, _a), [[sympy.S.Infinity,0]], [r'\log_{', _a, r'}(', _c*_x+_b, r')-\log_{', _a, r'}(', _f*_x+_e, r')']], 
                  [(1+_b/_x)**(_e*_x), [[sympy.S.Infinity,0], [-sympy.S.Infinity,0]], [(1+_b/_x)**(_e*_x)]], 
                  [(_b/_x)*sympy.log(_c*_x+1), [[0,0]], [(_b/_x)*sympy.log(_c*_x+1)]], 
                  [(sympy.exp(_b*_x)-1)/(_e*_x), [[0,0]], [(sympy.exp(_b*_x)-1)/(_e*_x)]]]
    def __init__(self, emin=-3, emax=3):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
    def _parameter_substitution(self, _func, _values):
        _func = _func.subs(self._a, _values['a'])
        _func = _func.subs(self._b, _values['b'])
        _func = _func.subs(self._c, _values['c'])
        _func = _func.subs(self._d, _values['d'])
        _func = _func.subs(self._e, _values['e'])
        _func = _func.subs(self._f, _values['f'])
        return _func
    def _generate_values(self):
        _values = dict()
        _values['a'] = sympy.Rational(1,nonone_randpint(self.elem_min,self.elem_max)) if random.random() < 0.5 else nonone_randpint(self.elem_min,self.elem_max)
        _values['b'] = nonzero_randint(self.elem_min,self.elem_max)
        _values['c'] = abs(nonzero_randint(self.elem_min,self.elem_max))
        _values['d'] = sympy.Rational(1,nonone_randpint(self.elem_min,self.elem_max)) if random.random() < 0.5 else nonone_randpint(self.elem_min,self.elem_max)
        _values['e'] = nonzero_randint(self.elem_min,self.elem_max)
        _values['f'] = abs(nonzero_randint(self.elem_min,self.elem_max))
        return _values
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='指数関数と対数関数の極限', quiz_number=_quiz_number)
        while True:
            [_funcO, _alist, _texform] = random.choice(self._skeletons)
            _values = self._generate_values()
            _func = self._parameter_substitution(_funcO, _values)
            if not _func.is_number:
                break
        [_a, _dir] = random.choice(_alist)
#        print(_funcO, " : ", _func, ":", _a, " with ", _values)
        if _dir == 0:
            _limit = sympy.limit(sympy.simplify(_func), self._x, _a, dir="+-")
        elif _dir > 0:
            _limit = sympy.limit(sympy.simplify(_func), self._x, _a, dir="+")
        else:
            _limit = sympy.limit(sympy.simplify(_func), self._x, _a, dir="-")
#        print('===> ', _limit)
        quiz.quiz_identifier = hash(str(_func) + str(_a) + str(_limit))
        # 正答の選択肢の生成
        quiz.data = [_func, _a, _dir, _limit, _values, _texform]
        ans = { 'fraction': 100, 'data': _limit }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_func, _a, _dir, _limit, _values, _texform] = quiz.data
        ans['feedback'] = r'無限大へ近づけているか，または右側極限と左側極限は一致しますので，極限は存在します。'
        ans['data'] = r'not exist'
        answers.append(dict(ans))
        ans['data'] = sympy.S.Infinity
        if abs(_limit) != sympy.S.Infinity:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif _limit != sympy.S.Infinity:
            ans['feedback'] = r'極限を求める場合，符号のミスは起こりやすいものの1つです。よく確認しましょう。'
            answers.append(dict(ans))    
        ans['data'] = -sympy.S.Infinity
        if abs(_limit) != sympy.S.Infinity:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif _limit != -sympy.S.Infinity:
            ans['feedback'] = r'極限を求める場合，符号のミスは起こりやすいものの1つです。よく確認しましょう。'
            answers.append(dict(ans))    
        ans['data'] = 0
        if abs(_limit) == sympy.S.Infinity:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif _limit != 0:
            ans['feedback'] = r'極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。'
            answers.append(dict(ans))
        if _limit != 0 and abs(_limit) != sympy.S.Infinity:
            ans['data'] = 1/_limit
            ans['feedback'] = r'極限を求める場合，式の取り違いも起こりえます。よく確認しましょう。'
            answers.append(dict(ans))    
        _incorrect_limit = nonzero_randint(self.elem_min, self.elem_max)
        ans['data'] = _incorrect_limit
        if abs(_limit) == sympy.S.Infinity:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif _limit != _incorrect_limit:
            ans['feedback'] = r'極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。'
            answers.append(dict(ans))  
        ans['data'] = sympy.Rational(1,_incorrect_limit)
        if abs(_limit) == sympy.S.Infinity:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif _limit != _incorrect_limit:
            ans['feedback'] = r'極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。'
            answers.append(dict(ans))  
        _incorrect_limit = sympy.Rational(nonzero_randint(self.elem_min, self.elem_max), nonzero_randint(self.elem_min, self.elem_max))
        ans['data'] = _incorrect_limit
        if abs(_limit) == sympy.S.Infinity:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif _limit != _incorrect_limit:
            ans['feedback'] = r'極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。'
            answers.append(dict(ans))    
        ans['data'] = 1/_incorrect_limit
        if abs(_limit) == sympy.S.Infinity:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif _limit != _incorrect_limit:
            ans['feedback'] = r'極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。'
            answers.append(dict(ans))     
        _incorrect_limit = sympy.E**nonzero_randint(self.elem_min, self.elem_max)
        ans['data'] = _incorrect_limit
        if abs(_limit) == sympy.S.Infinity:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif _limit != _incorrect_limit:
            ans['feedback'] = r'極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。'
            answers.append(dict(ans))    
        ans['data'] = 1/_incorrect_limit
        if abs(_limit) == sympy.S.Infinity:
            ans['feedback'] = r'極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。'
            answers.append(dict(ans))    
        elif _limit != _incorrect_limit:
            ans['feedback'] = r'極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。'
            answers.append(dict(ans))    
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_func, _a, _dir, _limit, _values, _texform] = quiz.data
        _text = r'次の極限を選択してください。<br />'
        _text += r'\( \lim_{' + sympy.latex(self._x) + r'\rightarrow'
        if _dir > 0:
            _text += r'+'
        elif _dir < 0:
            _text += r'-'
        _text += sympy.latex(_a) + r'}'
        for _v in _texform:
            if isinstance(_v, str):
                _text += _v
            else:
                _text += sympy.latex(self._parameter_substitution(_v, _values), order='lex') 
        _text += r' \)'
        return _text
    def answer_text(self, ans):
        if not isinstance(ans['data'],str):
            return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'
        else:
            return r'極限は存在しない'

# %%
if __name__ == "__main__":
    q = limit_of_exponential_and_logarithmic_function()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=5)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow0}- \frac{2 \log{\left(3 x + 1 \right)}}{x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:137）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview137">\( 3 \)</li><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview137">\( 0 \)</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。"><input type="radio" name="preview137">\( -\infty \)</li><li title="点数:0
# フィードバック:無限大へ近づけているか，または右側極限と左側極限は一致しますので，極限は存在します。"><input type="radio" name="preview137">極限は存在しない</li><li title="点数:100"><input type="radio" name="preview137">\( -6 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow0}- \frac{\log{\left(x + 1 \right)}}{x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:104）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview104">\( -1 \)</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。"><input type="radio" name="preview104">\( \infty \)</li><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview104">\( 3 \)</li><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview104">\( \frac{1}{2} \)</li><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview104">\( 2 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow\infty}3^{- x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:047）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview47">\( 2 \)</li><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview47">\( e^{-2} \)</li><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview47">\( -1 \)</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。"><input type="radio" name="preview47">\( \infty \)</li><li title="点数:100"><input type="radio" name="preview47">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow0}- \frac{-1 + e^{- x}}{x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:032）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview32">\( 0 \)</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。発散していませんので，よく確認しましょう。"><input type="radio" name="preview32">\( \infty \)</li><li title="点数:100"><input type="radio" name="preview32">\( 1 \)</li><li title="点数:0
# フィードバック:極限を求める場合，最後の数値の四則演算などで間違えることもあります。よく確認しましょう。"><input type="radio" name="preview32">\( 3 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{x\rightarrow\infty}\log_{\frac{1}{3}}(3 x) \)<div style="text-align:right;font-size:smaller">（問題整理番号:064）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。"><input type="radio" name="preview64">\( e^{-2} \)</li><li title="点数:100"><input type="radio" name="preview64">\( -\infty \)</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。"><input type="radio" name="preview64">\( 2 \)</li><li title="点数:0
# フィードバック:極限を求める場合，符号のミスは起こりやすいものの1つです。よく確認しましょう。"><input type="radio" name="preview64">\( \infty \)</li><li title="点数:0
# フィードバック:極限の状況には，収束・発散・存在しない，の3通りあります。収束していませんので，よく確認しましょう。"><input type="radio" name="preview64">\( e^{2} \)</li></ol></div></div>

# %%
if __name__ == "__main__":
    pass
    #qz.save('limit_of_exponential_and_logarithmic_function.xml')

# %% [markdown]
# ## average rate of change

# %%
class average_rate_of_change(core.Question):
    name = '平均変化率（微分係数の導入前段階）'
    _a = sympy.Symbol('a') # non-zero
    _b = sympy.Symbol('b') # non-zero
    _c = sympy.Symbol('c') # positive
    _x = sympy.Symbol('x')
    _skeletons = [_a*sympy.sin(_b*_x),_a*sympy.cos(_b*_x),_a*sympy.tan(_b*_x),
                  _a*_x**_c, _a/_x**_c, _a*_x+_b, 1/(_x+_a), _a*_x**2+_b, 1/(_x**2+_a)]
    def __init__(self, emin=-3, emax=3, hmin=-2, hmax=2):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        self.h_min = hmin
        self.h_max = hmax
    def _function_generate(self, _func):
        _func = _func.subs(self._a, nonzero_randint(self.elem_min, self.elem_max))
        _func = _func.subs(self._b, nonzero_randint(self.elem_min, self.elem_max))
        _func = _func.subs(self._c, abs(nonzero_randint(self.elem_min, self.elem_max)))
        return _func
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='平均変化率', quiz_number=_quiz_number)
        _func = random.choice(self._skeletons)
        _func = self._function_generate(_func)
        _a = random.randint(self.elem_min, self.elem_max)
        _h = nonzero_randint(self.h_min, self.h_max)
        while True:
            err = 0
            if _h < 0:
                for _b in range(0, _h - 1, -1):
                    if not _func.subs(self._x, _a + _b).is_real:
                        err = err + 1
            else:
                for _b in range(0, _h + 1, 1):
                    if not _func.subs(self._x, _a + _b).is_real:
                        err = err + 1
            if err == 0:
                break
            _func = random.choice(self._skeletons)
            _func = self._function_generate(_func)
            _a = random.randint(self.elem_min, self.elem_max)
            _h = nonzero_randint(self.h_min, self.h_max)
        quiz.quiz_identifier = hash(str(_func) + str(_a) + str(_h))
        # 正答の選択肢の生成
        _arc = (_func.subs(self._x, _a + _h) - _func.subs(self._x, _a))*sympy.Rational(1,_h)
        quiz.data = [_func, _a, _h, _arc]
        ans = { 'fraction': 100, 'data': _arc }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_func, _a, _h, _arc] = quiz.data
        _incorrect = -(_func.subs(self._x, _a + _h) - _func.subs(self._x, _a))*sympy.Rational(1,_h)
        if _arc != _incorrect:
            ans['feedback'] = r'平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。'
            ans['data'] = _incorrect
            answers.append(dict(ans))
        _incorrect = (_func.subs(self._x, _a + _h) + _func.subs(self._x, _a))*sympy.Rational(1,_h)
        if _arc != _incorrect:
            ans['feedback'] = r'平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。'
            ans['data'] = _incorrect
            answers.append(dict(ans))
        _incorrect = -(_func.subs(self._x, _a + _h) + _func.subs(self._x, _a))*sympy.Rational(1,_h)
        if _arc != _incorrect:
            ans['feedback'] = r'平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。'
            ans['data'] = _incorrect
            answers.append(dict(ans))
        _incorrect = (_func.subs(self._x, _a + _h) - _func.subs(self._x, _a))
        if _arc != _incorrect:
            ans['feedback'] = r'平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。'
            ans['data'] = _incorrect
            answers.append(dict(ans))
        _incorrect = -(_func.subs(self._x, _a + _h) - _func.subs(self._x, _a))
        if _arc != _incorrect:
            ans['feedback'] = r'平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。'
            ans['data'] = _incorrect
            answers.append(dict(ans))          
        answers = common.answer_union(answers)
        while len(answers) < size:
            _incorrect = _arc + random.randint(self.elem_min, self.elem_max)
            if _arc != _incorrect:
                ans['feedback'] = r'平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。'
                ans['data'] = _incorrect
                answers.append(dict(ans))
            if _arc != -_incorrect:
                ans['feedback'] = r'平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。'
                ans['data'] = -_incorrect
                answers.append(dict(ans))                
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_func, _a, _h, _arc] = quiz.data
        _text = r'次の関数\( f(x) \)が\( x=' + sympy.latex(_a) + r' \)から\( x='
        _text += sympy.latex(_a)
        if _h < 0:
            _text += r'+(' + sympy.latex(_h) + r')'
        else:
            _text += r'+' + sympy.latex(_h)
        _text += r' \)まで変化するときの平均変化率を選択してください。<br />'
        _text += r'\( f(x)=' + sympy.latex(_func, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = average_rate_of_change()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=5)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)が\( x=-3 \)から\( x=-3+2 \)まで変化するときの平均変化率を選択してください。<br />\( f(x)=x^{2} - 2 \)<div style="text-align:right;font-size:smaller">（問題整理番号:127）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview127">\( -8 \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview127">\( 3 \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview127">\( 4 \)</li><li title="点数:100"><input type="radio" name="preview127">\( -4 \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview127">\( 8 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)が\( x=-3 \)から\( x=-3+2 \)まで変化するときの平均変化率を選択してください。<br />\( f(x)=- 2 \sin{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:053）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview53">\( - \sin{\left(1 \right)} - \sin{\left(3 \right)} \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview53">\( - 2 \sin{\left(1 \right)} + 2 \sin{\left(3 \right)} \)</li><li title="点数:100"><input type="radio" name="preview53">\( - \sin{\left(3 \right)} + \sin{\left(1 \right)} \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview53">\( \sin{\left(3 \right)} + \sin{\left(1 \right)} \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview53">\( - 2 \sin{\left(3 \right)} + 2 \sin{\left(1 \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)が\( x=1 \)から\( x=1+(-2) \)まで変化するときの平均変化率を選択してください。<br />\( f(x)=x^{2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:123）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview123">\( 1 \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview123">\( -2 \)</li><li title="点数:100"><input type="radio" name="preview123">\( 0 \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview123">\( 2 \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview123">\( -1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)が\( x=-1 \)から\( x=-1+2 \)まで変化するときの平均変化率を選択してください。<br />\( f(x)=- 2 \cos{\left(3 x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:175）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview175">\( -3 \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview175">\( - 2 \cos{\left(3 \right)} \)</li><li title="点数:100"><input type="radio" name="preview175">\( 0 \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview175">\( 2 \cos{\left(3 \right)} \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview175">\( 3 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)が\( x=2 \)から\( x=2+1 \)まで変化するときの平均変化率を選択してください。<br />\( f(x)=- \frac{1}{x^{3}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:186）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview186">\( - \frac{19}{216} \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview186">\( \frac{197}{216} \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview186">\( - \frac{35}{216} \)</li><li title="点数:100"><input type="radio" name="preview186">\( \frac{19}{216} \)</li><li title="点数:0
# フィードバック:平均変化率は，変化先から変化元を引いた関数の値の変化の変数の値の変化に対する割合です。"><input type="radio" name="preview186">\( - \frac{197}{216} \)</li></ol></div></div>

# %%
if __name__ == "__main__":
    pass
    #qz.save('average_rate_of_change.xml')

# %% [markdown]
# ## differential coefficient

# %%
class differential_coefficient(core.Question):
    name = '微分係数の計算（多項式，有理関数及び区分的関数）'
    _function_types = ['polynomial', 'rational', 'piecewise']
    _h = sympy.Symbol('h')
    def __init__(self, emin=-3, emax=3, amin=-2, amax=2):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 極限を求めるxの値の範囲
        self.a_min = amin
        self.a_max = amax
    def _differential_coefficient(self, _func, _var, _a, _dir):
        _rate_of_change = (_func.subs(_var, _a + self._h) - _func.subs(_var, _a))/self._h
        return sympy.limit(_rate_of_change, self._h, 0, dir=_dir)
    def _function_generate(self, _var, _a):
        _type = random.choice(self._function_types)
        if _type == 'polynomial':
            _pol = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            while _pol == 0:
                _pol = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            return _pol
        elif _type == 'rational':
            _den = 0
            while _den == 0:
                _den = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            return sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(1,3))]) / _den
        else:
            _ok = random.choice([False, True])
            _notequal = _ok
            _upper = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            _lower = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            while _upper.subs(_var, _a) != _lower.subs(_var, _a):
                _upper = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
                _lower = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            if _ok:
                _limit = self._differential_coefficient(_upper, _var, _a, "+")
                _limit_left = self._differential_coefficient(_lower, _var, _a, "-")
                if _limit == _limit_left:
                    _notequal = False                
            while _upper == _lower or _upper == 0 or _lower == 0 or _notequal:
                _notequal = _ok
                _upper = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
                _lower = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
                while _upper.subs(_var, _a) != _lower.subs(_var, _a):
                    _upper = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
                    _lower = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
                if _ok:
                    _limit = self._differential_coefficient(_upper, _var, _a, "+")
                    _limit_left = self._differential_coefficient(_lower, _var, _a, "-")
                    if _limit == _limit_left:
                        _notequal = False                
            return [_upper, _lower]
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='微分係数の計算（区分的関数含む）', quiz_number=_quiz_number)
        _var = sympy.Symbol('x')
        _a = random.randint(self.a_min, self.a_max)
        _f = self._function_generate(_var, _a)
        if isinstance(_f, list):
            _limit_right = self._differential_coefficient(_f[0], _var, _a, "+")
            _limit_left = self._differential_coefficient(_f[1], _var, _a, "-")
        else:
            _limit_right = self._differential_coefficient(_f, _var, _a, "+")
            _limit_left = self._differential_coefficient(_f, _var, _a, "-")
        if _limit_right != _limit_left:
            _limit = r'微分可能でない'
        else:
            _limit = _limit_right
        while True:
            if isinstance(_limit, str):
                break
            elif _limit.is_real:
                break
            _a = random.randint(self.a_min, self.a_max)
            _f = self._function_generate(_var, _a)
            if isinstance(_f, list):
                _limit_right = self._differential_coefficient(_f[0], _var, _a, "+")
                _limit_left = self._differential_coefficient(_f[1], _var, _a, "-")
            else:
                _limit_right = self._differential_coefficient(_f, _var, _a, "+")
                _limit_left = self._differential_coefficient(_f, _var, _a, "-")
            if _limit_right != _limit_left:
                _limit = r'微分可能でない'
            else:
                _limit = _limit_right            
        quiz.quiz_identifier = hash(str(_f) + str(_a) + str(_limit))
        # 正答の選択肢の生成
        quiz.data = [_var, _f, _a, _limit, _limit_right, _limit_left]
        ans = { 'fraction': 100, 'data': _limit }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_var, _f, _a, _limit, _limit_right, _limit_left] = quiz.data
        _incorrect = r'微分可能でない'
        if _incorrect != _limit:
            ans['feedback'] = r'微分係数の定義に基づき右側極限と左側極限を求めると一致しますので，微分係数は存在します。'
            ans['data'] = _incorrect
            answers.append(dict(ans))
            _incorrect = -_limit
            if _incorrect != _limit:
                ans['feedback'] = r'微分係数の定義に基づき丁寧に計算し直してください。'
                ans['data'] = _incorrect
                answers.append(dict(ans))
            _incorrect = 0
            if _incorrect != _limit:
                ans['feedback'] = r'微分係数の定義に基づき，きちんと計算をしてください。'
                ans['data'] = _incorrect
                answers.append(dict(ans))
            _incorrect = _a
            if _incorrect != _limit:
                ans['feedback'] = r'微分係数の定義に基づき，きちんと計算をしてください。'
                ans['data'] = _incorrect
                answers.append(dict(ans))
            _incorrect = -_a
            if _incorrect != _limit:
                ans['feedback'] = r'微分係数の定義に基づき，きちんと計算をしてください。'
                ans['data'] = _incorrect
                answers.append(dict(ans))
        else:
            ans['feedback'] = r'微分係数の定義に基づき極限を求めたとき，右側極限と左側極限が一致しなければ，微分係数は存在しません。'
            ans['data'] = _limit_right
            answers.append(dict(ans))
            ans['data'] = _limit_left
            answers.append(dict(ans))
            ans['data'] = -_limit_right
            answers.append(dict(ans))
            ans['data'] = -_limit_left
            answers.append(dict(ans))
            ans['feedback'] = r'微分係数の定義に基づき，きちんと計算をしてください。'
            ans['data'] = _a
            answers.append(dict(ans))
            ans['data'] = -_a
            answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_var, _f, _a, _limit, _limit_right, _limit_left] = quiz.data
        _text = r'次の関数\( f(' + sympy.latex(_var) + r') \)の\( ' + sympy.latex(_var) + r'=' + sympy.latex(_a) + r' \)での微分係数を選択してください。<br />'
        _text += r'\( f(' + sympy.latex(_var) +  r')=' 
        if isinstance(_f, list):
            _text += r'\left\{\begin{array}{cc}' 
            _text += sympy.latex(_f[0], order='lex') + r'&(' + sympy.latex(_var) + r'\geq ' + sympy.latex(_a) + r')\\'
            _text += sympy.latex(_f[1], order='lex') + r'&(' + sympy.latex(_var) + r'<' + sympy.latex(_a) + r')'
            _text += r'\end{array}\right.'
        else:
            _text += sympy.latex(_f, order='lex')
        _text += r' \)'
        return _text
    def answer_text(self, ans):
        if isinstance(ans['data'], str):
            return ans['data']
        else:
            return r'\( ' + sympy.latex(ans['data']) + r' \)'

# %%
if __name__ == "__main__":
    q = differential_coefficient()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=0 \)での微分係数を選択してください。<br />\( f(x)=2 x - 1 \)<div style="text-align:right;font-size:smaller">（問題整理番号:070）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:微分係数の定義に基づき丁寧に計算し直してください。"><input type="radio" name="preview70">\( -2 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき右側極限と左側極限を求めると一致しますので，微分係数は存在します。"><input type="radio" name="preview70">微分可能でない</li><li title="点数:100"><input type="radio" name="preview70">\( 2 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview70">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=-2 \)での微分係数を選択してください。<br />\( f(x)=\left\{\begin{array}{cc}2 x&(x\geq -2)\\x - 2&(x<-2)\end{array}\right. \)<div style="text-align:right;font-size:smaller">（問題整理番号:149）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:微分係数の定義に基づき極限を求めたとき，右側極限と左側極限が一致しなければ，微分係数は存在しません。"><input type="radio" name="preview149">\( -2 \)</li><li title="点数:100"><input type="radio" name="preview149">微分可能でない</li><li title="点数:0
# フィードバック:微分係数の定義に基づき極限を求めたとき，右側極限と左側極限が一致しなければ，微分係数は存在しません。"><input type="radio" name="preview149">\( -1 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき極限を求めたとき，右側極限と左側極限が一致しなければ，微分係数は存在しません。"><input type="radio" name="preview149">\( 2 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき極限を求めたとき，右側極限と左側極限が一致しなければ，微分係数は存在しません。"><input type="radio" name="preview149">\( 1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=-2 \)での微分係数を選択してください。<br />\( f(x)=\frac{- 2 x - 1}{2 x - 1} \)<div style="text-align:right;font-size:smaller">（問題整理番号:094）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview94">\( 2 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview94">\( -2 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき右側極限と左側極限を求めると一致しますので，微分係数は存在します。"><input type="radio" name="preview94">微分可能でない</li><li title="点数:100"><input type="radio" name="preview94">\( \frac{4}{25} \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview94">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=2 \)での微分係数を選択してください。<br />\( f(x)=- \frac{3 x}{x^{2} - 3 x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:062）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:微分係数の定義に基づき丁寧に計算し直してください。"><input type="radio" name="preview62">\( -3 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき右側極限と左側極限を求めると一致しますので，微分係数は存在します。"><input type="radio" name="preview62">微分可能でない</li><li title="点数:100"><input type="radio" name="preview62">\( 3 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview62">\( 0 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview62">\( -2 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=0 \)での微分係数を選択してください。<br />\( f(x)=- 2 x + 3 \)<div style="text-align:right;font-size:smaller">（問題整理番号:104）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:微分係数の定義に基づき丁寧に計算し直してください。"><input type="radio" name="preview104">\( 2 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき右側極限と左側極限を求めると一致しますので，微分係数は存在します。"><input type="radio" name="preview104">微分可能でない</li><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview104">\( 0 \)</li><li title="点数:100"><input type="radio" name="preview104">\( -2 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=-1 \)での微分係数を選択してください。<br />\( f(x)=\frac{- 3 x + 1}{3 x^{2} - x - 2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:139）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview139">\( 1 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき丁寧に計算し直してください。"><input type="radio" name="preview139">\( - \frac{11}{2} \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview139">\( -1 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview139">\( 0 \)</li><li title="点数:100"><input type="radio" name="preview139">\( \frac{11}{2} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=-1 \)での微分係数を選択してください。<br />\( f(x)=\left\{\begin{array}{cc}2 x + 3&(x\geq -1)\\- 3 x^{2} - 2 x + 2&(x<-1)\end{array}\right. \)<div style="text-align:right;font-size:smaller">（問題整理番号:180）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:微分係数の定義に基づき極限を求めたとき，右側極限と左側極限が一致しなければ，微分係数は存在しません。"><input type="radio" name="preview180">\( 2 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき極限を求めたとき，右側極限と左側極限が一致しなければ，微分係数は存在しません。"><input type="radio" name="preview180">\( -2 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき極限を求めたとき，右側極限と左側極限が一致しなければ，微分係数は存在しません。"><input type="radio" name="preview180">\( -4 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview180">\( 1 \)</li><li title="点数:100"><input type="radio" name="preview180">微分可能でない</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=-1 \)での微分係数を選択してください。<br />\( f(x)=\frac{3 x^{2} + 3 x + 3}{x^{2} - 2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:174）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview174">\( -1 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview174">\( 1 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき右側極限と左側極限を求めると一致しますので，微分係数は存在します。"><input type="radio" name="preview174">微分可能でない</li><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview174">\( 0 \)</li><li title="点数:100"><input type="radio" name="preview174">\( 9 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=0 \)での微分係数を選択してください。<br />\( f(x)=\left\{\begin{array}{cc}- x^{2} + 3&(x\geq 0)\\- 2 x^{2} + 3&(x<0)\end{array}\right. \)<div style="text-align:right;font-size:smaller">（問題整理番号:004）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:微分係数の定義に基づき右側極限と左側極限を求めると一致しますので，微分係数は存在します。"><input type="radio" name="preview4">微分可能でない</li><li title="点数:100"><input type="radio" name="preview4">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=2 \)での微分係数を選択してください。<br />\( f(x)=2 x^{2} + 2 x + 2 \)<div style="text-align:right;font-size:smaller">（問題整理番号:081）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview81">\( 10 \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づき右側極限と左側極限を求めると一致しますので，微分係数は存在します。"><input type="radio" name="preview81">微分可能でない</li><li title="点数:0
# フィードバック:微分係数の定義に基づき，きちんと計算をしてください。"><input type="radio" name="preview81"

# %%
if __name__ == "__main__":
    #pass
    qz.save('differential_coefficient.xml')

# %% [markdown]
# ## differential coefficient intermediate expression

# %%
class differential_coefficient_intermediate_expression(core.Question):
    name = '微分係数の途中式（不適切なものを選択）'
    _function_types = ['polynomial', 'rational', 'piecewise']
    _h = sympy.Symbol('h')
    def __init__(self, emin=-3, emax=3, amin=-2, amax=2):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 極限を求めるxの値の範囲
        self.a_min = amin
        self.a_max = amax
    def _differential_coefficient(self, _func, _var, _a, _dir):
        _rate_of_change = (_func.subs(_var, _a + self._h) - _func.subs(_var, _a))/self._h
        return sympy.limit(_rate_of_change, self._h, 0, dir=_dir)
    def _function_generate(self, _var, _a):
        _type = random.choice(self._function_types)
        if _type == 'polynomial':
            _pol = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            while _pol == 0:
                _pol = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            return _pol
        elif _type == 'rational':
            _den = 0
            while _den == 0:
                _den = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            return sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(1,3))]) / _den
        else:
            _ok = random.choice([False, True])
            _notequal = _ok
            _upper = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            _lower = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            while _upper.subs(_var, _a) != _lower.subs(_var, _a):
                _upper = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
                _lower = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
            if _ok:
                _limit = self._differential_coefficient(_upper, _var, _a, "+")
                _limit_left = self._differential_coefficient(_lower, _var, _a, "-")
                if _limit == _limit_left:
                    _notequal = False                
            while _upper == _lower or _upper == 0 or _lower == 0 or _notequal:
                _notequal = _ok
                _upper = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
                _lower = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
                while _upper.subs(_var, _a) != _lower.subs(_var, _a):
                    _upper = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
                    _lower = sum([random.randint(self.elem_min, self.elem_max)*_var**i for i in range(0,random.randint(2,3))])
                if _ok:
                    _limit = self._differential_coefficient(_upper, _var, _a, "+")
                    _limit_left = self._differential_coefficient(_lower, _var, _a, "-")
                    if _limit == _limit_left:
                        _notequal = False                
            return [_upper, _lower]
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='微分係数の途中式', quiz_number=_quiz_number)
        _var = sympy.Symbol('x')
        _a = random.randint(self.a_min, self.a_max)
        _f = self._function_generate(_var, _a)
        quiz.quiz_identifier = hash(str(_f) + str(_a))
        quiz.data = [_var, _f, _a]
        # 不正解の選択肢の生成
        ans = dict()
        ans['fraction'] = 0
        ans['feedback'] = r'微分係数の定義に基づいた式であり，必要な極限計算となります。'
        ans['data'] = r'\( \lim_{' + sympy.latex(_var) + r'\rightarrow' + sympy.latex(_a) + r'}\frac{f(' + sympy.latex(_var) + r')-f(' + sympy.latex(_a) + r')}{' + sympy.latex(_var)
        if _a < 0:
            ans['data'] += r'+' + sympy.latex(-_a) + r'} \)'
        elif _a == 0:
            ans['data'] += r'} \)'
        else:
            ans['data'] += r'-' + sympy.latex(_a) + r'} \)'
        quiz.answers.append(dict(ans))
        if _a != 0:
            ans['data'] = r'\( \lim_{h\rightarrow 0}\frac{f(' + sympy.latex(_a) + r'+h)-f(' + sympy.latex(_a) + r')}{h} \)'
        else:
            ans['data'] = r'\( \lim_{h\rightarrow 0}\frac{f(h)-f(' + sympy.latex(_a) + r')}{h} \)'
        quiz.answers.append(dict(ans))
        ans['feedback'] = r'極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。'
        if _a != 0:
            ans['data'] = r'\( \lim_{' + sympy.latex(_var) + r'\rightarrow' + sympy.latex(_a) + r'-0}\frac{f(' + sympy.latex(_var) + r')-f(' + sympy.latex(_a) + r')}{' + sympy.latex(_var)
            if _a < 0:
                ans['data'] += r'+' + sympy.latex(-_a) + r'} \)'
            elif _a == 0:
                ans['data'] += r'} \)'
            else:
                ans['data'] += r'-' + sympy.latex(_a) + r'} \)'
            quiz.answers.append(dict(ans))
            ans['data'] = r'\( \lim_{' + sympy.latex(_var) + r'\rightarrow' + sympy.latex(_a) + r'+0}\frac{f(' + sympy.latex(_var) + r')-f(' + sympy.latex(_a) + r')}{' + sympy.latex(_var)
            if _a < 0:
                ans['data'] += r'+' + sympy.latex(-_a) + r'} \)'
            elif _a == 0:
                ans['data'] += r'} \)'
            else:
                ans['data'] += r'-' + sympy.latex(_a) + r'} \)'
            quiz.answers.append(dict(ans))
        else:
            ans['data'] = r'\( \lim_{' + sympy.latex(_var) + r'\rightarrow -0}\frac{f(' + sympy.latex(_var) + r')-f(' + sympy.latex(_a) + r')}{' + sympy.latex(_var) + r'} \)'
            quiz.answers.append(dict(ans))
            ans['data'] = r'\( \lim_{' + sympy.latex(_var) + r'\rightarrow +0}\frac{f(' + sympy.latex(_var) + r')-f(' + sympy.latex(_a) + r')}{' + sympy.latex(_var) + r'} \)'
            quiz.answers.append(dict(ans))
        ans['data'] = r'\( \lim_{h\rightarrow -0}\frac{f(' + sympy.latex(_a) + r'+h)-f(' + sympy.latex(_a) + r')}{h} \)'
        quiz.answers.append(dict(ans))
        ans['data'] = r'\( \lim_{h\rightarrow +0}\frac{f(' + sympy.latex(_a) + r'+h)-f(' + sympy.latex(_a) + r')}{h} \)'
        quiz.answers.append(dict(ans))
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        [_var, _f, _a] = quiz.data
        answers = []
        ans = dict()
        ans['fraction'] = 100
        ans['data'] = r'\( \lim_{' + sympy.latex(_var) + r'\rightarrow' + sympy.latex(_a) + r'}\frac{f(' + sympy.latex(_var) + r')+f(' + sympy.latex(_a) + r')}{' + sympy.latex(_var)
        if _a < 0:
            ans['data'] += r'+' + sympy.latex(-_a) + r'} \)'
        elif _a == 0:
            ans['data'] += r'} \)'
        else:
            ans['data'] += r'-' + sympy.latex(_a) + r'} \)'
        answers.append(dict(ans))
        if _a != 0:
            ans['data'] = r'\( \lim_{h\rightarrow 0}\frac{f(' + sympy.latex(_a) + r'+h)+f(' + sympy.latex(_a) + r')}{h} \)'
        else:
            ans['data'] = r'\( \lim_{h\rightarrow 0}\frac{f(h)+f(' + sympy.latex(_a) + r')}{h} \)'
        answers.append(dict(ans))
        if _a != 0:
            ans['data'] = r'\( \lim_{' + sympy.latex(_var) + r'\rightarrow' + sympy.latex(_a) + r'-0}\frac{f(' + sympy.latex(_var) + r')+f(' + sympy.latex(_a) + r')}{' + sympy.latex(_var)
            if _a < 0:
                ans['data'] += r'+' + sympy.latex(-_a) + r'} \)'
            elif _a == 0:
                ans['data'] += r'} \)'
            else:
                ans['data'] += r'-' + sympy.latex(_a) + r'} \)'
            answers.append(dict(ans))
            ans['data'] = r'\( \lim_{' + sympy.latex(_var) + r'\rightarrow' + sympy.latex(_a) + r'+0}\frac{f(' + sympy.latex(_var) + r')+f(' + sympy.latex(_a) + r')}{' + sympy.latex(_var)
            if _a < 0:
                ans['data'] += r'+' + sympy.latex(-_a) + r'} \)'
            elif _a == 0:
                ans['data'] += r'} \)'
            else:
                ans['data'] += r'-' + sympy.latex(_a) + r'} \)'
            answers.append(dict(ans))
        else:
            ans['data'] = r'\( \lim_{' + sympy.latex(_var) + r'\rightarrow -0}\frac{f(' + sympy.latex(_var) + r')+f(' + sympy.latex(_a) + r')}{' + sympy.latex(_var) + r'} \)'
            answers.append(dict(ans))
            ans['data'] = r'\( \lim_{' + sympy.latex(_var) + r'\rightarrow +0}\frac{f(' + sympy.latex(_var) + r')+f(' + sympy.latex(_a) + r')}{' + sympy.latex(_var) + r'} \)'
            answers.append(dict(ans))
        ans['data'] = r'\( \lim_{h\rightarrow -0}\frac{f(' + sympy.latex(_a) + r'+h)+f(' + sympy.latex(_a) + r')}{h} \)'
        answers.append(dict(ans))
        ans['data'] = r'\( \lim_{h\rightarrow +0}\frac{f(' + sympy.latex(_a) + r'+h)+f(' + sympy.latex(_a) + r')}{h} \)'
        answers.append(dict(ans))
        ans['data'] = r'\( \lim_{' + sympy.latex(_var) + r'\rightarrow' + sympy.latex(_a) + r'}\frac{f(' + sympy.latex(_var) + r')-f(' + sympy.latex(_a) + r')}{' + sympy.latex(_var)
        if _a < 0:
            ans['data'] += sympy.latex(_a) + r'} \)'
            answers.append(dict(ans))
        elif _a > 0:
            ans['data'] += r'+' + sympy.latex(_a) + r'} \)'
            answers.append(dict(ans))            
        if _a != 0:
            ans['data'] = r'\( \lim_{h\rightarrow ' + sympy.latex(_a) + r'}\frac{f(' + sympy.latex(_a) + r'+h)-f(' + sympy.latex(_a) + r')}{h} \)'
            answers.append(dict(ans))
            ans['data'] = r'\( \lim_{' + sympy.latex(_var) + r'\rightarrow' + sympy.latex(_a) + r'-0}\frac{f(' + sympy.latex(_var) + r')-f(' + sympy.latex(_a) + r')}{' + sympy.latex(_var)
            if _a < 0:
                ans['data'] += sympy.latex(_a) + r'} \)'
            elif _a > 0:
                ans['data'] += r'+' + sympy.latex(_a) + r'} \)'
            answers.append(dict(ans))
            ans['data'] = r'\( \lim_{' + sympy.latex(_var) + r'\rightarrow' + sympy.latex(_a) + r'+0}\frac{f(' + sympy.latex(_var) + r')-f(' + sympy.latex(_a) + r')}{' + sympy.latex(_var)
            if _a < 0:
                ans['data'] += sympy.latex(_a) + r'} \)'
            elif _a > 0:
                ans['data'] += r'+' + sympy.latex(_a) + r'} \)'
            answers.append(dict(ans))
        return [random.choice(answers)]        
    def incorrect_answers_generate(self, quiz, size=4):
        # 個別には作らないので何もしない
        pass
    def question_text(self, quiz):
        [_var, _f, _a] = quiz.data
        _text = r'次の関数\( f(' + sympy.latex(_var) + r') \)の\( ' + sympy.latex(_var) + r'=' + sympy.latex(_a) + r' \)での微分係数が存在するか調べたり計算することに関係のない数式を選択してください。<br />'
        _text += r'\( f(' + sympy.latex(_var) +  r')=' 
        if isinstance(_f, list):
            _text += r'\left\{\begin{array}{cc}' 
            _text += sympy.latex(_f[0], order='lex') + r'&(' + sympy.latex(_var) + r'\geq ' + sympy.latex(_a) + r')\\'
            _text += sympy.latex(_f[1], order='lex') + r'&(' + sympy.latex(_var) + r'<' + sympy.latex(_a) + r')'
            _text += r'\end{array}\right.'
        else:
            _text += sympy.latex(_f, order='lex')
        _text += r' \)'
        return _text
    def answer_text(self, ans):
        return ans['data']

# %%
if __name__ == "__main__":
    q = differential_coefficient_intermediate_expression()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=-1 \)での微分係数が存在するか調べたり計算することに関係のない数式を選択してください。<br />\( f(x)=x - 1 \)<div style="text-align:right;font-size:smaller">（問題整理番号:112）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:微分係数の定義に基づいた式であり，必要な極限計算となります。"><input type="radio" name="preview112">\( \lim_{x\rightarrow-1}\frac{f(x)-f(-1)}{x+1} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview112">\( \lim_{h\rightarrow +0}\frac{f(-1+h)-f(-1)}{h} \)</li><li title="点数:100"><input type="radio" name="preview112">\( \lim_{x\rightarrow-1+0}\frac{f(x)+f(-1)}{x+1} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview112">\( \lim_{h\rightarrow -0}\frac{f(-1+h)-f(-1)}{h} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview112">\( \lim_{x\rightarrow-1+0}\frac{f(x)-f(-1)}{x+1} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview112">\( \lim_{x\rightarrow-1-0}\frac{f(x)-f(-1)}{x+1} \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づいた式であり，必要な極限計算となります。"><input type="radio" name="preview112">\( \lim_{h\rightarrow 0}\frac{f(-1+h)-f(-1)}{h} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=2 \)での微分係数が存在するか調べたり計算することに関係のない数式を選択してください。<br />\( f(x)=x - 1 \)<div style="text-align:right;font-size:smaller">（問題整理番号:017）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview17">\( \lim_{h\rightarrow -0}\frac{f(2+h)-f(2)}{h} \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づいた式であり，必要な極限計算となります。"><input type="radio" name="preview17">\( \lim_{x\rightarrow2}\frac{f(x)-f(2)}{x-2} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview17">\( \lim_{x\rightarrow2-0}\frac{f(x)-f(2)}{x-2} \)</li><li title="点数:100"><input type="radio" name="preview17">\( \lim_{h\rightarrow 0}\frac{f(2+h)+f(2)}{h} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview17">\( \lim_{h\rightarrow +0}\frac{f(2+h)-f(2)}{h} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview17">\( \lim_{x\rightarrow2+0}\frac{f(x)-f(2)}{x-2} \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づいた式であり，必要な極限計算となります。"><input type="radio" name="preview17">\( \lim_{h\rightarrow 0}\frac{f(2+h)-f(2)}{h} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=-1 \)での微分係数が存在するか調べたり計算することに関係のない数式を選択してください。<br />\( f(x)=\left\{\begin{array}{cc}2 x^{2} + x&(x\geq -1)\\x^{2} - x - 1&(x<-1)\end{array}\right. \)<div style="text-align:right;font-size:smaller">（問題整理番号:064）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview64">\( \lim_{h\rightarrow 0}\frac{f(-1+h)+f(-1)}{h} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview64">\( \lim_{h\rightarrow -0}\frac{f(-1+h)-f(-1)}{h} \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づいた式であり，必要な極限計算となります。"><input type="radio" name="preview64">\( \lim_{x\rightarrow-1}\frac{f(x)-f(-1)}{x+1} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview64">\( \lim_{h\rightarrow +0}\frac{f(-1+h)-f(-1)}{h} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview64">\( \lim_{x\rightarrow-1+0}\frac{f(x)-f(-1)}{x+1} \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づいた式であり，必要な極限計算となります。"><input type="radio" name="preview64">\( \lim_{h\rightarrow 0}\frac{f(-1+h)-f(-1)}{h} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview64">\( \lim_{x\rightarrow-1-0}\frac{f(x)-f(-1)}{x+1} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=2 \)での微分係数が存在するか調べたり計算することに関係のない数式を選択してください。<br />\( f(x)=2 x^{2} + x - 3 \)<div style="text-align:right;font-size:smaller">（問題整理番号:021）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview21">\( \lim_{h\rightarrow +0}\frac{f(2+h)-f(2)}{h} \)</li><li title="点数:100"><input type="radio" name="preview21">\( \lim_{x\rightarrow2-0}\frac{f(x)-f(2)}{x+2} \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づいた式であり，必要な極限計算となります。"><input type="radio" name="preview21">\( \lim_{h\rightarrow 0}\frac{f(2+h)-f(2)}{h} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview21">\( \lim_{x\rightarrow2-0}\frac{f(x)-f(2)}{x-2} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview21">\( \lim_{h\rightarrow -0}\frac{f(2+h)-f(2)}{h} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview21">\( \lim_{x\rightarrow2+0}\frac{f(x)-f(2)}{x-2} \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づいた式であり，必要な極限計算となります。"><input type="radio" name="preview21">\( \lim_{x\rightarrow2}\frac{f(x)-f(2)}{x-2} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=0 \)での微分係数が存在するか調べたり計算することに関係のない数式を選択してください。<br />\( f(x)=- x^{2} - 2 x + 2 \)<div style="text-align:right;font-size:smaller">（問題整理番号:088）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview88">\( \lim_{x\rightarrow +0}\frac{f(x)-f(0)}{x} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview88">\( \lim_{x\rightarrow -0}\frac{f(x)-f(0)}{x} \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づいた式であり，必要な極限計算となります。"><input type="radio" name="preview88">\( \lim_{h\rightarrow 0}\frac{f(h)-f(0)}{h} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview88">\( \lim_{h\rightarrow +0}\frac{f(0+h)-f(0)}{h} \)</li><li title="点数:0
# フィードバック:微分係数の定義に基づいた式であり，必要な極限計算となります。"><input type="radio" name="preview88">\( \lim_{x\rightarrow0}\frac{f(x)-f(0)}{x} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview88">\( \lim_{h\rightarrow -0}\frac{f(0+h)-f(0)}{h} \)</li><li title="点数:100"><input type="radio" name="preview88">\( \lim_{x\rightarrow +0}\frac{f(x)+f(0)}{x} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=-1 \)での微分係数が存在するか調べたり計算することに関係のない数式を選択してください。<br />\( f(x)=\left\{\begin{array}{cc}- 3 x^{2} - 3 x - 3&(x\geq -1)\\- 2 x^{2} - x - 2&(x<-1)\end{array}\right. \)<div style="text-align:right;font-size:smaller">（問題整理番号:183）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview183">\( \lim_{h\rightarrow +0}\frac{f(-1+h)-f(-1)}{h} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" name="preview183">\( \lim_{x\rightarrow-1+0}\frac{f(x)-f(-1)}{x+1} \)</li><li title="点数:100"><input type="radio" name="preview183">\( \lim_{h\rightarrow -0}\frac{f(-1+h)+f(-1)}{h} \)</li><li title="点数:0
# フィードバック:極限計算は丁寧に行うならば，片側極限同士の一致を調べるため必要な計算となります。"><input type="radio" n

# %%
if __name__ == "__main__":
    pass
    #qz.save('differential_coefficient_intermediate_expression.xml')

# %% [markdown]
# ## derivative by definition

# %%
class derivative_by_definition(core.Question):
    name = '導関数の途中式（定義に基づく極限計算による）'
    _a = sympy.Symbol('a') # possibly zero
    _b = sympy.Symbol('b') # possibly zero
    _c = sympy.Symbol('c') # possibly zero
    _s = sympy.Symbol('s') # non-zero
    _t = sympy.Symbol('t') # non-zero
    _p = sympy.Symbol('p') # positive
    _e = sympy.Symbol('e') # non-one positive
    _x = sympy.Symbol('x')
    _h = sympy.Symbol('h')
    _skeletons = [_s*_x**2+_b*_x+_c, _s*_x+_c, (_s*_x+_a)/(_t*_x+_b), _s*_x**_p, 
                  _s*sympy.sin(_x), _s*sympy.cos(_x), _s*sympy.tan(_x), _s*sympy.exp(_x), 
                  _s*_e**_x, _s*sympy.log(_x)]
    def __init__(self, emin=-5, emax=5):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
    def _function_generate(self, _func):
        _func = _func.subs(self._a, random.randint(self.elem_min, self.elem_max))
        _func = _func.subs(self._b, random.randint(self.elem_min, self.elem_max))
        _func = _func.subs(self._c, random.randint(self.elem_min, self.elem_max))
        _func = _func.subs(self._s, nonzero_randint(self.elem_min, self.elem_max))
        _func = _func.subs(self._t, nonzero_randint(self.elem_min, self.elem_max))
        _func = _func.subs(self._p, abs(nonzero_randint(self.elem_min, self.elem_max)))
        _func = _func.subs(self._e, nonone_randpint(self.elem_min, self.elem_max))
        return _func
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='導関数の途中式', quiz_number=_quiz_number)
        _func = random.choice(self._skeletons)
        _func = self._function_generate(_func)
        while _func.is_real:
            _func = random.choice(self._skeletons)
            _func = self._function_generate(_func)            
        quiz.quiz_identifier = hash(str(_func))
        # 正答の選択肢の生成
        _ime = sympy.simplify((_func.subs(self._x, self._x + self._h) - _func)/self._h)
        quiz.data = [_func, _ime]
        ans = { 'fraction': 100, 'data': _ime }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_func, _ime] = quiz.data
        _incorrect = sympy.simplify((_func.subs(self._x, self._x + self._h) - _func))
        ans['feedback'] = r'導関数を定義に基づき求める立式を行ってください。分母が欠けていることがわかります。'
        ans['data'] = _incorrect
        answers.append(dict(ans))
        _incorrect = sympy.simplify((_func.subs(self._x, self._x + self._h) + _func))
        ans['feedback'] = r'導関数を定義に基づき求める立式を行ってください。分母が欠けていることがわかります。'
        ans['data'] = _incorrect
        answers.append(dict(ans))
        _incorrect = sympy.simplify((_func.subs(self._x, self._x + self._h) + _func)/self._h)
        if sympy.simplify(_incorrect - _ime) != 0:
            ans['feedback'] = r'導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。'
            ans['data'] = _incorrect
            answers.append(dict(ans))
        _incorrect = sympy.simplify((_func.subs(self._x, self._x + self._h) - _func.subs(self._x, self._x - self._h))/self._h)
        if sympy.simplify(_incorrect - _ime) != 0:
            ans['feedback'] = r'導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。'
            ans['data'] = _incorrect
            answers.append(dict(ans))
        _incorrect = sympy.simplify((_func.subs(self._x, self._x + self._h) + _func.subs(self._x, self._x - self._h))/self._h)
        if sympy.simplify(_incorrect - _ime) != 0:
            ans['feedback'] = r'導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。'
            ans['data'] = _incorrect
            answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_func, _ime] = quiz.data
        _text = r'次の関数\( f(x) \)の導関数を定義に基づき極限計算により求める際に，表れる途中式を選択してください。<br />'
        _text += r'\( f(x)=' + sympy.latex(_func, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        return r'\( \lim_{' + sympy.latex(self._h) + r'\rightarrow 0}' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = derivative_by_definition()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=5)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を定義に基づき極限計算により求める際に，表れる途中式を選択してください。<br />\( f(x)=- 2 \log{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:018）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。分母が欠けていることがわかります。"><input type="radio" name="preview18">\( \lim_{h\rightarrow 0}2 \log{\left(x \right)} - 2 \log{\left(h + x \right)} \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。分母が欠けていることがわかります。"><input type="radio" name="preview18">\( \lim_{h\rightarrow 0}- 2 \log{\left(x \right)} - 2 \log{\left(h + x \right)} \)</li><li title="点数:100"><input type="radio" name="preview18">\( \lim_{h\rightarrow 0}\frac{2 \left(\log{\left(x \right)} - \log{\left(h + x \right)}\right)}{h} \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。"><input type="radio" name="preview18">\( \lim_{h\rightarrow 0}- \frac{2 \log{\left(- h + x \right)} + 2 \log{\left(h + x \right)}}{h} \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。"><input type="radio" name="preview18">\( \lim_{h\rightarrow 0}\frac{2 \left(\log{\left(- h + x \right)} - \log{\left(h + x \right)}\right)}{h} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を定義に基づき極限計算により求める際に，表れる途中式を選択してください。<br />\( f(x)=- 4 x^{2} + 3 x - 4 \)<div style="text-align:right;font-size:smaller">（問題整理番号:166）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。"><input type="radio" name="preview166">\( \lim_{h\rightarrow 0}\frac{- 8 h^{2} - 8 x^{2} + 6 x - 8}{h} \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。"><input type="radio" name="preview166">\( \lim_{h\rightarrow 0}- 16 x + 6 \)</li><li title="点数:100"><input type="radio" name="preview166">\( \lim_{h\rightarrow 0}- 4 h - 8 x + 3 \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。"><input type="radio" name="preview166">\( \lim_{h\rightarrow 0}\frac{3 h - 4 x^{2} + 6 x - 4 \left(h + x\right)^{2} - 8}{h} \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。分母が欠けていることがわかります。"><input type="radio" name="preview166">\( \lim_{h\rightarrow 0}3 h - 4 x^{2} + 6 x - 4 \left(h + x\right)^{2} - 8 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を定義に基づき極限計算により求める際に，表れる途中式を選択してください。<br />\( f(x)=- x^{2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:184）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。"><input type="radio" name="preview184">\( \lim_{h\rightarrow 0}- \frac{\left(h - x\right)^{2} + \left(h + x\right)^{2}}{h} \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。"><input type="radio" name="preview184">\( \lim_{h\rightarrow 0}- \frac{x^{2} + \left(h + x\right)^{2}}{h} \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。"><input type="radio" name="preview184">\( \lim_{h\rightarrow 0}- 4 x \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。分母が欠けていることがわかります。"><input type="radio" name="preview184">\( \lim_{h\rightarrow 0}x^{2} - \left(h + x\right)^{2} \)</li><li title="点数:100"><input type="radio" name="preview184">\( \lim_{h\rightarrow 0}- h - 2 x \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を定義に基づき極限計算により求める際に，表れる途中式を選択してください。<br />\( f(x)=\tan{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:029）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。"><input type="radio" name="preview29">\( \lim_{h\rightarrow 0}\frac{- \tan{\left(h - x \right)} + \tan{\left(h + x \right)}}{h} \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。"><input type="radio" name="preview29">\( \lim_{h\rightarrow 0}\frac{\tan{\left(x \right)} + \tan{\left(h + x \right)}}{h} \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。分母が欠けていることがわかります。"><input type="radio" name="preview29">\( \lim_{h\rightarrow 0}- \tan{\left(x \right)} + \tan{\left(h + x \right)} \)</li><li title="点数:100"><input type="radio" name="preview29">\( \lim_{h\rightarrow 0}\frac{- \tan{\left(x \right)} + \tan{\left(h + x \right)}}{h} \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。"><input type="radio" name="preview29">\( \lim_{h\rightarrow 0}\frac{\tan{\left(h - x \right)} + \tan{\left(h + x \right)}}{h} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を定義に基づき極限計算により求める際に，表れる途中式を選択してください。<br />\( f(x)=\frac{2 x + 2}{4 x + 2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:197）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。"><input type="radio" name="preview197">\( \lim_{h\rightarrow 0}\frac{\left(x + 1\right) \left(2 h + 2 x + 1\right) + \left(2 x + 1\right) \left(h + x + 1\right)}{h \left(2 x + 1\right) \left(2 h + 2 x + 1\right)} \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。分母が欠けていることがわかります。"><input type="radio" name="preview197">\( \lim_{h\rightarrow 0}- \frac{h}{4 h x + 2 h + 4 x^{2} + 4 x + 1} \)</li><li title="点数:100"><input type="radio" name="preview197">\( \lim_{h\rightarrow 0}- \frac{1}{4 h x + 2 h + 4 x^{2} + 4 x + 1} \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。分母が欠けていることがわかります。"><input type="radio" name="preview197">\( \lim_{h\rightarrow 0}\frac{\left(x + 1\right) \left(2 h + 2 x + 1\right) + \left(2 x + 1\right) \left(h + x + 1\right)}{\left(2 x + 1\right) \left(2 h + 2 x + 1\right)} \)</li><li title="点数:0
# フィードバック:導関数を定義に基づき求める立式を行ってください。一部の符号に誤りがあることがわかります。"><input type="radio" name="preview197">\( \lim_{h\rightarrow 0}\frac{2 \left(- 2 h^{2} + 2 x^{2} + 3 x + 1\right)}{h \left(- 4 h^{2} + 4 x^{2} + 4 x + 1\right)} \)</li></ol></div></div>

# %%
if __name__ == "__main__":
    pass
    #qz.save('derivative_by_definition.xml')

# %% [markdown]
# ## DifferentiableFunction class for the following quizzes

# %%
class DifferentiableFunction():
    _const = sympy.Symbol('c') # non-zero integer
    _base = sympy.Symbol('a') # non-one positive integer
    _n = sympy.Symbol('n') # positive integer
    _x = sympy.Symbol('x')
    # in sympy, there is no way to represent log_a(x) without expanding.....
    # format: [f, df, incorrect dfs]
    _function_types = ['constant', 'monomial', 'sine', 'cosine', 'tangent', 
                       'natural_exponent', 'general_exponent', 'natural_logarithm']
    _function_defs = dict()
    _function_defs['constant'] = [_const, 0, [_const, 1]]
    _function_defs['monomial'] = [_x**_n, _n*_x**(_n-1), [_x**_n, _n*_x**_n, (_n-1)*_x**(_n-1)]]
    _function_defs['sine'] = [sympy.sin(_x), sympy.cos(_x), [sympy.sin(_x), -sympy.cos(_x)]]
    _function_defs['cosine'] = [sympy.cos(_x), -sympy.sin(_x), [sympy.cos(_x), sympy.sin(_x)]]
    _function_defs['tangent'] = [sympy.tan(_x), 1/sympy.cos(_x)**2, [sympy.tan(_x), 1/sympy.cos(_x), 1/sympy.sin(_x)**2]]
    _function_defs['natural_exponent'] = [sympy.exp(_x), sympy.exp(_x), [sympy.exp(_x-1)]]
    _function_defs['general_exponent'] = [_base**_x, sympy.log(_base)*_base**_x, [_base**_x, _base**(_x-1)]]
    _function_defs['natural_logarithm'] = [sympy.log(abs(_x)), 1/_x, [sympy.log(abs(_x))]]
    # func = logarithmic | linearity_all
    # logarithmic = linearity_mono**linearity_mono
    # linearity_all = [linearity_mono]+
    # linearity_mono = scalar*multi | scalar*quot | scalar*composite | scalar*elemental_func
    # composite|multi*quot = linearity @@ linearity
    # linearity = elemental_func | elemental_func + constant
    _expression_types = ['exponential', 'summation', 'scalar', 'composition', 'multiplication', 'quotient']
    _incorrect_reasons = ['formula', 'sign', 'composition', 'scalar', 'part']
    def __init__(self, emin=-3, emax=3, nmin=1, nmax=3, lrate=0, lmin=1, lmax=2, crate=0.5, mrate=0.3, qrate=0.3, srate=0.25, inclog=True):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 生成する次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 対数微分法を最後に付与する確率
        self.logarithmic_ratio = lrate
        # 線形性に表れる関数の個数
        self.linearity_min = lmin
        self.linearity_max = lmax
        # それぞれの合成関数の確率
        self.composite_ratio = crate
        # それぞれの積の微分法の確率
        self.multiplication_ratio = mrate
        # それぞれの商の微分法の確率
        self.quotient_ratio = qrate
        # 定数項の確率
        self.constant_term_ratio = srate
        # 対数関数を選択肢に入れるか
        if not inclog:
            self._function_types = self._function_types[:-1]
        # internals
        self.function = 0
    # func = logarithmic | linearity_all
    # logarithmic = linearity_mono**linearity_mono
    def generate_function(self):
        if random.random() < self.logarithmic_ratio:
            _funcE = self._generate_linearity_mono()
            _funcB = self._generate_linearity_mono()
            _func = ['exponential', _funcB, _funcE]
        else:
            _func = self._generate_linearity_all()
        self.function = _func
    # linearity_all = [linearity_mono]+
    def _generate_linearity_all(self):
        _n = random.randint(self.linearity_min, self.linearity_max)
        _func1 = self._generate_linearity_mono()
        if _n == 1:
            return _func1
        _func = ['summation', _func1]
        for _i in range(_n-1):
            _func.append(self._generate_linearity_mono())
        return _func
    # linearity_mono = scalar*multi | scalar*quot | scalar*composite | scalar*elemental_func
    def _generate_linearity_mono(self):
        _scalar = nonzero_randint(self.elem_min, self.elem_max)
        if random.random() < self.multiplication_ratio:
            _types = random.sample(self._function_types[1:], 2)
            _func = ['scalar', _scalar, self._generate_multiplication(_types)]
        elif random.random() < self.quotient_ratio:
            _types = random.sample(self._function_types[1:], 2)
            _func = ['scalar', _scalar, self._generate_quotient(_types)]
        elif random.random() < self.composite_ratio:
            _types = random.sample(self._function_types[1:], 2)
            _func = ['scalar', _scalar, self._generate_composition(_types)]
        else:
            _func = ['scalar', _scalar, self._generate_elemental_func()]
        return _func
    # composite|multi*quot = linearity @@ linearity
    def _generate_composition(self, _types):
        _func1 = self._generate_linearity(_types[0])
        _func2 = self._generate_linearity(_types[1])
        return ['composition', _func1, _func2]
    def _generate_multiplication(self, _types):
        _func1 = self._generate_linearity(_types[0])
        _func2 = self._generate_linearity(_types[1])
        return ['multiplication', _func1, _func2]
    def _generate_quotient(self, _types):
        _func1 = self._generate_linearity(_types[0])
        _func2 = self._generate_linearity(_types[1])
        return ['quotient', _func1, _func2]
    # linearity = elemental_func | elemental_func + constant
    def _generate_linearity(self, _type):
        _scalar = nonzero_randint(self.elem_min, self.elem_max)
        _func1 = ['scalar', _scalar, self._generate_elemental_func(_type)]
        if random.random() >= self.constant_term_ratio:
            return _func1
        else:
            _func = ['summation', _func1]
            _func.append(self._generate_elemental_func('constant'))
        return _func
    def _mysubs(self, target, var, repl):
        if sympy.sympify(target).is_real:
            return target
        elif len(var) == 1:
            return target.subs(var[0], repl[0])
        else:
            return self._mysubs(target.subs(var[0], repl[0]), var[1:], repl[1:])
    def _generate_elemental_func(self, _type=None):
        if _type is None:
            _type = random.choice(self._function_types[1:])
        _vars = [self._const, self._base, self._n]
        _repl = [nonzero_randint(self.elem_min, self.elem_max), 
                 nonone_randpint(self.elem_min, self.elem_max),
                 abs(nonzero_randint(self.deg_min, self.deg_max))]
        _func = self._function_defs[_type]
        _func = [self._mysubs(_func[0], _vars, _repl), 
                 self._mysubs(_func[1], _vars, _repl), 
                [self._mysubs(_f, _vars, _repl) for _f in _func[2]]]
        return _func
    def _get_function(self, _func):
        _recursive_call = self._get_function
        # ['exponential', 'summation', 'scalar', 'composition', 'multiplication', 'quotient']  
        if _func[0] == 'exponential':
            return _recursive_call(_func[1]) ** _recursive_call(_func[2])
        elif _func[0] == 'summation':
            _summand = 0
            for _f in _func[1:]:
                _summand = _summand + _recursive_call(_f)
            return _summand
        elif _func[0] == 'scalar':
            return _func[1] * _recursive_call(_func[2])
        elif _func[0] == 'composition':
            return _recursive_call(_func[1]).subs(self._x, _recursive_call(_func[2]))
        elif _func[0] == 'multiplication':
            return _recursive_call(_func[1]) * _recursive_call(_func[2])
        elif _func[0] == 'quotient':
            return _recursive_call(_func[1]) / _recursive_call(_func[2])
        else:
            return _func[0]
    def get_function(self):
        if self.function == 0:
            self.generate_function()
        return self._get_function(self.function)
    def _get_derivative(self, _func):
        _recursive_call = self._get_derivative
        # ['exponential', 'summation', 'scalar', 'composition', 'multiplication', 'quotient']  
        if _func[0] == 'exponential':
            _rest = ['multiplication', _func[2], ['composition', [sympy.log(self._x), 1/self._x, [sympy.log(self._x)]], _func[1]]]
            return (self._get_function(_func[1]) ** self._get_function(_func[2])) * _recursive_call(_rest)
        elif _func[0] == 'summation':
            _summand = 0
            for _f in _func[1:]:
                _summand = _summand + _recursive_call(_f)
            return _summand
        elif _func[0] == 'scalar':
            return _func[1] * _recursive_call(_func[2])
        elif _func[0] == 'composition':
            return _recursive_call(_func[2]) * self._mysubs(_recursive_call(_func[1]), [self._x], [self._get_function(_func[2])])
        elif _func[0] == 'multiplication':
            return _recursive_call(_func[1]) * self._get_function(_func[2]) + self._get_function(_func[1]) * _recursive_call(_func[2])
        elif _func[0] == 'quotient':
            return (_recursive_call(_func[1]) * self._get_function(_func[2]) - self._get_function(_func[1]) * _recursive_call(_func[2]))/(self._get_function(_func[2])**2)
        else:
            return _func[1]
    def get_derivative(self):
        if self.function == 0:
            self.generate_function()
#        display(sympy.diff(self.get_function(),self._x))
#        display(sympy.simplify(self._get_derivative(self.function) - sympy.diff(self.get_function(),self._x)))
        return self._get_derivative(self.function)
    def get_higher_derivative(self, n=1):
        if self.function == 0:
            self.generate_function()
        if n <= 0:
            return self.get_function()
        else:
            _df = self.get_derivative()
            return sympy.diff(_df, self._x, n-1)        
    def _get_incorrect_derivatives_by_formula(self, _func):
        _recursive_call = self._get_incorrect_derivatives_by_formula
        # ['exponential', 'summation', 'scalar', 'composition', 'multiplication', 'quotient']  
        if _func[0] == 'exponential':
            _rest = ['multiplication', _func[2], ['composition', [sympy.log(self._x), 1/self._x, [sympy.log(self._x)]], _func[1]]]
            return [(self._get_function(_func[1]) ** self._get_function(_func[2])) * _f for _f in _recursive_call(_rest)]
        elif _func[0] == 'summation':
            _summand = [0]
            for _f in _func[1:]:
                _dfs = _recursive_call(_f)
                _new_summand = []
                for _df in _dfs:
                    _new_summand = _new_summand + [ _s + _df for _s in _summand]
                _summand = _new_summand
            return _summand
        elif _func[0] == 'scalar':
            return [_func[1] * _f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append(_df2 * self._mysubs(_df1, [self._x], [self._get_function(_func[2])]))
            return _funcs
        elif _func[0] == 'multiplication':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append(_df1 * self._get_function(_func[2]) + self._get_function(_func[1]) * _df2)
            return _funcs
        elif _func[0] == 'quotient':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append((_df1 * self._get_function(_func[2]) - self._get_function(_func[1]) * _df2)/(self._get_function(_func[2])**2))
            return _funcs
        else:
            return _func[2]
    def _get_incorrect_derivatives_by_sign(self, _func):
        _recursive_call = self._get_incorrect_derivatives_by_sign
        # ['exponential', 'summation', 'scalar', 'composition', 'multiplication', 'quotient']  
        if _func[0] == 'exponential':
            _rest = ['multiplication', _func[2], ['composition', [sympy.log(self._x), 1/self._x, [sympy.log(self._x)]], _func[1]]]
            return [(self._get_function(_func[1]) ** self._get_function(_func[2])) * _f for _f in _recursive_call(_rest)]
        elif _func[0] == 'summation':
            _summand = [0]
            for _f in _func[1:]:
                _dfs = _recursive_call(_f)
                _new_summand = []
                for _df in _dfs:
                    _new_summand = _new_summand + [ _s + _df for _s in _summand]
                _summand = _new_summand
            return _summand
        elif _func[0] == 'scalar':
            return [_func[1] * _f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append(_df2 * self._mysubs(_df1, [self._x], [self._get_function(_func[2])]))
            return _funcs
        elif _func[0] == 'multiplication':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append(_df1 * self._get_function(_func[2]) - self._get_function(_func[1]) * _df2)
            return _funcs
        elif _func[0] == 'quotient':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append((_df1 * self._get_function(_func[2]) + self._get_function(_func[1]) * _df2)/(self._get_function(_func[2])**2))
            return _funcs
        else:
            return [_func[1]]
    def _get_incorrect_derivatives_by_composition(self, _func):
        _recursive_call = self._get_incorrect_derivatives_by_composition
        # ['exponential', 'summation', 'scalar', 'composition', 'multiplication', 'quotient']  
        if _func[0] == 'exponential':
            _rest = ['multiplication', _func[2], ['composition', [sympy.log(self._x), 1/self._x, [sympy.log(self._x)]], _func[1]]]
            return [(self._get_function(_func[1]) ** self._get_function(_func[2])) * _f for _f in _recursive_call(_rest)]
        elif _func[0] == 'summation':
            _summand = [0]
            for _f in _func[1:]:
                _dfs = _recursive_call(_f)
                _new_summand = []
                for _df in _dfs:
                    _new_summand = _new_summand + [ _s + _df for _s in _summand]
                _summand = _new_summand
            return _summand
        elif _func[0] == 'scalar':
            return [_func[1] * _f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                _funcs.append(_df1 )
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append(_df2 )
                    _funcs.append(_df1 * self._mysubs(_df2, [self._x], [self._get_function(_func[2])]))
            return _funcs
        elif _func[0] == 'multiplication':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append(_df1 * self._get_function(_func[2]) + self._get_function(_func[1]) * _df2)
            return _funcs
        elif _func[0] == 'quotient':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append((_df1 * self._get_function(_func[2]) - self._get_function(_func[1]) * _df2)/(self._get_function(_func[2])**2))
            return _funcs
        else:
            return [_func[1]]
    def _get_incorrect_derivatives_by_scalar(self, _func):
        _recursive_call = self._get_incorrect_derivatives_by_scalar
        # ['exponential', 'summation', 'scalar', 'composition', 'multiplication', 'quotient']  
        if _func[0] == 'exponential':
            _rest = ['multiplication', _func[2], ['composition', [sympy.log(self._x), 1/self._x, [sympy.log(self._x)]], _func[1]]]
            return [(self._get_function(_func[1]) ** self._get_function(_func[2])) * _f for _f in _recursive_call(_rest)]
        elif _func[0] == 'summation':
            _summand = [0]
            for _f in _func[1:]:
                _dfs = _recursive_call(_f)
                _new_summand = []
                for _df in _dfs:
                    _new_summand = _new_summand + [ _s + _df for _s in _summand]
                _summand = _new_summand
            return _summand
        elif _func[0] == 'scalar':
            return [_f for _f in _recursive_call(_func[2])] + [-_f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append(_df2 * self._mysubs(_df1, [self._x], [self._get_function(_func[2])]))
            return _funcs
        elif _func[0] == 'multiplication':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append(_df1 * self._get_function(_func[2]) + self._get_function(_func[1]) * _df2)
            return _funcs
        elif _func[0] == 'quotient':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append((_df1 * self._get_function(_func[2]) - self._get_function(_func[1]) * _df2)/(self._get_function(_func[2])**2))
            return _funcs
        else:
            return [_func[1]]
    def _get_incorrect_derivatives_by_part(self, _func):
        _recursive_call = self._get_incorrect_derivatives_by_part
        # ['exponential', 'summation', 'scalar', 'composition', 'multiplication', 'quotient']  
        if _func[0] == 'exponential':
            _rest = ['multiplication', _func[2], ['composition', [sympy.log(self._x), 1/self._x, [sympy.log(self._x)]], _func[1]]]
            return [(self._get_function(_func[1]) ** self._get_function(_func[2])) * _f for _f in _recursive_call(_rest)]
        elif _func[0] == 'summation':
            _funcs = []
            for _f in _func[1:]:
                _funcs = _funcs + _recursive_call(_f)
            return _funcs
        elif _func[0] == 'scalar':
            return [_func[1] * _f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append(_df2 * self._mysubs(_df1, [self._x], [self._get_function(_func[2])]))
            return _funcs
        elif _func[0] == 'multiplication':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append(_df1 * self._get_function(_func[2]) + self._get_function(_func[1]) * _df2)
            return _funcs
        elif _func[0] == 'quotient':
            _funcs = []
            for _df1 in _recursive_call(_func[1]):
                for _df2 in _recursive_call(_func[2]):
                    _funcs.append((_df1 * self._get_function(_func[2]) - self._get_function(_func[1]) * _df2)/(self._get_function(_func[2])**2))
            return _funcs
        else:
            return [_func[1]]
    def _not_same_check(self, value):
        if not value.is_real:
            return False
        if value > 1.0e-4:
            return True
        return False
    def _incorrect_derivarives_only(self, _dfs):
        _funcs = []
        _correct_df = self.get_derivative()
        _correct_df0 = self._mysubs(_correct_df, [self._x], [0])
        _correct_df1 = self._mysubs(_correct_df, [self._x], [1])
        _correct_df2 = self._mysubs(_correct_df, [self._x], [2])
        for _df in _dfs:
            if _df in _funcs:
                continue
            if self._not_same_check(abs(sympy.N(_correct_df0 - self._mysubs(_df, [self._x], [0])))):
                _funcs.append(_df)
            elif self._not_same_check(abs(sympy.N(_correct_df1 - self._mysubs(_df, [self._x], [1])))):
                _funcs.append(_df)
            elif self._not_same_check(abs(sympy.N(_correct_df2 - self._mysubs(_df, [self._x], [2])))):
                _funcs.append(_df)
        return _funcs
    def get_incorrect_derivatives(self, _type=None):
        if self.function == 0:
            self.generate_function()
        if _type is None:
            _type = random.choice(self._incorrect_reasons)
        if _type == 'formula':
            _dfs = self._get_incorrect_derivatives_by_formula(self.function)
        elif _type == 'sign':
            _dfs = self._get_incorrect_derivatives_by_sign(self.function)
        elif _type == 'composition':
            _dfs = self._get_incorrect_derivatives_by_composition(self.function)
        elif _type == 'scalar':
            _dfs = self._get_incorrect_derivatives_by_scalar(self.function)
        elif _type == 'part':
            _dfs = self._get_incorrect_derivatives_by_part(self.function)
        return self._incorrect_derivarives_only(_dfs)
    def _incorrect_higher_derivarives_only(self, _dfs, n):
        _funcs = []
        _correct_df = self.get_higher_derivative(n)
        _correct_df0 = self._mysubs(_correct_df, [self._x], [0])
        _correct_df1 = self._mysubs(_correct_df, [self._x], [1])
        _correct_df2 = self._mysubs(_correct_df, [self._x], [2])
        for _df in _dfs:
            if _df in _funcs:
                continue
            if self._not_same_check(abs(sympy.N(_correct_df0 - self._mysubs(_df, [self._x], [0])))):
                _funcs.append(_df)
            elif self._not_same_check(abs(sympy.N(_correct_df1 - self._mysubs(_df, [self._x], [1])))):
                _funcs.append(_df)
            elif self._not_same_check(abs(sympy.N(_correct_df2 - self._mysubs(_df, [self._x], [2])))):
                _funcs.append(_df)
        return _funcs
    def get_incorrect_higher_derivatives(self, n=1, _type=None):
        if self.function == 0:
            self.generate_function()
        if _type is None:
            _type = random.choice(self._incorrect_reasons + ['degree'])
        if _type == 'formula':
            _dfs = self._get_incorrect_derivatives_by_formula(self.function)
        elif _type == 'sign':
            _dfs = self._get_incorrect_derivatives_by_sign(self.function)
        elif _type == 'composition':
            _dfs = self._get_incorrect_derivatives_by_composition(self.function)
        elif _type == 'scalar':
            _dfs = self._get_incorrect_derivatives_by_scalar(self.function)
        elif _type == 'part':
            _dfs = self._get_incorrect_derivatives_by_part(self.function)
        elif _type == 'degree':
            _dfs = [self.get_higher_derivative(_n) for _n in list(set(range(0,n+2))-set([n]))]
        return self._incorrect_higher_derivarives_only(_dfs, n)

# %%
if __name__ == "__main__":
    df = DifferentiableFunction()
    df.generate_function()
    display(df.get_function())
    display(df.get_derivative())
    display(df.get_higher_derivative(2))
    display(df.get_incorrect_higher_derivatives(2, 'degree'))
# Out:
# 2*(-3*tan(x) - 2)*sin(x) + 3*exp(-x)*cos(x)
# -(9*exp(x)*sin(x) + 9*exp(x)*cos(x))*exp(-2*x)/3 + 2*(-3*tan(x) - 2)*cos(x) - 6*sin(x)/cos(x)**2
# -2*(-3*exp(x)*sin(x) - 3*exp(x)*cos(x))*exp(-2*x) - (-6*tan(x) - 4)*sin(x) + (-6*tan(x)**2 - 6)*cos(x) - 12*sin(x)**2/cos(x)**3 - 6/cos(x) - 6*exp(-x)*cos(x)
# [2*(-3*tan(x) - 2)*sin(x) + 3*exp(-x)*cos(x),
#  -(9*exp(x)*sin(x) + 9*exp(x)*cos(x))*exp(-2*x)/3 + 2*(-3*tan(x) - 2)*cos(x) - 6*sin(x)/cos(x)**2,
#  2*(-6*(sin(x) + cos(x))*exp(-x) + (3*tan(x) + 2)*cos(x) + 6*(tan(x)**2 + 1)*sin(x) - 6*(tan(x)**2 + 1)*cos(x)*tan(x) - 18*sin(x)**3/cos(x)**4 - 15*sin(x)/cos(x)**2 + 3*exp(-x)*sin(x) + 9*exp(-x)*cos(x))]

# %% [markdown]
# ## derivative by linearity

# %%
class derivative_by_linearity(core.Question):
    name = '線形性に基づく導関数の計算（基本公式と線形性の活用）'
    def __init__(self, emin=-3, emax=3, nmin=1, nmax=3, lmin=2, lmax=3):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 生成する次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 生成する関数の和の範囲
        self.func_min = lmin
        self.func_max = lmax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='線形性に基づく導関数の計算', quiz_number=_quiz_number)
        df = DifferentiableFunction(emin=self.elem_min, emax=self.elem_max, nmin=self.deg_min, nmax=self.deg_max, 
                                   lrate=0, lmin=self.func_min, lmax=self.func_max, crate=0, mrate=0, qrate=0, srate=0)
        _func = df.get_function()
        quiz.quiz_identifier = hash(str(_func))
        # 正答の選択肢の生成
        _df = df.get_derivative()
        quiz.data = [_func, _df, df]
        ans = { 'fraction': 100, 'data': _df }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_func, _df, df] = quiz.data
        ans['feedback'] = r'基本的な関数の導関数の公式を確認してください。'
        for _incorrect in df.get_incorrect_derivatives('formula'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        ans['feedback'] = r'導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。'
        for _incorrect in df.get_incorrect_derivatives('scalar'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        for _incorrect in df.get_incorrect_derivatives('part'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_func, _df, df] = quiz.data
        _text = r'次の関数\( f(x) \)の導関数を選択してください。'
        _text += r'<br />\( f(x)=' + sympy.latex(_func, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = derivative_by_linearity()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 5 \cdot 3^{x} + \sin{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:171）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview171">\( - 5 \cdot 3^{x} \log{\left(3 \right)} + \cos{\left(x \right)} \)</li><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview171">\( - 2 \cdot 3^{x} \log{\left(3 \right)} + \cos{\left(x \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview171">\( - 2 \cdot 3^{x} - 3 \cdot 3^{x - 1} + \sin{\left(x \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview171">\( - 5 \cdot 3^{x} - \cos{\left(x \right)} \)</li><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview171">\( \cos{\left(x \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 4 \sin{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:121）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview121">\( - 2 \cos{\left(x \right)} \)</li><li title="点数:100"><input type="radio" name="preview121">\( - 4 \cos{\left(x \right)} \)</li><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview121">\( 0 \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview121">\( - 2 \sin{\left(x \right)} + 2 \cos{\left(x \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview121">\( - 4 \sin{\left(x \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=3 \cdot 2^{x} - 2 \cos{\left(x \right)} + \tan{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:153）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview153">\( - 2^{x} \log{\left(2 \right)} - \sin{\left(x \right)} - \frac{1}{\cos^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview153">\( 3 \cdot 2^{x} - 2 \sin{\left(x \right)} + \frac{1}{\cos{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview153">\( \frac{1}{\cos^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview153">\( 3 \cdot 2^{x - 1} - 2 \sin{\left(x \right)} + \tan{\left(x \right)} \)</li><li title="点数:100"><input type="radio" name="preview153">\( 3 \cdot 2^{x} \log{\left(2 \right)} + 2 \sin{\left(x \right)} + \frac{1}{\cos^{2}{\left(x \right)}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=e^{x} - 2 \log{\left(\left|{x}\right| \right)} + 3 \sin{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:166）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview166">\( e^{x - 1} - 2 \log{\left(\left|{x}\right| \right)} - 3 \cos{\left(x \right)} \)</li><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview166">\( e^{x} + \cos{\left(x \right)} + \frac{1}{x} \)</li><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview166">\( e^{x} - \cos{\left(x \right)} + \frac{1}{x} \)</li><li title="点数:100"><input type="radio" name="preview166">\( e^{x} + 3 \cos{\left(x \right)} - \frac{2}{x} \)</li><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview166">\( 3 \cos{\left(x \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 3 x + \sin{\left(x \right)} + 2 \cos{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:173）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview173">\( \cos{\left(x \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview173">\( \sin{\left(x \right)} + 2 \cos{\left(x \right)} \)</li><li title="点数:100"><input type="radio" name="preview173">\( - 2 \sin{\left(x \right)} + \cos{\left(x \right)} - 3 \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview173">\( - 3 x + \cos{\left(x \right)} \)</li><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview173">\( \sin{\left(x \right)} - \cos{\left(x \right)} + 1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=x^{2} - 3 \cos{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:101）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview101">\( - 2 x + \sin{\left(x \right)} \)</li><li title="点数:100"><input type="radio" name="preview101">\( 2 x + 3 \sin{\left(x \right)} \)</li><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview101">\( 2 x + \sin{\left(x \right)} \)</li><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview101">\( 3 \sin{\left(x \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview101">\( 2 x^{2} - 3 \sin{\left(x \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- \log{\left(\left|{x}\right| \right)} - 3 \sin{\left(x \right)} - 2 \tan{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:154）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview154">\( - \cos{\left(x \right)} + \frac{1}{\cos^{2}{\left(x \right)}} + \frac{1}{x} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview154">\( - \log{\left(\left|{x}\right| \right)} + 3 \cos{\left(x \right)} - 2 \tan{\left(x \right)} \)</li><li title="点数:100"><input type="radio" name="preview154">\( - 3 \cos{\left(x \right)} - \frac{2}{\cos^{2}{\left(x \right)}} - \frac{1}{x} \)</li><li title="点数:0
# フィードバック:導関数の線形性に基づいて計算してください。定数倍や加減算を忘れている可能性があります。"><input type="radio" name="preview154">\( - \cos{\left(x \right)} + \frac{1}{\cos^{2}{\left(x \right)}} - \frac{1}{x} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview154">\( - \log{\left(\left|{x}\right| \right)} - 3 \sin{\left(x \right)} - \frac{2}{\cos{\left(x \right)}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\(

# %%
if __name__ == "__main__":
    pass
    #qz.save('derivative_by_linearity.xml')

# %% [markdown]
# ## derivative by multiplication

# %%
class derivative_by_multiplication(core.Question):
    name = '積の微分法に基づく導関数の計算（基本公式と積の微分法の活用）'
    def __init__(self, emin=-3, emax=3, nmin=1, nmax=3, lmin=1, lmax=1):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 生成する次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 生成する関数の和の範囲
        self.func_min = lmin
        self.func_max = lmax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='積の微分法に基づく導関数の計算', quiz_number=_quiz_number)
        df = DifferentiableFunction(emin=self.elem_min, emax=self.elem_max, nmin=self.deg_min, nmax=self.deg_max, 
                                   lrate=0, lmin=self.func_min, lmax=self.func_max, crate=0, mrate=1, qrate=0, srate=0)
        _func = df.get_function()
        quiz.quiz_identifier = hash(str(_func))
        # 正答の選択肢の生成
        _df = df.get_derivative()
        quiz.data = [_func, _df, df]
        ans = { 'fraction': 100, 'data': _df }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_func, _df, df] = quiz.data
        ans['feedback'] = r'基本的な関数の導関数の公式を確認してください。'
        for _incorrect in df.get_incorrect_derivatives('formula'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        ans['feedback'] = r'導関数の線形性に基づいて計算してください。加減算を忘れている可能性があります。'
        for _incorrect in df.get_incorrect_derivatives('part'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        ans['feedback'] = r'積の微分法を確認しましょう。符号を間違えている可能性があります。'
        for _incorrect in df.get_incorrect_derivatives('sign'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_func, _df, df] = quiz.data
        _text = r'次の関数\( f(x) \)の導関数を選択してください。'
        _text += r'<br />\( f(x)=' + sympy.latex(_func, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = derivative_by_multiplication()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 18 \cos{\left(x \right)} \tan{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:152）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview152">\( - 36 \cos{\left(x \right)} \tan{\left(x \right)} \)</li><li title="点数:100"><input type="radio" name="preview152">\( 18 \sin{\left(x \right)} \tan{\left(x \right)} - \frac{18}{\cos{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview152">\( - 18 \cos{\left(x \right)} \tan{\left(x \right)} - 18 \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview152">\( - 18 \cos{\left(x \right)} \tan{\left(x \right)} - \frac{18 \cos{\left(x \right)}}{\sin^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview152">\( - 18 \sin{\left(x \right)} \tan{\left(x \right)} - 18 \cos{\left(x \right)} \tan{\left(x \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 12 x \tan{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:042）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview42">\( - 24 x \tan{\left(x \right)} \)</li><li title="点数:100"><input type="radio" name="preview42">\( - \frac{12 x}{\cos^{2}{\left(x \right)}} - 12 \tan{\left(x \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview42">\( - \frac{12 x}{\sin^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview42">\( - \frac{12 x}{\cos{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview42">\( - 12 x \tan{\left(x \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 2 x^{2} \log{\left(\left|{x}\right| \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:034）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview34">\( - 4 x^{2} \log{\left(\left|{x}\right| \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview34">\( - 6 x^{2} \log{\left(\left|{x}\right| \right)} \)</li><li title="点数:0
# フィードバック:積の微分法を確認しましょう。符号を間違えている可能性があります。"><input type="radio" name="preview34">\( - 4 x \log{\left(\left|{x}\right| \right)} + 2 x \)</li><li title="点数:100"><input type="radio" name="preview34">\( - 4 x \log{\left(\left|{x}\right| \right)} - 2 x \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview34">\( - 2 x^{2} \log{\left(\left|{x}\right| \right)} - 2 x \log{\left(\left|{x}\right| \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 6 x^{3} \tan{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:060）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview60">\( - 6 x^{3} \tan{\left(x \right)} - \frac{6 x^{3}}{\cos{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview60">\( - 12 x^{3} \tan{\left(x \right)} \)</li><li title="点数:100"><input type="radio" name="preview60">\( - \frac{6 x^{3}}{\cos^{2}{\left(x \right)}} - 18 x^{2} \tan{\left(x \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview60">\( - 6 x^{3} \tan{\left(x \right)} - \frac{6 x^{3}}{\sin^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:積の微分法を確認しましょう。符号を間違えている可能性があります。"><input type="radio" name="preview60">\( \frac{6 x^{3}}{\cos^{2}{\left(x \right)}} - 18 x^{2} \tan{\left(x \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 3 \cdot 3^{x} \tan{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:187）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview187">\( - 3 \cdot 3^{x} \tan{\left(x \right)} - 3 \cdot 3^{x - 1} \tan{\left(x \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview187">\( - \frac{3 \cdot 3^{x}}{\sin^{2}{\left(x \right)}} - 3 \cdot 3^{x - 1} \tan{\left(x \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview187">\( - 6 \cdot 3^{x} \tan{\left(x \right)} \)</li><li title="点数:100"><input type="radio" name="preview187">\( - 3 \cdot 3^{x} \log{\left(3 \right)} \tan{\left(x \right)} - \frac{3 \cdot 3^{x}}{\cos^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview187">\( - 3 \cdot 3^{x} \tan{\left(x \right)} - \frac{3 \cdot 3^{x}}{\cos{\left(x \right)}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 3 \cdot 2^{x} e^{x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:162）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview162">\( - 3 \cdot 2^{x} e^{x} - 3 \cdot 2^{x} e^{x - 1} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview162">\( - 3 \cdot 2^{x} e^{x - 1} - 3 \cdot 2^{x - 1} e^{x} \)</li><li title="点数:100"><input type="radio" name="preview162">\( - 3 \cdot 2^{x} e^{x} - 3 \cdot 2^{x} e^{x} \log{\left(2 \right)} \)</li><li title="点数:0
# フィードバック:積の微分法を確認しましょう。符号を間違えている可能性があります。"><input type="radio" name="preview162">\( - 3 \cdot 2^{x} e^{x} \log{\left(2 \right)} + 3 \cdot 2^{x} e^{x} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=12 \cdot 3^{x} x^{3} \)<div style="text-align:right;font-size:smaller">（問題整理番号:076）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview76">\( 48 \cdot 3^{x} x^{3} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview76">\( 12 \cdot 3^{x} x^{3} + 12 \cdot 3^{x - 1} x^{3} \)</li><li title="点数:100"><input type="radio" name="preview76">\( 12 \cdot 3^{x} x^{3} \log{\left(3 \right)} + 36 \cdot 3^{x} x^{2} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview76">\( 12 \cdot 3^{x} x^{3} + 24 \cdot 3^{x} x^{2} \)</li><li title="点数:0
# フィードバック:積の微分法を確認しましょう。符号を間違えている可能性があります。"><input type="radio" name="preview76">\( - 12 \cdot 3^{x} x^{3} \log{\left(3 \right)} + 36 \cdot 3^{x} x^{2} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=12 e^{x} \tan{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:123）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してくださ

# %%
if __name__ == "__main__":
    pass
    #qz.save('derivative_by_multiplication.xml')

# %% [markdown]
# ## derivative by quotient

# %%
class derivative_by_quotient(core.Question):
    name = '商の微分法に基づく導関数の計算（基本公式と商の微分法の活用）'
    def __init__(self, emin=-3, emax=3, nmin=1, nmax=3, lmin=1, lmax=1):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 生成する次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 生成する関数の和の範囲
        self.func_min = lmin
        self.func_max = lmax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='商の微分法に基づく導関数の計算', quiz_number=_quiz_number)
        df = DifferentiableFunction(emin=self.elem_min, emax=self.elem_max, nmin=self.deg_min, nmax=self.deg_max, 
                                   lrate=0, lmin=self.func_min, lmax=self.func_max, crate=0, mrate=0, qrate=1, srate=0)
        _func = df.get_function()
        quiz.quiz_identifier = hash(str(_func))
        # 正答の選択肢の生成
        _df = df.get_derivative()
        quiz.data = [_func, _df, df]
        ans = { 'fraction': 100, 'data': _df }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_func, _df, df] = quiz.data
        ans['feedback'] = r'基本的な関数の導関数の公式を確認してください。'
        for _incorrect in df.get_incorrect_derivatives('formula'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        ans['feedback'] = r'導関数の線形性に基づいて計算してください。加減算を忘れている可能性があります。'
        for _incorrect in df.get_incorrect_derivatives('part'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        ans['feedback'] = r'商の微分法を確認しましょう。符号を間違えている可能性があります。'
        for _incorrect in df.get_incorrect_derivatives('sign'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_func, _df, df] = quiz.data
        _text = r'次の関数\( f(x) \)の導関数を選択してください。'
        _text += r'<br />\( f(x)=' + sympy.latex(_func, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = derivative_by_quotient()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=\frac{3 e^{x}}{\tan{\left(x \right)}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:010）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview10">\( \frac{3 \left(- e^{x} \tan{\left(x \right)} + e^{x - 1} \tan{\left(x \right)}\right)}{\tan^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview10">\( \frac{3 \left(- \frac{e^{x}}{\sin^{2}{\left(x \right)}} + e^{x - 1} \tan{\left(x \right)}\right)}{\tan^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:商の微分法を確認しましょう。符号を間違えている可能性があります。"><input type="radio" name="preview10">\( \frac{3 \left(e^{x} \tan{\left(x \right)} + \frac{e^{x}}{\cos^{2}{\left(x \right)}}\right)}{\tan^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview10">\( \frac{3 \left(- \frac{e^{x}}{\cos{\left(x \right)}} + e^{x - 1} \tan{\left(x \right)}\right)}{\tan^{2}{\left(x \right)}} \)</li><li title="点数:100"><input type="radio" name="preview10">\( \frac{3 \left(e^{x} \tan{\left(x \right)} - \frac{e^{x}}{\cos^{2}{\left(x \right)}}\right)}{\tan^{2}{\left(x \right)}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 3 \cdot 2^{- x} \log{\left(\left|{x}\right| \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:192）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:商の微分法を確認しましょう。符号を間違えている可能性があります。"><input type="radio" name="preview192">\( - \frac{2^{- 2 x} \left(9 \cdot 2^{x} \log{\left(2 \right)} \log{\left(\left|{x}\right| \right)} + \frac{9 \cdot 2^{x}}{x}\right)}{3} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview192">\( 0 \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview192">\( - \frac{2^{- 2 x} \left(9 \cdot 2^{x} \log{\left(\left|{x}\right| \right)} - 9 \cdot 2^{x - 1} \log{\left(\left|{x}\right| \right)}\right)}{3} \)</li><li title="点数:100"><input type="radio" name="preview192">\( - \frac{2^{- 2 x} \left(- 9 \cdot 2^{x} \log{\left(2 \right)} \log{\left(\left|{x}\right| \right)} + \frac{9 \cdot 2^{x}}{x}\right)}{3} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- \frac{3 \cdot 2^{x}}{2 \tan{\left(x \right)}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:018）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview18">\( - \frac{- \frac{6 \cdot 2^{x}}{\sin^{2}{\left(x \right)}} + 6 \cdot 2^{x - 1} \tan{\left(x \right)}}{4 \tan^{2}{\left(x \right)}} \)</li><li title="点数:100"><input type="radio" name="preview18">\( - \frac{6 \cdot 2^{x} \log{\left(2 \right)} \tan{\left(x \right)} - \frac{6 \cdot 2^{x}}{\cos^{2}{\left(x \right)}}}{4 \tan^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:商の微分法を確認しましょう。符号を間違えている可能性があります。"><input type="radio" name="preview18">\( - \frac{6 \cdot 2^{x} \log{\left(2 \right)} \tan{\left(x \right)} + \frac{6 \cdot 2^{x}}{\cos^{2}{\left(x \right)}}}{4 \tan^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview18">\( 0 \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview18">\( - \frac{6 \cdot 2^{x} \tan{\left(x \right)} - \frac{6 \cdot 2^{x}}{\sin^{2}{\left(x \right)}}}{4 \tan^{2}{\left(x \right)}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 2 e^{- x} \sin{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:040）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview40">\( - \left(- 2 e^{x} \sin{\left(x \right)} + 2 e^{x} \cos{\left(x \right)}\right) e^{- 2 x} \)</li><li title="点数:0
# フィードバック:商の微分法を確認しましょう。符号を間違えている可能性があります。"><input type="radio" name="preview40">\( - \left(2 e^{x} \sin{\left(x \right)} + 2 e^{x} \cos{\left(x \right)}\right) e^{- 2 x} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview40">\( - \left(- 2 e^{x} \cos{\left(x \right)} - 2 e^{x - 1} \sin{\left(x \right)}\right) e^{- 2 x} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview40">\( - \left(2 e^{x} \sin{\left(x \right)} - 2 e^{x - 1} \sin{\left(x \right)}\right) e^{- 2 x} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- \frac{2 \log{\left(\left|{x}\right| \right)}}{\cos{\left(x \right)}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:051）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:商の微分法を確認しましょう。符号を間違えている可能性があります。"><input type="radio" name="preview51">\( \frac{2 \left(\log{\left(\left|{x}\right| \right)} \sin{\left(x \right)} - \frac{\cos{\left(x \right)}}{x}\right)}{\cos^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview51">\( 0 \)</li><li title="点数:100"><input type="radio" name="preview51">\( \frac{2 \left(- \log{\left(\left|{x}\right| \right)} \sin{\left(x \right)} - \frac{\cos{\left(x \right)}}{x}\right)}{\cos^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview51">\( \frac{2 \left(\log{\left(\left|{x}\right| \right)} \sin{\left(x \right)} - \log{\left(\left|{x}\right| \right)} \cos{\left(x \right)}\right)}{\cos^{2}{\left(x \right)}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=\frac{6 e^{x}}{x^{3}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:199）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview199">\( - \frac{3 \left(6 x^{3} e^{x} - 2 x^{3} e^{x - 1}\right)}{x^{6}} \)</li><li title="点数:100"><input type="radio" name="preview199">\( - \frac{3 \left(- 2 x^{3} e^{x} + 6 x^{2} e^{x}\right)}{x^{6}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview199">\( - \frac{3 \left(- 2 x^{3} e^{x - 1} + 4 x^{2} e^{x}\right)}{x^{6}} \)</li><li title="点数:0
# フィードバック:商の微分法を確認しましょう。符号を間違えている可能性があります。"><input type="radio" name="preview199">\( - \frac{3 \left(- 2 x^{3} e^{x} - 6 x^{2} e^{x}\right)}{x^{6}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview199">\( - \frac{3 \left(2 x^{3} e^{x} - 2 x^{3} e^{x - 1}\right)}{x^{6}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- \frac{\log{\left(\left|{x}\right| \right)}}{2 \cos{\left(x \right)}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:086）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview86">\( \frac{2 \log{\left(\left|{x}\right| \right)} \sin{\left(x \right)} - 2 \log{\left(\left|{x}\right| \right)} \cos{\left(x \right)}}{4 \cos^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:商の微分法を確認しましょう。符号を間違えている可能性があります。

# %%
if __name__ == "__main__":
    pass
    #qz.save('derivative_by_quotient.xml')

# %% [markdown]
# ## derivative by composition

# %%
class derivative_by_composition(core.Question):
    name = '合成関数の微分法に基づく導関数の計算（基本公式と合成関数の微分法の活用）'
    def __init__(self, emin=-3, emax=3, nmin=2, nmax=3, lmin=1, lmax=1):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 生成する次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 生成する関数の和の範囲
        self.func_min = lmin
        self.func_max = lmax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='合成関数の微分法に基づく導関数の計算', quiz_number=_quiz_number)
        df = DifferentiableFunction(emin=self.elem_min, emax=self.elem_max, nmin=self.deg_min, nmax=self.deg_max, 
                                   lrate=0, lmin=self.func_min, lmax=self.func_max, crate=1, mrate=0, qrate=0, srate=0)
        _func = df.get_function()
        quiz.quiz_identifier = hash(str(_func))
        # 正答の選択肢の生成
        _df = df.get_derivative()
        quiz.data = [_func, _df, df]
        ans = { 'fraction': 100, 'data': _df }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_func, _df, df] = quiz.data
        ans['feedback'] = r'基本的な関数の導関数の公式を確認してください。'
        for _incorrect in df.get_incorrect_derivatives('formula'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        ans['feedback'] = r'導関数の線形性に基づいて計算してください。加減算を忘れている可能性があります。'
        for _incorrect in df.get_incorrect_derivatives('part'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        ans['feedback'] = r'合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。'
        for _incorrect in df.get_incorrect_derivatives('composition'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_func, _df, df] = quiz.data
        _text = r'次の関数\( f(x) \)の導関数を選択してください。'
        _text += r'<br />\( f(x)=' + sympy.latex(_func, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = derivative_by_composition()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 6 e^{- 2 x^{3}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:133）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview133">\( 144 x^{6} e^{x} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview133">\( 36 x^{3} e^{- 2 x^{3} - 1} \)</li><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview133">\( 18 x^{2} \)</li><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview133">\( - 6 e^{x} \)</li><li title="点数:100"><input type="radio" name="preview133">\( 36 x^{2} e^{- 2 x^{3}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 3 \cdot 2^{\log{\left(\left|{x}\right| \right)}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:014）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview14">\( - 3 \cdot 2^{x} \log{\left(2 \right)} \)</li><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview14">\( - \frac{3 \cdot 2^{x} \log{\left(2 \right)}}{\log{\left(\left|{x}\right| \right)}} \)</li><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview14">\( \frac{1}{x} \)</li><li title="点数:100"><input type="radio" name="preview14">\( - \frac{3 \cdot 2^{\log{\left(\left|{x}\right| \right)}} \log{\left(2 \right)}}{x} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview14">\( - 3 \cdot 2^{\log{\left(\left|{x}\right| \right)} - 1} \log{\left(\left|{x}\right| \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 2 \cos{\left(2 x^{2} \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:099）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview99">\( - 4 x \sin{\left(2 x^{2} \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview99">\( - 8 x^{2} \sin{\left(2 x^{2} \right)} \)</li><li title="点数:100"><input type="radio" name="preview99">\( 8 x \sin{\left(2 x^{2} \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview99">\( - 4 x^{2} \sin{\left(2 x^{2} \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview99">\( 4 x^{2} \cos{\left(2 x^{2} \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=e^{\tan{\left(x \right)}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:135）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview135">\( \frac{e^{x}}{\cos^{2}{\left(\tan{\left(x \right)} \right)}} \)</li><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview135">\( e^{x} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview135">\( e^{\tan{\left(x \right)} - 1} \tan{\left(x \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview135">\( \frac{e^{\tan{\left(x \right)} - 1}}{\cos{\left(x \right)}} \)</li><li title="点数:100"><input type="radio" name="preview135">\( \frac{e^{\tan{\left(x \right)}}}{\cos^{2}{\left(x \right)}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 3 \tan{\left(3 \cos{\left(x \right)} \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:123）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview123">\( - \frac{3}{\cos^{2}{\left(x \right)}} \)</li><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview123">\( \frac{9 \sin{\left(3 \cos{\left(x \right)} \right)}}{\cos^{2}{\left(x \right)}} \)</li><li title="点数:100"><input type="radio" name="preview123">\( \frac{9 \sin{\left(x \right)}}{\cos^{2}{\left(3 \cos{\left(x \right)} \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview123">\( - \frac{9 \cos{\left(x \right)}}{\cos{\left(3 \cos{\left(x \right)} \right)}} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview123">\( - \frac{9 \sin{\left(x \right)}}{\cos{\left(3 \cos{\left(x \right)} \right)}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=- 2 \sin{\left(3 \cdot 3^{x} \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:129）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview129">\( - 2 \cos{\left(x \right)} \)</li><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview129">\( - 6 \cdot 3^{3 \cdot 3^{x}} \log{\left(3 \right)} \cos{\left(x \right)} \)</li><li title="点数:100"><input type="radio" name="preview129">\( - 6 \cdot 3^{x} \log{\left(3 \right)} \cos{\left(3 \cdot 3^{x} \right)} \)</li><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview129">\( 3 \cdot 3^{x} \log{\left(3 \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview129">\( - 6 \cdot 3^{x - 1} \sin{\left(3 \cdot 3^{x} \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=3 \cos{\left(3 e^{x} \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:184）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview184">\( - 9 e^{x} \sin{\left(3 e^{x} \right)} \)</li><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview184">\( - 3 \sin{\left(x \right)} \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview184">\( 9 e^{x - 1} \cos{\left(3 e^{x} \right)} \)</li><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview184">\( - 9 e^{3 e^{x}} \sin{\left(x \right)} \)</li><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview184">\( - 9 e^{x} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=6 \cos{\left(2 \sin{\left(x \right)} \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:020）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview20">\( - 6 \sin{\left(x \right)} \)</li><li title="点数:0
# フィードバック:合成関数の微分法を確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview20">\( - 12 \sin{\left(x \right)} \cos{\left(2 \sin{\left(x \right)} \right)} \)</li><li t

# %%
if __name__ == "__main__":
    pass
    #qz.save('derivative_by_composition.xml')

# %% [markdown]
# ## derivative by taking logarithm

# %%
class derivative_by_taking_logarithm(core.Question):
    name = '対数微分法に基づく導関数の計算（基本公式と対数微分法の活用）'
    def __init__(self, emin=-3, emax=3, nmin=2, nmax=3, lmin=1, lmax=1):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 生成する次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 生成する関数の和の範囲
        self.func_min = lmin
        self.func_max = lmax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='対数微分法に基づく導関数の計算', quiz_number=_quiz_number)
        df = DifferentiableFunction(emin=self.elem_min, emax=self.elem_max, nmin=self.deg_min, nmax=self.deg_max, 
                                   lrate=1, lmin=self.func_min, lmax=self.func_max, crate=0, mrate=0, qrate=0, srate=0)
        _func = df.get_function()
        quiz.quiz_identifier = hash(str(_func))
        # 正答の選択肢の生成
        _df = df.get_derivative()
        quiz.data = [_func, _df, df]
        ans = { 'fraction': 100, 'data': _df }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_func, _df, df] = quiz.data
        ans['feedback'] = r'基本的な関数の導関数の公式を確認してください。'
        for _incorrect in df.get_incorrect_derivatives('formula'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        ans['feedback'] = r'対数微分法の途中の計算で部分的に間違えていないでしょうか。'
        for _incorrect in df.get_incorrect_derivatives('sign'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        for _incorrect in df.get_incorrect_derivatives('composition'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        for _incorrect in df.get_incorrect_derivatives('part'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        for _incorrect in df.get_incorrect_derivatives('scalar'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_func, _df, df] = quiz.data
        _text = r'次の関数\( f(x) \)の導関数を選択してください。'
        _text += r'<br />\( f(x)=' + sympy.latex(_func, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = derivative_by_taking_logarithm()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=\left(- 3 x^{3}\right)^{- 2 \log{\left(\left|{x}\right| \right)}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:166）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:対数微分法の途中の計算で部分的に間違えていないでしょうか。"><input type="radio" name="preview166">\( \left(- 3 x^{3}\right)^{- 2 \log{\left(\left|{x}\right| \right)}} \left(\frac{\log{\left(- 3 x^{3} \right)}}{x} - \frac{2 \log{\left(\left|{x}\right| \right)}}{x}\right) \)</li><li title="点数:100"><input type="radio" name="preview166">\( \left(- 3 x^{3}\right)^{- 2 \log{\left(\left|{x}\right| \right)}} \left(- \frac{2 \log{\left(- 3 x^{3} \right)}}{x} - \frac{6 \log{\left(\left|{x}\right| \right)}}{x}\right) \)</li><li title="点数:0
# フィードバック:対数微分法の途中の計算で部分的に間違えていないでしょうか。"><input type="radio" name="preview166">\( \left(- 3 x^{3}\right)^{- 2 \log{\left(\left|{x}\right| \right)}} \left(- \frac{2 \log{\left(- 3 x^{3} \right)}}{x} - \frac{2 \log{\left(\left|{x}\right| \right)}}{x}\right) \)</li><li title="点数:0
# フィードバック:対数微分法の途中の計算で部分的に間違えていないでしょうか。"><input type="radio" name="preview166">\( \left(- 3 x^{3}\right)^{- 2 \log{\left(\left|{x}\right| \right)}} \left(162 x^{5} \log{\left(\left|{x}\right| \right)} - \frac{2 \log{\left(- 3 x^{3} \right)}}{x}\right) \)</li><li title="点数:0
# フィードバック:対数微分法の途中の計算で部分的に間違えていないでしょうか。"><input type="radio" name="preview166">\( \left(- 3 x^{3}\right)^{- 2 \log{\left(\left|{x}\right| \right)}} \left(- \frac{\log{\left(- 3 x^{3} \right)}}{x} - \frac{2 \log{\left(\left|{x}\right| \right)}}{x}\right) \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=\left(- e^{x}\right)^{- 2^{x}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:088）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview88">\( \left(- e^{x}\right)^{- 2^{x}} \left(2^{x} e^{x - 1} \log{\left(- e^{x} \right)} - 2^{x - 1} \log{\left(- e^{x} \right)}\right) \)</li><li title="点数:100"><input type="radio" name="preview88">\( \left(- e^{x}\right)^{- 2^{x}} \left(- 2^{x} \log{\left(2 \right)} \log{\left(- e^{x} \right)} - 2^{x}\right) \)</li><li title="点数:0
# フィードバック:対数微分法の途中の計算で部分的に間違えていないでしょうか。"><input type="radio" name="preview88">\( \left(- e^{x}\right)^{- 2^{x}} \left(- 2^{x} \log{\left(2 \right)} \log{\left(- e^{x} \right)} + 2^{x}\right) \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview88">\( \left(- e^{x}\right)^{- 2^{x}} \left(2^{x} e^{x - 1} \log{\left(- e^{x} \right)} - 2^{x} \log{\left(- e^{x} \right)}\right) \)</li><li title="点数:0
# フィードバック:対数微分法の途中の計算で部分的に間違えていないでしょうか。"><input type="radio" name="preview88">\( \left(- e^{x}\right)^{- 2^{x}} \left(- 2^{x} \log{\left(2 \right)} \log{\left(- e^{x} \right)} + \frac{2^{x} e^{- e^{x}}}{x}\right) \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=\left(- 3 \tan{\left(x \right)}\right)^{3 \cos{\left(x \right)}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:108）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview108">\( \left(- 3 \tan{\left(x \right)}\right)^{3 \cos{\left(x \right)}} \left(- 9 \log{\left(- 3 \tan{\left(x \right)} \right)} \cos{\left(x \right)} \tan{\left(x \right)} + 3 \log{\left(- 3 \tan{\left(x \right)} \right)} \cos{\left(x \right)}\right) \)</li><li title="点数:100"><input type="radio" name="preview108">\( \left(- 3 \tan{\left(x \right)}\right)^{3 \cos{\left(x \right)}} \left(- 3 \log{\left(- 3 \tan{\left(x \right)} \right)} \sin{\left(x \right)} + \frac{3}{\cos{\left(x \right)} \tan{\left(x \right)}}\right) \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview108">\( \left(- 3 \tan{\left(x \right)}\right)^{3 \cos{\left(x \right)}} \left(3 \log{\left(- 3 \tan{\left(x \right)} \right)} \sin{\left(x \right)} - 9 \log{\left(- 3 \tan{\left(x \right)} \right)} \cos{\left(x \right)} \tan{\left(x \right)}\right) \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview108">\( \left(- 3 \tan{\left(x \right)}\right)^{3 \cos{\left(x \right)}} \left(3 \log{\left(- 3 \tan{\left(x \right)} \right)} \sin{\left(x \right)} - \frac{9 \log{\left(- 3 \tan{\left(x \right)} \right)} \cos{\left(x \right)}}{\sin^{2}{\left(x \right)}}\right) \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview108">\( \left(- 3 \tan{\left(x \right)}\right)^{3 \cos{\left(x \right)}} \left(3 \log{\left(- 3 \tan{\left(x \right)} \right)} \cos{\left(x \right)} - \frac{9 \log{\left(- 3 \tan{\left(x \right)} \right)} \cos{\left(x \right)}}{\sin^{2}{\left(x \right)}}\right) \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=\left(- 2 x^{3}\right)^{3^{x}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:017）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview17">\( \left(- 2 x^{3}\right)^{3^{x}} \left(- 6 \cdot 3^{x} x^{3} \log{\left(- 2 x^{3} \right)} + 3^{x} \log{\left(- 2 x^{3} \right)}\right) \)</li><li title="点数:0
# フィードバック:対数微分法の途中の計算で部分的に間違えていないでしょうか。"><input type="radio" name="preview17">\( \left(- 2 x^{3}\right)^{3^{x}} \left(- 3^{x} \log{\left(3 \right)} \log{\left(- 2 x^{3} \right)} + \frac{3 \cdot 3^{x}}{2 x}\right) \)</li><li title="点数:0
# フィードバック:対数微分法の途中の計算で部分的に間違えていないでしょうか。"><input type="radio" name="preview17">\( \left(- 2 x^{3}\right)^{3^{x}} \left(3^{x} \log{\left(3 \right)} \log{\left(- 2 x^{3} \right)} - \frac{3 \cdot 3^{x}}{2 x}\right) \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview17">\( \left(- 2 x^{3}\right)^{3^{x}} \left(- 6 \cdot 3^{x} x^{3} \log{\left(- 2 x^{3} \right)} + 3^{x - 1} \log{\left(- 2 x^{3} \right)}\right) \)</li><li title="点数:100"><input type="radio" name="preview17">\( \left(- 2 x^{3}\right)^{3^{x}} \left(3^{x} \log{\left(3 \right)} \log{\left(- 2 x^{3} \right)} + \frac{3 \cdot 3^{x}}{x}\right) \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の導関数を選択してください。<br />\( f(x)=\left(2 \log{\left(\left|{x}\right| \right)}\right)^{\sin{\left(x \right)}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:042）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:対数微分法の途中の計算で部分的に間違えていないでしょうか。"><input type="radio" name="preview42">\( \left(2 \log{\left(\left|{x}\right| \right)}\right)^{\sin{\left(x \right)}} \left(- \log{\left(2 \log{\left(\left|{x}\right| \right)} \right)} \cos{\left(x \right)} + \frac{\sin{\left(x \right)}}{2 x \log{\left(\left|{x}\right| \right)}}\right) \)</li><li title="点数:0
# フィードバック:対数微分法の途中の計算で部分的に間違えていないでしょうか。"><input type="radio" name="preview42">\( \left(2 \log{\left(\left|{x}\right| \right)}\right)^{\sin{\left(x \right)}} \left(\log{\left(2 \log{\left(\left|{x}\right| \right)} \right)} \cos{\left(x \right)} - \frac{\sin{\left(x \right)}}{x \log{\left(\left|{x}\right| \right)}}\right) \)</li><li title="点数:0
# フィードバック:基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview42">\( \left(2 \log{\left(\left|{x}\right| \right)}\right)^{\sin{\left(x \right)}} \left(2 \log{\left(2 \log{\left(\left|{x}\right| \right)} \right)} \log{\left(\left|{x}\right| \right)} \sin{\left(x \right)} - \log{\left(2 \lo

# %%
if __name__ == "__main__":
    pass
    #qz.save('derivative_by_taking_logarithm.xml')

# %% [markdown]
# ## higher derivative

# %%
class higher_derivative(core.Question):
    name = '高階導関数の計算'
    def __init__(self, emin=-4, emax=4, nmin=2, nmax=3, lmin=1, lmax=1, dmin=2, dmax=3):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 生成する次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 生成する関数の和の範囲
        self.func_min = lmin
        self.func_max = lmax
        # 何階の導関数を求めるか
        self.order_min = dmin
        self.order_max = dmax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='高階導関数の計算', quiz_number=_quiz_number)
        _order = random.randint(self.order_min, self.order_max)
        if _order <= 2:
            df = DifferentiableFunction(emin=self.elem_min, emax=self.elem_max, nmin=self.deg_min, nmax=self.deg_max, inclog=False,
                                   lrate=0, lmin=self.func_min, lmax=self.func_max, crate=0.25, mrate=0.25, qrate=0, srate=0.25)
        else:
            df = DifferentiableFunction(emin=self.elem_min, emax=self.elem_max, nmin=self.deg_min, nmax=self.deg_max, inclog=False,
                                   lrate=0, lmin=self.func_min, lmax=self.func_max, crate=0, mrate=0, qrate=0, srate=0.25)
        _func = df.get_function()
        quiz.quiz_identifier = hash(str(_func) + str(_order))
        # 正答の選択肢の生成
        _df = df.get_higher_derivative(_order)
        quiz.data = [_func, _order, _df, df]
        ans = { 'fraction': 100, 'data': _df }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_func, _order, _df, df] = quiz.data
        ans['feedback'] = r'高階導関数とは，階数分の微分を行った関数です。'
        for _incorrect in df.get_incorrect_higher_derivatives(_order, 'degree'):
            ans['data'] = _incorrect
            answers.append(dict(ans))
        answers = common.answer_union(answers)
        additional_answers = []
        ans['feedback'] = r'それぞれの微分について，計算を確認してください。'
        for _incorrect in df.get_incorrect_higher_derivatives(_order, 'formula'):
            ans['data'] = _incorrect
            additional_answers.append(dict(ans))
        for _incorrect in df.get_incorrect_higher_derivatives(_order, 'sign'):
            ans['data'] = _incorrect
            additional_answers.append(dict(ans))
        for _incorrect in df.get_incorrect_higher_derivatives(_order, 'composition'):
            ans['data'] = _incorrect
            additional_answers.append(dict(ans))
        for _incorrect in df.get_incorrect_higher_derivatives(_order, 'part'):
            ans['data'] = _incorrect
            additional_answers.append(dict(ans))
        for _incorrect in df.get_incorrect_higher_derivatives(_order, 'scalar'):
            ans['data'] = _incorrect
            additional_answers.append(dict(ans))
        additional_answers = common.answer_union(additional_answers)
        if len(additional_answers) > len(answers):
            additional_answers = random.sample(additional_answers, k=max(len(answers),min(size-len(answers),len(additional_answers))))
        answers = answers + additional_answers
        answers = common.answer_union(answers)
        if len(answers) > size:
            answers = random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_func, _order, _df, df] = quiz.data
        _text = r'次の関数\( f(x) \)の' + str(_order) + r'階導関数を選択してください。'
        _text += r'<br />\( f(x)=' + sympy.latex(_func, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = higher_derivative()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の2階導関数を選択してください。<br />\( f(x)=- 2^{x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:024）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview24">\( - 2^{x} \log{\left(2 \right)}^{2} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview24">\( - 2^{x} \log{\left(2 \right)}^{3} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview24">\( - 2^{x} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview24">\( - 2^{x} \log{\left(2 \right)} \)</li><li title="点数:0
# フィードバック:それぞれの微分について，計算を確認してください。"><input type="radio" name="preview24">\( - 2^{x - 1} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の2階導関数を選択してください。<br />\( f(x)=9 \cdot 2^{x} x^{3} \)<div style="text-align:right;font-size:smaller">（問題整理番号:128）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview128">\( 9 \cdot 2^{x} x^{3} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview128">\( 9 \cdot 2^{x} \left(x^{3} \log{\left(2 \right)}^{3} + 9 x^{2} \log{\left(2 \right)}^{2} + 18 x \log{\left(2 \right)} + 6\right) \)</li><li title="点数:0
# フィードバック:それぞれの微分について，計算を確認してください。"><input type="radio" name="preview128">\( 36 \cdot 2^{x} x^{3} \)</li><li title="点数:0
# フィードバック:それぞれの微分について，計算を確認してください。"><input type="radio" name="preview128">\( 27 \cdot 2^{x} x^{3} + 9 \cdot 2^{x - 1} x^{3} \)</li><li title="点数:100"><input type="radio" name="preview128">\( 9 \cdot 2^{x} x^{3} \log{\left(2 \right)}^{2} + 54 \cdot 2^{x} x^{2} \log{\left(2 \right)} + 54 \cdot 2^{x} x \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の2階導関数を選択してください。<br />\( f(x)=3 \cos{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:195）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview195">\( 3 \sin{\left(x \right)} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview195">\( - 3 \sin{\left(x \right)} \)</li><li title="点数:0
# フィードバック:それぞれの微分について，計算を確認してください。"><input type="radio" name="preview195">\( \sin{\left(x \right)} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview195">\( 3 \cos{\left(x \right)} \)</li><li title="点数:100"><input type="radio" name="preview195">\( - 3 \cos{\left(x \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の3階導関数を選択してください。<br />\( f(x)=3 \cdot 4^{x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:022）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview22">\( 3 \cdot 4^{x} \log{\left(4 \right)} \)</li><li title="点数:0
# フィードバック:それぞれの微分について，計算を確認してください。"><input type="radio" name="preview22">\( - 4^{x} \log{\left(4 \right)} \)</li><li title="点数:100"><input type="radio" name="preview22">\( 3 \cdot 4^{x} \log{\left(4 \right)}^{3} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview22">\( 3 \cdot 4^{x} \log{\left(4 \right)}^{4} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview22">\( 3 \cdot 4^{x} \log{\left(4 \right)}^{2} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の2階導関数を選択してください。<br />\( f(x)=- 16 \cdot 4^{e^{x}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:014）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:それぞれの微分について，計算を確認してください。"><input type="radio" name="preview14">\( - 16 \cdot 4^{x} e^{e^{x}} \log{\left(4 \right)} \)</li><li title="点数:100"><input type="radio" name="preview14">\( - 16 \cdot 4^{e^{x}} e^{2 x} \log{\left(4 \right)}^{2} - 16 \cdot 4^{e^{x}} e^{x} \log{\left(4 \right)} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview14">\( - 16 \cdot 4^{e^{x}} e^{x} \log{\left(4 \right)} \)</li><li title="点数:0
# フィードバック:それぞれの微分について，計算を確認してください。"><input type="radio" name="preview14">\( - 4^{e^{x}} e^{x} \log{\left(4 \right)} \)</li><li title="点数:0
# フィードバック:それぞれの微分について，計算を確認してください。"><input type="radio" name="preview14">\( - 4 e^{x} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の2階導関数を選択してください。<br />\( f(x)=- x^{3} \)<div style="text-align:right;font-size:smaller">（問題整理番号:050）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview50">\( - 6 x \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview50">\( - 3 x^{2} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview50">\( - x^{3} \)</li><li title="点数:0
# フィードバック:それぞれの微分について，計算を確認してください。"><input type="radio" name="preview50">\( - 3 x^{3} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview50">\( -6 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の3階導関数を選択してください。<br />\( f(x)=- 4 \cdot 4^{x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:017）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview17">\( - 4 \cdot 4^{x} \log{\left(4 \right)}^{2} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview17">\( - 4 \cdot 4^{x} \log{\left(4 \right)}^{4} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview17">\( - 4 \cdot 4^{x} \log{\left(4 \right)} \)</li><li title="点数:0
# フィードバック:それぞれの微分について，計算を確認してください。"><input type="radio" name="preview17">\( - 4^{x} \log{\left(4 \right)} \)</li><li title="点数:100"><input type="radio" name="preview17">\( - 4 \cdot 4^{x} \log{\left(4 \right)}^{3} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の2階導関数を選択してください。<br />\( f(x)=- 4 \cdot 2^{x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:163）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:それぞれの微分について，計算を確認してください。"><input type="radio" name="preview163">\( - 2^{x} \log{\left(2 \right)} \)</li><li title="点数:100"><input type="radio" name="preview163">\( - 4 \cdot 2^{x} \log{\left(2 \right)}^{2} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview163">\( - 4 \cdot 2^{x} \log{\left(2 \right)}^{3} \)</li><li title="点数:0
# フィードバック:それぞれの微分について，計算を確認してください。"><input type="radio" name="preview163">\( 2^{x} \log{\left(2 \right)} \)</li><li title="点数:0
# フィードバック:高階導関数とは，階数分の微分を行った関数です。"><input type="radio" name="preview163">\( - 4 \cdot 2^{x} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の2階導関数を選択してください。<br />\( f(x)=24 \sin{\left(x \right)} \tan{\left(x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:193）</div><ol style="list-style

# %%
if __name__ == "__main__":
    pass
    #qz.save('higher_derivative.xml')

# %% [markdown]
# ## local minimum and maximum

# %%
class local_minimum_maximum(core.Question):
    name = '極大値と極小値（増減表からの決定）'    
    def __init__(self, emax=5, nmin=1, nmax=3):
        # 生成するdf=0の個数範囲
        self.nsp_min = nmin
        self.nsp_max = nmax
        # 数の生成
        self.numbers = list(range(0,emax+1)) + [sympy.sqrt(sympy.prime(i)) for i in range(1,emax)] + [sympy.pi, sympy.E]
        self.numbers = self.numbers + [_e/sympy.Integer(2) for _e in self.numbers]
        self.numbers = self.numbers + [-_e for _e in self.numbers]
        self.numbers = sorted(list(set(self.numbers)))
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='極大値と極小値', quiz_number=_quiz_number)
        _number_of_sp = random.randint(self.nsp_min, self.nsp_max)
        _spxs = sorted(random.sample(self.numbers, k=_number_of_sp))
        _spys = random.sample(self.numbers, k=_number_of_sp)
        _intervals = [[_spys[i],_spys[i+1]] for i in range(len(_spys)-1)]
        _spss = [random.choice([1,-1])] + [1 if _y[0] <= _y[1] else -1 for _y in _intervals] + [random.choice([1,-1])]
        quiz.quiz_identifier = hash(str(_spxs) + str(_spys) + str(_spss))
        # 正答の選択肢の生成
        _saddles = []
        for i in range(len(_spys)):
            if _spss[i]*_spss[i+1] < 0:
                if _spss[i] < 0:
                    _saddles.append([_spxs[i],_spys[i],-1])
                else:
                    _saddles.append([_spxs[i],_spys[i],1])
        quiz.data = [_number_of_sp, _spxs, _spys, _spss, _saddles]
        ans = { 'fraction': 100, 'data': _saddles }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_number_of_sp, _spxs, _spys, _spss, _saddles] = quiz.data
        if len(_saddles) > 0:
            ans['feedback'] = r'増減表をきちんと確認してください。極値をもちます。'
            ans['data'] = list()
            answers.append(dict(ans))
            ans['feedback'] = r'極大と極小の定義を確認しましょう。取り違えています。'
            ans['data'] = [[_saddle[0], _saddle[1], -1*_saddle[2]] for _saddle in _saddles]
            answers.append(dict(ans))
        if len(_saddles) > 1:
            ans['feedback'] = r'全ての極値を調べてください。不足があります。'
            for i in range(len(_saddles)):
                ans['data'] = _saddles[:i] + _saddles[i+1:]
                answers.append(dict(ans))
                ans['feedback'] = r'極大と極小の定義を確認しましょう。不足もありますし，取り違えてもいます。'
                ans['data'] = [[_saddle[0], _saddle[1], -1*_saddle[2]] for _saddle in ans['data']]
                answers.append(dict(ans))
        if len(_saddles) < len(_spxs):
            _used_spxs = [_saddle[0] for _saddle in _saddles]
            for i in range(_number_of_sp):
                if _spxs[i] in _used_spxs:
                    continue
                _incorrect_small = []
                _incorrect_large = []
                for _saddle in _saddles:
                    if _saddle[0] < _spxs[i]:
                        _incorrect_small.append(_saddle)
                    else:
                        _incorrect_large.append(_saddle)
                ans['feedback'] = r'極大と極小の定義を確認しましょう。多すぎます。'
                ans['data'] = _incorrect_small + [[_spxs[i], _spys[i], -1]] + _incorrect_large
                answers.append(dict(ans))
                ans['feedback'] = r'極大と極小の定義を確認しましょう。多すぎます。'
                ans['data'] = _incorrect_small + [[_spxs[i], _spys[i], +1]] + _incorrect_large
                answers.append(dict(ans))
            
#        answers = common.answer_union(answers)
        if len(answers) > size:
            answers = random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_number_of_sp, _spxs, _spys, _spss, _saddles] = quiz.data
        _text = r'以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。'
        _text += r'<br />\( \begin{array}{'
        for i in range(2*_number_of_sp+2):
            _text += r'|c'
        _text += r'|}\hline '
        _text += r'x'
        for _spx in _spxs:
            _text += r'&\cdots&' + sympy.latex(_spx)
        _text += r"&\cdots\\\hline f'(x)"
        for _sps in _spss[:-1]:
            if _sps > 0:
                _text += r'&+&0'
            else:
                _text += r'&-&0'
        if _spss[-1] > 0:
            _text += r'&+'
        else:
            _text += r'&-'
        _text += r'\\\hline f(x)'
        for _spy in _spys:
            _text += r'&&' + sympy.latex(_spy)
        _text += r"&\\\hline"
        _text += r'\end{array} \)'
        return _text
    def answer_text(self, ans):
        _saddles = ans['data']
        if len(_saddles) == 0:
            return r'極値をもたない'
        _text = r''
        for _saddle in _saddles[:-1]:
            _text += r'\( x=' + sympy.latex(_saddle[0]) + r' \)のとき'
            if _saddle[2] > 0:
                _text += r'極大値'
            else:
                _text += r'極小値'
            _text += r'\( ' +  sympy.latex(_saddle[1]) + r' \)，'
        _text += r'\( x=' + sympy.latex(_saddles[-1][0]) + r' \)のとき'
        if _saddles[-1][2] > 0:
            _text += r'極大値'
        else:
            _text += r'極小値'
        _text += r'\( ' +  sympy.latex(_saddles[-1][1]) + r' \)をとる'
        return _text

# %%
if __name__ == "__main__":
    q = local_minimum_maximum()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。<br />\( \begin{array}{|c|c|c|c|c|c|}\hline x&\cdots&- \frac{3}{2}&\cdots&\frac{e}{2}&\cdots\\\hline f'(x)&-&0&+&0&-\\\hline f(x)&&- \frac{\sqrt{5}}{2}&&- \frac{\sqrt{2}}{2}&\\\hline\end{array} \)<div style="text-align:right;font-size:smaller">（問題整理番号:112）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。不足もありますし，取り違えてもいます。"><input type="radio" name="preview112">\( x=- \frac{3}{2} \)のとき極大値\( - \frac{\sqrt{5}}{2} \)をとる</li><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。不足もありますし，取り違えてもいます。"><input type="radio" name="preview112">\( x=- \frac{3}{2} \)のとき極小値\( - \frac{\sqrt{5}}{2} \)をとる</li><li title="点数:100"><input type="radio" name="preview112">\( x=- \frac{3}{2} \)のとき極小値\( - \frac{\sqrt{5}}{2} \)，\( x=\frac{e}{2} \)のとき極大値\( - \frac{\sqrt{2}}{2} \)をとる</li><li title="点数:0
# フィードバック:増減表をきちんと確認してください。極値をもちます。"><input type="radio" name="preview112">極値をもたない</li><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。不足もありますし，取り違えてもいます。"><input type="radio" name="preview112">\( x=\frac{e}{2} \)のとき極小値\( - \frac{\sqrt{2}}{2} \)をとる</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。<br />\( \begin{array}{|c|c|c|c|}\hline x&\cdots&- \frac{\sqrt{3}}{2}&\cdots\\\hline f'(x)&-&0&-\\\hline f(x)&&\frac{\sqrt{2}}{2}&\\\hline\end{array} \)<div style="text-align:right;font-size:smaller">（問題整理番号:173）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。多すぎます。"><input type="radio" name="preview173">\( x=- \frac{\sqrt{3}}{2} \)のとき極小値\( \frac{\sqrt{2}}{2} \)をとる</li><li title="点数:100"><input type="radio" name="preview173">極値をもたない</li><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。多すぎます。"><input type="radio" name="preview173">\( x=- \frac{\sqrt{3}}{2} \)のとき極大値\( \frac{\sqrt{2}}{2} \)をとる</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。<br />\( \begin{array}{|c|c|c|c|c|c|}\hline x&\cdots&- \frac{5}{2}&\cdots&-1&\cdots\\\hline f'(x)&+&0&-&0&+\\\hline f(x)&&\frac{\sqrt{2}}{2}&&\frac{1}{2}&\\\hline\end{array} \)<div style="text-align:right;font-size:smaller">（問題整理番号:139）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。不足もありますし，取り違えてもいます。"><input type="radio" name="preview139">\( x=-1 \)のとき極大値\( \frac{1}{2} \)をとる</li><li title="点数:100"><input type="radio" name="preview139">\( x=- \frac{5}{2} \)のとき極大値\( \frac{\sqrt{2}}{2} \)，\( x=-1 \)のとき極小値\( \frac{1}{2} \)をとる</li><li title="点数:0
# フィードバック:全ての極値を調べてください。不足があります。"><input type="radio" name="preview139">\( x=-1 \)のとき極小値\( \frac{1}{2} \)をとる</li><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。不足もありますし，取り違えてもいます。"><input type="radio" name="preview139">\( x=- \frac{5}{2} \)のとき極大値\( \frac{\sqrt{2}}{2} \)をとる</li><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。取り違えています。"><input type="radio" name="preview139">\( x=- \frac{5}{2} \)のとき極小値\( \frac{\sqrt{2}}{2} \)，\( x=-1 \)のとき極大値\( \frac{1}{2} \)をとる</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。<br />\( \begin{array}{|c|c|c|c|c|c|c|c|}\hline x&\cdots&- \sqrt{5}&\cdots&- \frac{e}{2}&\cdots&-1&\cdots\\\hline f'(x)&-&0&-&0&+&0&-\\\hline f(x)&&\frac{\pi}{2}&&\sqrt{2}&&\frac{5}{2}&\\\hline\end{array} \)<div style="text-align:right;font-size:smaller">（問題整理番号:159）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview159">\( x=- \frac{e}{2} \)のとき極小値\( \sqrt{2} \)，\( x=-1 \)のとき極大値\( \frac{5}{2} \)をとる</li><li title="点数:0
# フィードバック:全ての極値を調べてください。不足があります。"><input type="radio" name="preview159">\( x=-1 \)のとき極大値\( \frac{5}{2} \)をとる</li><li title="点数:0
# フィードバック:増減表をきちんと確認してください。極値をもちます。"><input type="radio" name="preview159">極値をもたない</li><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。不足もありますし，取り違えてもいます。"><input type="radio" name="preview159">\( x=- \frac{e}{2} \)のとき極小値\( \sqrt{2} \)をとる</li><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。不足もありますし，取り違えてもいます。"><input type="radio" name="preview159">\( x=- \frac{e}{2} \)のとき極大値\( \sqrt{2} \)をとる</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。<br />\( \begin{array}{|c|c|c|c|c|c|}\hline x&\cdots&- \frac{\sqrt{3}}{2}&\cdots&5&\cdots\\\hline f'(x)&+&0&+&0&-\\\hline f(x)&&- \frac{1}{2}&&1&\\\hline\end{array} \)<div style="text-align:right;font-size:smaller">（問題整理番号:090）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。多すぎます。"><input type="radio" name="preview90">\( x=- \frac{\sqrt{3}}{2} \)のとき極小値\( - \frac{1}{2} \)，\( x=5 \)のとき極大値\( 1 \)をとる</li><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。取り違えています。"><input type="radio" name="preview90">\( x=5 \)のとき極小値\( 1 \)をとる</li><li title="点数:100"><input type="radio" name="preview90">\( x=5 \)のとき極大値\( 1 \)をとる</li><li title="点数:0
# フィードバック:増減表をきちんと確認してください。極値をもちます。"><input type="radio" name="preview90">極値をもたない</li><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。多すぎます。"><input type="radio" name="preview90">\( x=- \frac{\sqrt{3}}{2} \)のとき極大値\( - \frac{1}{2} \)，\( x=5 \)のとき極大値\( 1 \)をとる</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。<br />\( \begin{array}{|c|c|c|c|c|c|c|c|}\hline x&\cdots&- \sqrt{3}&\cdots&- \frac{\sqrt{3}}{2}&\cdots&\frac{\sqrt{2}}{2}&\cdots\\\hline f'(x)&+&0&-&0&-&0&+\\\hline f(x)&&\sqrt{5}&&\frac{\sqrt{2}}{2}&&0&\\\hline\end{array} \)<div style="text-align:right;font-size:smaller">（問題整理番号:076）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。多すぎます。"><input type="radio" name="preview76">\( x=- \sqrt{3} \)のとき極大値\( \sqrt{5} \)，\( x=- \frac{\sqrt{3}}{2} \)のとき極大値\( \frac{\sqrt{2}}{2} \)，\( x=\frac{\sqrt{2}}{2} \)のとき極小値\( 0 \)をとる</li><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。不足もありますし，取り違えてもいます。"><input type="radio" name="preview76">\( x=\frac{\sqrt{2}}{2} \)のとき極大値\( 0 \)をとる</li><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。不足もありますし，取り違えてもいます。"><input type="radio" name="preview76">\( x=- \sqrt{3} \)のとき極大値\( \sqrt{5} \)をとる</li><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。取り違えています。"><input type="radio" name="preview76">\( x=- \sqrt{3} \)のとき極小値\( \sqrt{5} \)，\( x=\frac{\sqrt{2}}{2} \)のとき極大値\( 0 \)をとる</li><li title="点数:100"><input type="radio" name="preview76">\( x=- \sqrt{3} \)のとき極大値\( \sqrt{5} \)，\( x=\frac{\sqrt{2}}{2} \)のとき極小値\( 0 \)をとる</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。<br />\( \begin{array}{|c|c|c|c|c|c|c|c|}\hline x&\cdots&- \frac{\sqrt{7}}{2}&\cdots&\sqrt{2}&\cdots&2&\cdots\\\hline f'(x)&-&0&+&0&+&0&-\\\hline f(x)&&\frac{1}{2}&&\frac{5}{2}&&3&\\\hline\end{array} \)<div style="text-align:right;font-size:smaller">（問題整理番号:197）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。多すぎます。"><input type="radio" name="preview197">\( x=- \frac{\sqrt{7}}{2} \)のとき極小値\( \frac{1}{2} \)，\( x=\sqrt{2} \)のとき極小値\( \frac{5}{2} \)，\( x=2 \)のとき極大値\( 3 \)をとる</li><li title="点数:0
# フィードバック:極大と極小の定義を確認しましょう。取り違えています。"><input type="radio" name="preview197">\( x=- \frac{\sqrt{7}}{2} \)のとき極大値\( \frac{1}{2} \)，\( x=2 \)のとき極小値\( 3 \)をとる</li

# %%
if __name__ == "__main__":
    pass
    #qz.save('local_minimum_maximum.xml')

# %% [markdown]
# ## inflection points

# %%
class inflection_points(core.Question):
    name = '変曲点（増減表からの決定）'    
    def __init__(self, emax=5, nmin=1, nmax=2, srate=0.5):
        # 生成するdf=0の個数範囲
        self.nsp_min = nmin
        self.nsp_max = nmax
        # 左端と右端に変曲点がある確率
        self.slope_ratio = srate
        # 数の生成
        self.numbers = list(range(0,emax+1)) + [sympy.sqrt(sympy.prime(i)) for i in range(1,emax)] + [sympy.pi, sympy.E]
        self.numbers = self.numbers + [_e/sympy.Integer(2) for _e in self.numbers]
        self.numbers = self.numbers + [-_e for _e in self.numbers]
        self.numbers = sorted(list(set(self.numbers)))
    def random_interval(self, x0, x1):
        if x0 == sympy.nan:
            _i0 = -1
        else:
            _i0 = self.numbers.index(x0)
        if x1 == sympy.nan:
            _i1 = len(self.numbers)
        else:
            _i1 = self.numbers.index(x1)
        if _i1 == 0:
            return self.numbers[0] - 1
        elif _i0 == len(self.numbers) - 1:
            return self.numbers[-1] + 1
        elif _i0 + 1 < _i1:
            return random.choice(self.numbers[_i0+1:_i1])
        else:
            return (x0+x1)/sympy.Integer(2)
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='変曲点', quiz_number=_quiz_number)
        _number_of_sp = random.randint(self.nsp_min, self.nsp_max)
        _spxs = sorted(random.sample(self.numbers, k=_number_of_sp))
        _spys = random.sample(self.numbers, k=_number_of_sp)
        _intervals = [[_spys[i],_spys[i+1]] for i in range(len(_spys)-1)]
        _spss = [random.choice([1,-1])] + [1 if _y[0] <= _y[1] else -1 for _y in _intervals] + [random.choice([1,-1])]
        _matrix = sympy.zeros(4,4*_number_of_sp-1)*sympy.nan
        for i in range(_number_of_sp):
            _matrix[0,4*i+1] = _spxs[i] 
            _matrix[1,4*i] = _spss[i]
            _matrix[1,4*i+1] = 0
            _matrix[1,4*i+2] = _spss[i+1]
            if _spss[i] == _spss[i+1]:
                _matrix[2,4*i+1] = 0
            _matrix[3,4*i+1] = _spys[i]
        for i in range(_number_of_sp-1):
            _matrix[0,4*i+3] = self.random_interval(_spxs[i],_spxs[i+1])
            _matrix[1,4*i+3] = _spss[i+1]
            _matrix[2,4*i+3] = 0
            _matrix[3,4*i+3] = self.random_interval(_spys[i],_spys[i+1])
        if random.random() < self.slope_ratio:
            _matrix = _matrix.col_insert(0, sympy.Matrix([self.random_interval(sympy.nan,_spxs[0]), _spss[0], 0, self.random_interval(sympy.nan,_spys[0])]))
            _matrix = _matrix.col_insert(0, sympy.Matrix([sympy.nan, _spss[0], sympy.nan, sympy.nan]))
        if random.random() < self.slope_ratio:
            _matrix = _matrix.col_insert(_matrix.cols, sympy.Matrix([self.random_interval(_spxs[-1], sympy.nan), _spss[-1], 0, self.random_interval(_spys[-1], sympy.nan)]))
            _matrix = _matrix.col_insert(_matrix.cols, sympy.Matrix([sympy.nan, _spss[-1], sympy.nan, sympy.nan]))
        _preserved = []
        for i in range(_matrix.cols):
            if _matrix[2,i] != 0:
                _preserved.append(i)
            if _matrix[2,i] == 0 or i == _matrix.cols - 1:
                if len(_preserved) > 1:
                    if _matrix[1,_preserved[0]] > 0 and _matrix[1,_preserved[-1]] < 0:
                        for j in _preserved:
                            _matrix[2,j] = -1
                        _preserved = []
                        continue
                    elif _matrix[1,_preserved[0]] < 0 and _matrix[1,_preserved[-1]] > 0:
                        for j in _preserved:
                            _matrix[2,j] = 1
                        _preserved = []
                        continue
                for j in _preserved:
                    is_left_zero = False
                    is_right_zero = False
                    if j != 0:
                        if _matrix[1,j-1] == 0:
                            is_left_zero = True
                    if j != _matrix.cols - 1:
                        if _matrix[1,j+1] == 0:
                            is_right_zero = True
                    if is_left_zero:
                        _matrix[2,j] = _matrix[1,j]
                    if is_right_zero:
                        _matrix[2,j] = -1*_matrix[1,j]       
                _preserved = []
        if not _matrix[2,0].is_real:
            _matrix[2,0] = _matrix[1,0]
        if not _matrix[2,_matrix.cols - 1].is_real:
            _matrix[2,_matrix.cols - 1] = -1*_matrix[1,_matrix.cols - 1]
        quiz.quiz_identifier = hash(str(_matrix))
        # 正答の選択肢の生成
        _inflections = []
        for i in range(_matrix.cols):
            if _matrix[2,i] == 0:
                if _matrix[2,i-1]*_matrix[2,i+1] < 0:
                    _inflections.append(_matrix[0,i])
        quiz.data = [_matrix, _inflections]
        ans = { 'fraction': 100, 'data': _inflections }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_matrix, _inflections] = quiz.data
        if len(_inflections) > 0:
            ans['feedback'] = r'増減表をきちんと確認してください。変曲点をもちます。'
            ans['data'] = list()
            answers.append(dict(ans))
        _incorrect = []
        for i in range(_matrix.cols):
            if _matrix[1,i] == 0:
                if _matrix[1,i-1]*_matrix[1,i+1] < 0:
                    _incorrect.append(_matrix[0,i])
        if _incorrect != _inflections:
            ans['feedback'] = r'変曲点と極値をもつ点を混同しないようにしましょう。'
            ans['data'] = _incorrect
            answers.append(dict(ans))
        _incorrect = []
        for i in range(_matrix.cols):
            if _matrix[1,i] == 0:
                _incorrect.append(_matrix[0,i])
        if _incorrect != _inflections:
            ans['feedback'] = r'変曲点と極値の必要条件の点を混同しないようにしましょう。'
            ans['data'] = _incorrect
            answers.append(dict(ans))
        _incorrect = []
        for i in range(_matrix.cols):
            if _matrix[2,i] == 0:
                _incorrect.append(_matrix[0,i])
        if _incorrect != _inflections:
            ans['feedback'] = r'変曲点の定義を確認しましょう。'
            ans['data'] = _incorrect
            answers.append(dict(ans))
        answers = common.answer_union(answers)
        additional_answers = []
        ans['feedback'] = r'変曲点の定義や増減表の見方などを確認してください。'
        _incorrect_numbers = []
        for i in range(_matrix.cols):
            if _matrix[0,i].is_real:
                _incorrect_numbers.append(_matrix[0,i])
                if _inflections != [_matrix[0,i]]:
                    ans['data'] = [_matrix[0,i]]
                    additional_answers.append(dict(ans))
            if _matrix[3,i].is_real:
                _incorrect_numbers.append(_matrix[3,i])
                if _inflections != [_matrix[3,i]]:
                    ans['data'] = [_matrix[3,i]]
                    additional_answers.append(dict(ans))                    
        if len(_incorrect_numbers) < 2:
            _incorrect_numbers.append(_incorrect_numbers[0]+1)
        for i in range(size):
            _incorrect = sorted(random.sample(_incorrect_numbers, k=2))
            if _incorrect != _inflections:
                ans['data'] = _incorrect
                additional_answers.append(dict(ans))                    
        additional_answers = common.answer_union(additional_answers)
        if len(additional_answers) > len(answers):
            additional_answers = random.sample(additional_answers, k=max(len(answers),min(size-len(answers),len(additional_answers))))
        answers = answers + additional_answers
        answers = common.answer_union(answers)
        if len(answers) > size:
            answers = random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_matrix, _inflections] = quiz.data
        _text = r'以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。'
        _text += r'<br />\( \begin{array}{'
        for i in range(_matrix.cols + 1):
            _text += r'|c'
        _text += r'|}\hline '
        _text += r'x'
        for i in range(_matrix.cols):
            if _matrix[0,i].is_real:
                _text += r'&' + sympy.latex(_matrix[0,i])
            else:
                _text += r'&\cdots'
        _text += r"\\\hline f'(x)"
        for i in range(_matrix.cols):
            if _matrix[1,i].is_real:
                if _matrix[1,i] > 0:
                    _text += r'&+'
                elif _matrix[1,i] < 0:
                    _text += r'&-'
                else:
                    _text += r'&0'
            else:
                _text += r'&'
        _text += r"\\\hline f''(x)"
        for i in range(_matrix.cols):
            if _matrix[2,i].is_real:
                if _matrix[2,i] > 0:
                    _text += r'&+'
                elif _matrix[2,i] < 0:
                    _text += r'&-'
                else:
                    _text += r'&0'
            else:
                _text += r'&'
        _text += r'\\\hline f(x)'
        for i in range(_matrix.cols):
            if _matrix[3,i].is_real:
                _text += r'&' + sympy.latex(_matrix[3,i])
            else:
                _text += r'&'
        _text += r"\\\hline"
        _text += r'\end{array} \)'
        return _text
    def answer_text(self, ans):
        _inflections = ans['data']
        if len(_inflections) == 0:
            return r'変曲点をもたない'
        _text = r'\( x='
        for _x in _inflections:
            _text += sympy.latex(_x) + r','
        _text = _text[:-1]
        _text += r' \)で変曲点をもつ'
        return _text

# %%
if __name__ == "__main__":
    q = inflection_points()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=5)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。<br />\( \begin{array}{|c|c|c|c|c|c|c|c|}\hline x&\cdots&- \frac{3}{2}&\cdots&3&\cdots&5&\cdots\\\hline f'(x)&-&0&-&-&-&0&+\\\hline f''(x)&+&0&-&0&+&+&+\\\hline f(x)&&5&&6&&- \frac{\sqrt{7}}{2}&\\\hline\end{array} \)<div style="text-align:right;font-size:smaller">（問題整理番号:066）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:増減表をきちんと確認してください。変曲点をもちます。"><input type="radio" name="preview66">変曲点をもたない</li><li title="点数:100"><input type="radio" name="preview66">\( x=- \frac{3}{2},3 \)で変曲点をもつ</li><li title="点数:0
# フィードバック:変曲点の定義や増減表の見方などを確認してください。"><input type="radio" name="preview66">\( x=3 \)で変曲点をもつ</li><li title="点数:0
# フィードバック:変曲点と極値をもつ点を混同しないようにしましょう。"><input type="radio" name="preview66">\( x=5 \)で変曲点をもつ</li><li title="点数:0
# フィードバック:変曲点と極値の必要条件の点を混同しないようにしましょう。"><input type="radio" name="preview66">\( x=- \frac{3}{2},5 \)で変曲点をもつ</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。<br />\( \begin{array}{|c|c|c|c|c|c|c|c|}\hline x&\cdots&-2&\cdots&\frac{\sqrt{3}}{2}&\cdots&\frac{3}{2}&\cdots\\\hline f'(x)&+&0&-&-&-&0&-\\\hline f''(x)&-&-&-&0&+&0&-\\\hline f(x)&&\sqrt{3}&&- \frac{\sqrt{7}}{4} + \frac{\sqrt{3}}{2}&&- \frac{\sqrt{7}}{2}&\\\hline\end{array} \)<div style="text-align:right;font-size:smaller">（問題整理番号:004）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview4">\( x=\frac{\sqrt{3}}{2},\frac{3}{2} \)で変曲点をもつ</li><li title="点数:0
# フィードバック:変曲点の定義や増減表の見方などを確認してください。"><input type="radio" name="preview4">\( x=- \frac{\sqrt{7}}{4} + \frac{\sqrt{3}}{2},\frac{\sqrt{3}}{2} \)で変曲点をもつ</li><li title="点数:0
# フィードバック:増減表をきちんと確認してください。変曲点をもちます。"><input type="radio" name="preview4">変曲点をもたない</li><li title="点数:0
# フィードバック:変曲点と極値をもつ点を混同しないようにしましょう。"><input type="radio" name="preview4">\( x=-2 \)で変曲点をもつ</li><li title="点数:0
# フィードバック:変曲点の定義や増減表の見方などを確認してください。"><input type="radio" name="preview4">\( x=-2,- \frac{\sqrt{7}}{2} \)で変曲点をもつ</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。<br />\( \begin{array}{|c|c|c|c|c|c|}\hline x&\cdots&- \frac{3}{2}&\cdots&\sqrt{2}&\cdots\\\hline f'(x)&-&-&-&0&+\\\hline f''(x)&-&0&+&+&+\\\hline f(x)&&- \frac{5}{2}&&\sqrt{7}&\\\hline\end{array} \)<div style="text-align:right;font-size:smaller">（問題整理番号:126）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:増減表をきちんと確認してください。変曲点をもちます。"><input type="radio" name="preview126">変曲点をもたない</li><li title="点数:0
# フィードバック:変曲点の定義や増減表の見方などを確認してください。"><input type="radio" name="preview126">\( x=- \frac{5}{2} \)で変曲点をもつ</li><li title="点数:0
# フィードバック:変曲点と極値をもつ点を混同しないようにしましょう。"><input type="radio" name="preview126">\( x=\sqrt{2} \)で変曲点をもつ</li><li title="点数:100"><input type="radio" name="preview126">\( x=- \frac{3}{2} \)で変曲点をもつ</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。<br />\( \begin{array}{|c|c|c|c|c|c|c|c|c|c|}\hline x&\cdots&-5&\cdots&- \frac{\pi}{2}&\cdots&- \frac{\sqrt{7}}{2}&\cdots&- \frac{\sqrt{3}}{2}&\cdots\\\hline f'(x)&+&+&+&0&-&-&-&0&+\\\hline f''(x)&+&0&-&-&-&0&+&+&+\\\hline f(x)&&- \frac{\sqrt{5}}{2}&&\frac{3}{2}&&\frac{1}{4}&&-1&\\\hline\end{array} \)<div style="text-align:right;font-size:smaller">（問題整理番号:188）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview188">\( x=-5,- \frac{\sqrt{7}}{2} \)で変曲点をもつ</li><li title="点数:0
# フィードバック:変曲点と極値をもつ点を混同しないようにしましょう。"><input type="radio" name="preview188">\( x=- \frac{\pi}{2},- \frac{\sqrt{3}}{2} \)で変曲点をもつ</li><li title="点数:0
# フィードバック:変曲点の定義や増減表の見方などを確認してください。"><input type="radio" name="preview188">\( x=-5,\frac{3}{2} \)で変曲点をもつ</li><li title="点数:0
# フィードバック:変曲点の定義や増減表の見方などを確認してください。"><input type="radio" name="preview188">\( x=- \frac{\pi}{2},- \frac{\sqrt{7}}{2} \)で変曲点をもつ</li><li title="点数:0
# フィードバック:増減表をきちんと確認してください。変曲点をもちます。"><input type="radio" name="preview188">変曲点をもたない</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">以下は，ある関数\( f(x) \)の増減表です。\( f(x) \)に関して最も適切なものを選択してください。<br />\( \begin{array}{|c|c|c|c|c|c|c|c|}\hline x&\cdots&-4&\cdots&\sqrt{2}&\cdots&\frac{\pi}{2}&\cdots\\\hline f'(x)&+&+&+&0&-&-&-\\\hline f''(x)&+&0&-&-&-&0&+\\\hline f(x)&&-4&&-3&&\frac{\pi}{2}&\\\hline\end{array} \)<div style="text-align:right;font-size:smaller">（問題整理番号:119）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview119">\( x=-4,\frac{\pi}{2} \)で変曲点をもつ</li><li title="点数:0
# フィードバック:変曲点の定義や増減表の見方などを確認してください。"><input type="radio" name="preview119">\( x=-3,\frac{\pi}{2} \)で変曲点をもつ</li><li title="点数:0
# フィードバック:増減表をきちんと確認してください。変曲点をもちます。"><input type="radio" name="preview119">変曲点をもたない</li><li title="点数:0
# フィードバック:変曲点と極値をもつ点を混同しないようにしましょう。"><input type="radio" name="preview119">\( x=\sqrt{2} \)で変曲点をもつ</li><li title="点数:0
# フィードバック:変曲点の定義や増減表の見方などを確認してください。"><input type="radio" name="preview119">\( x=-3 \)で変曲点をもつ</li></ol></div></div>

# %%
if __name__ == "__main__":
    pass
    #qz.save('inflection_points.xml')

# %% [markdown]
# ## power series expansion

# %%
class power_series_expansion(core.Question):
    name = '級数展開（マクローリンとテイラー展開）'
    _x = sympy.Symbol('x')
    def __init__(self, emin=-3, emax=3, nmin=2, nmax=4, amin=-2, amax=2, azero=True, omin=1, omax=3):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 展開点の範囲
        self.epnt_min = amin
        self.epnt_max = amax
        self.epnt_zero = azero
        # 多項式関数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 展開次数
        self.ord_min = omin
        self.ord_max = omax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='級数展開', quiz_number=_quiz_number)
        _type = random.choice(['polynomial', 'sin', 'cos', 'exp', 'aexp', 'rational', 'log'])
        while _type == 'log' and self.epnt_min == self.epnt_max and self.epnt_min == 0:
            _type = random.choice(['polynomial', 'sin', 'cos', 'exp', 'aexp', 'rational', 'log'])
        if _type == 'polynomial':
            _func = sympy.Integer(0)
            while _func == 0 or _func.is_real:
                for i in range(random.randint(self.deg_min, self.deg_max)+1):
                    _func = _func + random.randint(self.elem_min, self.elem_max)*self._x**i
            if self.epnt_zero:
                _point = random.randint(self.epnt_min, self.epnt_max)
            else:
                _point = nonzero_randint(self.epnt_min, self.epnt_max)
        elif _type == 'sin':
            _func = nonzero_randint(self.elem_min, self.elem_max)*sympy.sin(nonzero_randint(self.elem_min, self.elem_max)*self._x)
            _point = sympy.pi*random.randint(3*self.epnt_min, 3*self.epnt_max)/sympy.Integer(3)
            while _point == 0 and not self.epnt_zero:
                _point = sympy.pi*random.randint(3*self.epnt_min, 3*self.epnt_max)/sympy.Integer(3)
        elif _type == 'cos':
            _func = nonzero_randint(self.elem_min, self.elem_max)*sympy.sin(nonzero_randint(self.elem_min, self.elem_max)*self._x)
            _point = sympy.pi*random.randint(3*self.epnt_min, 3*self.epnt_max)/sympy.Integer(3)
            while _point == 0 and not self.epnt_zero:
                _point = sympy.pi*random.randint(3*self.epnt_min, 3*self.epnt_max)/sympy.Integer(3)
        elif _type == 'exp':
            _func = nonzero_randint(self.elem_min, self.elem_max)*sympy.exp(nonzero_randint(self.elem_min, self.elem_max)*self._x)
            _point = random.randint(self.epnt_min, self.epnt_max)
            while _point == 0 and not self.epnt_zero:
                _point = random.randint(self.epnt_min, self.epnt_max)
        elif _type == 'aexp':
            _func = nonzero_randint(self.elem_min, self.elem_max)*nonone_randpint(self.elem_min, self.elem_max)**(nonzero_randint(self.elem_min, self.elem_max)*self._x)
            _point = random.randint(self.epnt_min, self.epnt_max)
            while _point == 0 and not self.epnt_zero:
                _point = random.randint(self.epnt_min, self.epnt_max)
        elif _type == 'log':
            _func = nonzero_randint(self.elem_min, self.elem_max)*sympy.log(abs(nonzero_randint(self.elem_min, self.elem_max))*self._x)
            _point = abs(nonzero_randint(self.epnt_min, self.epnt_max))
            while _point == 0 and not self.epnt_zero:
                _point = abs(nonzero_randint(self.epnt_min, self.epnt_max))
        else:
            _point = random.randint(self.epnt_min, self.epnt_max)
            while _point == 0 and not self.epnt_zero:
                _point = random.randint(self.epnt_min, self.epnt_max)
            _func = sympy.Integer(0)
            while _func.subs(self._x, _point) == 0:
                _func = sympy.Integer(0)
                while _func == 0 or _func.is_real:
                    for i in range(2):
                        _func = _func + random.randint(self.elem_min, self.elem_max)*self._x**i
            _func = sympy.Integer(1)/_func
        _order = random.randint(self.ord_min, self.ord_max)
        quiz.quiz_identifier = hash(str(_func) + str(_point) + str(_order))
        # 正答の選択肢の生成
        _series = _func.series(x=self._x, x0=_point, n=_order+1).removeO()        
        quiz.data = [_func, _point, _order, _series]
        ans = { 'fraction': 100, 'data': _series }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def _incorrect_series_expansion_by_factorial(self, _func, _point, _order):
        _incorrect = 0
        for i in range(_order+1):
            _incorrect = _incorrect + sympy.diff(_func,self._x,i).subs(self._x,_point)*(self._x-_point)**i
        return _incorrect
    def _incorrect_series_expansion_by_factorial2(self, _func, _point, _order):
        _incorrect = 0
        for i in range(_order+1):
            _incorrect = _incorrect + (1 if i == 0 else 1/sympy.Integer(i))*sympy.diff(_func,self._x,i).subs(self._x,_point)*(self._x-_point)**i
        return _incorrect
    def _incorrect_series_expansion_by_signofa(self, _func, _point, _order):
        _incorrect = 0
        for i in range(_order+1):
            _incorrect = _incorrect + (sympy.factorial(i))*sympy.diff(_func,self._x,i).subs(self._x,_point)*(self._x+_point)**i
        return _incorrect
    def _incorrect_series_expansion_by_factorial_and_signofa(self, _func, _point, _order):
        _incorrect = 0
        for i in range(_order+1):
            _incorrect = _incorrect + sympy.diff(_func,self._x,i).subs(self._x,_point)*(self._x+_point)**i
        return _incorrect
    def _incorrect_series_expansion_by_factorial2_and_signofa(self, _func, _point, _order):
        _incorrect = 0
        for i in range(_order+1):
            _incorrect = _incorrect + (1 if i == 0 else 1/sympy.Integer(i))*sympy.diff(_func,self._x,i).subs(self._x,_point)*(self._x+_point)**i
        return _incorrect
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_func, _point, _order, _series] = quiz.data
        for _n in range(2,_order+2):
            _incorrect = _func.series(x=self._x, x0=_point, n=_n).removeO()   
            if _incorrect != _series:
                ans['feedback'] = r'剰余項を除き，指定された次数の多項式として近似してください。'
                ans['data'] = _incorrect
                answers.append(dict(ans))
            _incorrect = self._incorrect_series_expansion_by_factorial(_func, _point, _n)   
            if _incorrect != _series:
                ans['feedback'] = r'展開に関する公式を確認しましょう。特に階乗部分を確認してください。'
                ans['data'] = _incorrect
                answers.append(dict(ans))
            _incorrect = self._incorrect_series_expansion_by_factorial2(_func, _point, _n)   
            if _incorrect != _series:
                ans['feedback'] = r'展開に関する公式を確認しましょう。特に階乗部分を確認してください。'
                ans['data'] = _incorrect
                answers.append(dict(ans))
        if _point != 0:
            for _n in range(2,_order+2):
                _incorrect = self._incorrect_series_expansion_by_signofa(_func, _point, _n)   
                if _incorrect != _series:
                    ans['feedback'] = r'展開に関する公式を確認しましょう。特に展開点に関する確認してください。'
                    ans['data'] = _incorrect
                    answers.append(dict(ans))
                _incorrect = self._incorrect_series_expansion_by_factorial_and_signofa(_func, _point, _n)   
                if _incorrect != _series:
                    ans['feedback'] = r'展開に関する公式を確認しましょう。かなり誤解している可能性があります。'
                    ans['data'] = _incorrect
                    answers.append(dict(ans))
                _incorrect = self._incorrect_series_expansion_by_factorial2_and_signofa(_func, _point, _n)   
                if _incorrect != _series:
                    ans['feedback'] = r'展開に関する公式を確認しましょう。かなり誤解している可能性があります。'
                    ans['data'] = _incorrect
                    answers.append(dict(ans))
        answers = common.answer_union(answers)
        while len(answers) < size:
            _incorrect = _series + random.randint(self.elem_min, self.elem_max)
            if _incorrect != _series:
                ans['feedback'] = r'展開に関する公式を確認しましょう。'
                ans['data'] = _incorrect
                answers.append(dict(ans))
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_func, _point, _order, _series] = quiz.data
        _text = r'次の関数\( f(x) \)の'
        if _point == 0:
            _text += r'マクローリン展開による'
        else:
            _text += r'\( x=' + sympy.latex(_point) + r' \)のまわりでのテイラー展開による'
        _text += r'\( ' + sympy.latex(_order) + r' \)次多項式としての近似を選択してください。<br />'
        _text += r'\( f(x)=' + sympy.latex(_func,  order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' +  sympy.latex(ans['data'], order='lex', long_frac_ratio=1) + r' \)'

# %%
if __name__ == "__main__":
    q = power_series_expansion(emin=-4, emax=4, amin=0, amax=0)
    qz = core.generate(q, size=200, category=r'マクローリン展開')
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)のマクローリン展開による\( 2 \)次多項式としての近似を選択してください。<br />\( f(x)=2^{3 x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:071）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview71">\( \frac{9}{2} x^{2} \log{\left(2 \right)}^{2} + 3 x \log{\left(2 \right)} + 1 \)</li><li title="点数:0
# フィードバック:剰余項を除き，指定された次数の多項式として近似してください。"><input type="radio" name="preview71">\( 3 x \log{\left(2 \right)} + 1 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview71">\( 9 x^{3} \log{\left(2 \right)}^{3} + \frac{9}{2} x^{2} \log{\left(2 \right)}^{2} + 3 x \log{\left(2 \right)} + 1 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview71">\( 27 x^{3} \log{\left(2 \right)}^{3} + 9 x^{2} \log{\left(2 \right)}^{2} + 3 x \log{\left(2 \right)} + 1 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview71">\( 9 x^{2} \log{\left(2 \right)}^{2} + 3 x \log{\left(2 \right)} + 1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)のマクローリン展開による\( 1 \)次多項式としての近似を選択してください。<br />\( f(x)=- 3 \sin{\left(2 x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:011）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。"><input type="radio" name="preview11">\( - 6 x - 3 \)</li><li title="点数:100"><input type="radio" name="preview11">\( - 6 x \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。"><input type="radio" name="preview11">\( - 6 x + 4 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。"><input type="radio" name="preview11">\( - 6 x - 2 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。"><input type="radio" name="preview11">\( - 6 x - 4 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)のマクローリン展開による\( 1 \)次多項式としての近似を選択してください。<br />\( f(x)=- 2 e^{- 4 x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:178）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview178">\( 8 x - 2 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。"><input type="radio" name="preview178">\( 8 x + 2 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview178">\( - 16 x^{2} + 8 x - 2 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview178">\( - 32 x^{2} + 8 x - 2 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。"><input type="radio" name="preview178">\( 8 x \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)のマクローリン展開による\( 2 \)次多項式としての近似を選択してください。<br />\( f(x)=- e^{- 4 x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:124）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview124">\( - 16 x^{2} + 4 x - 1 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview124">\( 64 x^{3} - 16 x^{2} + 4 x - 1 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview124">\( \frac{64}{3} x^{3} - 8 x^{2} + 4 x - 1 \)</li><li title="点数:100"><input type="radio" name="preview124">\( - 8 x^{2} + 4 x - 1 \)</li><li title="点数:0
# フィードバック:剰余項を除き，指定された次数の多項式として近似してください。"><input type="radio" name="preview124">\( 4 x - 1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)のマクローリン展開による\( 1 \)次多項式としての近似を選択してください。<br />\( f(x)=\frac{1}{- 4 x + 4} \)<div style="text-align:right;font-size:smaller">（問題整理番号:110）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。"><input type="radio" name="preview110">\( \frac{x}{4} + \frac{13}{4} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview110">\( \frac{x^{2}}{2} + \frac{x}{4} + \frac{1}{4} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。"><input type="radio" name="preview110">\( \frac{x}{4} + \frac{9}{4} \)</li><li title="点数:100"><input type="radio" name="preview110">\( \frac{x}{4} + \frac{1}{4} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview110">\( \frac{x^{2}}{4} + \frac{x}{4} + \frac{1}{4} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)のマクローリン展開による\( 3 \)次多項式としての近似を選択してください。<br />\( f(x)=\frac{1}{3 x - 2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:066）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview66">\( - \frac{9}{4} x^{2} - \frac{3}{4} x - \frac{1}{2} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview66">\( - \frac{9}{8} x^{2} - \frac{3}{4} x - \frac{1}{2} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview66">\( - \frac{81}{8} x^{3} - \frac{9}{4} x^{2} - \frac{3}{4} x - \frac{1}{2} \)</li><li title="点数:100"><input type="radio" name="preview66">\( - \frac{27}{16} x^{3} - \frac{9}{8} x^{2} - \frac{3}{4} x - \frac{1}{2} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview66">\( - \frac{243}{16} x^{4} - \frac{27}{8} x^{3} - \frac{9}{8} x^{2} - \frac{3}{4} x - \frac{1}{2} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)のマクローリン展開による\( 1 \)次多項式としての近似を選択してください。<br />\( f(x)=- x^{2} + x - 3 \)<div style="text-align:right;font-size:smaller">（問題整理番号:068）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview68">\( x - 3 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview68">\( - x^{2} + x - 3 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。"><input type="radio" name="preview68">\( x - 6 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。"><input type="radio" name="preview68">\( x - 2 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview68">\( - 2 x^{2} + x - 3 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)のマクローリン展開による\( 2 \)次多項式としての近似を選択してください。<br />\( f(x)=x^{4} - x^{2} - 4 x - 1 \)<div style="text-align:right;font-size:smaller">（問題整理番号:055）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。"><input type="radio" name="preview55">\( - x^{2} - 4 x + 3 \)</li><li title="点数:0
# フィードバック:剰余項を除き，指定された次数の多項式として近似してください。"><input type="radio" name="preview55">\( - 4 x - 1 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。"><input type="radio" name="preview55">\( - x^{2} - 4 x + 2 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview55">\( - 2 x^{2} - 4 x - 1 \)</li><li title="点数:100"><input type="radio" name="preview55">\( - x^{2} - 4 x - 1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)のマ

# %%
if __name__ == "__main__":
    pass
    #qz.save('power_series_expansion_maclaurin.xml')

# %%
if __name__ == "__main__":
    q = power_series_expansion(emin=-3, emax=3, amin=-2, amax=2, azero=False)
    qz = core.generate(q, size=200, category=r'テイラー展開')
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=\frac{2 \pi}{3} \)のまわりでのテイラー展開による\( 2 \)次多項式としての近似を選択してください。<br />\( f(x)=2 \sin{\left(2 x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:095）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。かなり誤解している可能性があります。"><input type="radio" name="preview95">\( - 2 x + 4 \sqrt{3} \left(x + \frac{2}{3} \pi\right)^{2} - \frac{4}{3} \pi - \sqrt{3} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に展開点に関する確認してください。"><input type="radio" name="preview95">\( - 2 x + 48 \left(x + \frac{2}{3} \pi\right)^{3} + 8 \sqrt{3} \left(x + \frac{2}{3} \pi\right)^{2} - \frac{4}{3} \pi - \sqrt{3} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。かなり誤解している可能性があります。"><input type="radio" name="preview95">\( - 2 x + \frac{8}{3} \left(x + \frac{2}{3} \pi\right)^{3} + 2 \sqrt{3} \left(x + \frac{2}{3} \pi\right)^{2} - \frac{4}{3} \pi - \sqrt{3} \)</li><li title="点数:100"><input type="radio" name="preview95">\( - 2 x + 2 \sqrt{3} \left(x - \frac{2}{3} \pi\right)^{2} - \sqrt{3} + \frac{4}{3} \pi \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。かなり誤解している可能性があります。"><input type="radio" name="preview95">\( - 2 x + 8 \left(x + \frac{2}{3} \pi\right)^{3} + 4 \sqrt{3} \left(x + \frac{2}{3} \pi\right)^{2} - \frac{4}{3} \pi - \sqrt{3} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=2 \)のまわりでのテイラー展開による\( 1 \)次多項式としての近似を選択してください。<br />\( f(x)=- 3 e^{3 x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:082）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview82">\( - 9 \left(x - 2\right) e^{6} - 3 e^{6} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。かなり誤解している可能性があります。"><input type="radio" name="preview82">\( - \frac{27}{2} \left(x + 2\right)^{2} e^{6} - 9 \left(x + 2\right) e^{6} - 3 e^{6} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview82">\( - 27 \left(x - 2\right)^{2} e^{6} - 9 \left(x - 2\right) e^{6} - 3 e^{6} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview82">\( - \frac{27}{2} \left(x - 2\right)^{2} e^{6} - 9 \left(x - 2\right) e^{6} - 3 e^{6} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。かなり誤解している可能性があります。"><input type="radio" name="preview82">\( - 27 \left(x + 2\right)^{2} e^{6} - 9 \left(x + 2\right) e^{6} - 3 e^{6} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=-2 \)のまわりでのテイラー展開による\( 2 \)次多項式としての近似を選択してください。<br />\( f(x)=3 e^{3 x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:092）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:剰余項を除き，指定された次数の多項式として近似してください。"><input type="radio" name="preview92">\( \frac{9}{e^{6}} \left(x + 2\right) + \frac{3}{e^{6}} \)</li><li title="点数:100"><input type="radio" name="preview92">\( \frac{27}{2 e^{6}} \left(x + 2\right)^{2} + \frac{9}{e^{6}} \left(x + 2\right) + \frac{3}{e^{6}} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に展開点に関する確認してください。"><input type="radio" name="preview92">\( \frac{486}{e^{6}} \left(x - 2\right)^{3} + \frac{54}{e^{6}} \left(x - 2\right)^{2} + \frac{9}{e^{6}} \left(x - 2\right) + \frac{3}{e^{6}} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview92">\( \frac{27}{e^{6}} \left(x + 2\right)^{2} + \frac{9}{e^{6}} \left(x + 2\right) + \frac{3}{e^{6}} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。かなり誤解している可能性があります。"><input type="radio" name="preview92">\( \frac{81}{e^{6}} \left(x - 2\right)^{3} + \frac{27}{e^{6}} \left(x - 2\right)^{2} + \frac{9}{e^{6}} \left(x - 2\right) + \frac{3}{e^{6}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=1 \)のまわりでのテイラー展開による\( 1 \)次多項式としての近似を選択してください。<br />\( f(x)=\frac{1}{2 x - 1} \)<div style="text-align:right;font-size:smaller">（問題整理番号:083）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。かなり誤解している可能性があります。"><input type="radio" name="preview83">\( - 2 x + 8 \left(x + 1\right)^{2} - 1 \)</li><li title="点数:100"><input type="radio" name="preview83">\( - 2 x + 3 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview83">\( - 2 x + 8 \left(x - 1\right)^{2} + 3 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に展開点に関する確認してください。"><input type="radio" name="preview83">\( - 2 x + 16 \left(x + 1\right)^{2} - 1 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview83">\( - 2 x + 4 \left(x - 1\right)^{2} + 3 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=1 \)のまわりでのテイラー展開による\( 3 \)次多項式としての近似を選択してください。<br />\( f(x)=\frac{1}{- 3 x - 1} \)<div style="text-align:right;font-size:smaller">（問題整理番号:144）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。かなり誤解している可能性があります。"><input type="radio" name="preview144">\( \frac{3}{16} x - \frac{9}{32} \left(x + 1\right)^{2} - \frac{1}{16} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview144">\( \frac{3}{16} x - \frac{9}{64} \left(x - 1\right)^{2} - \frac{7}{16} \)</li><li title="点数:100"><input type="radio" name="preview144">\( \frac{3}{16} x + \frac{27}{256} \left(x - 1\right)^{3} - \frac{9}{64} \left(x - 1\right)^{2} - \frac{7}{16} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。かなり誤解している可能性があります。"><input type="radio" name="preview144">\( \frac{3}{16} x + \frac{27}{128} \left(x + 1\right)^{3} - \frac{9}{64} \left(x + 1\right)^{2} - \frac{1}{16} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。かなり誤解している可能性があります。"><input type="radio" name="preview144">\( \frac{3}{16} x - \frac{243}{512} \left(x + 1\right)^{4} + \frac{27}{128} \left(x + 1\right)^{3} - \frac{9}{64} \left(x + 1\right)^{2} - \frac{1}{16} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=1 \)のまわりでのテイラー展開による\( 2 \)次多項式としての近似を選択してください。<br />\( f(x)=\log{\left(2 x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:087）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。かなり誤解している可能性があります。"><input type="radio" name="preview87">\( x - \frac{1}{2} \left(x + 1\right)^{2} + \log{\left(2 \right)} + 1 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview87">\( x + 2 \left(x - 1\right)^{3} - \left(x - 1\right)^{2} - 1 + \log{\left(2 \right)} \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。かなり誤解している可能性があります。"><input type="radio" name="preview87">\( x - \left(x + 1\right)^{2} + \log{\left(2 \right)} + 1 \)</li><li title="点数:0
# フィードバック:展開に関する公式を確認しましょう。特に階乗部分を確認してください。"><input type="radio" name="preview87">\( x + \frac{2}{3} \left(x - 1\right)^{3} - \frac{1}{2} \left(x - 1\right)^{2} - 1 + \log{\left(2 \right)} \)</li><li title="点数:100"><input type="radio" name="preview87">\( x - \frac{1}{2} \left(x - 1\right)^{2} - 1 + \log{\left(2 \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x) \)の\( x=- \frac{2 \pi}{3} \)のまわりでのテイラー展開による\( 1 \)次多項式としての近似を選択してください。<br />\( f(x)=- 2 \sin{\left(3 x \right)} \)<div style="text-align:right;font-size:smaller">（問題整理

# %%
if __name__ == "__main__":
    pass
    #qz.save('power_series_expansion_taylor.xml')

# %% [markdown]
# ## dummy

# %% [markdown]
# # All the questions

# %%
questions_str = ['composite_function', 'limit_of_polynomial_or_rational_function', 
                 'limit_of_polynomial_or_rational_function_with_nolimit', 'directional_limit_of_rational_function', 
                 'asymptotic_behavior_of_limit', 'limit_of_trigonometric_function', 'limit_of_exponential_and_logarithmic_function',
                 'average_rate_of_change', 'differential_coefficient', 'differential_coefficient_intermediate_expression',
                 'derivative_by_definition', 'derivative_by_linearity', 'derivative_by_multiplication', 'derivative_by_quotient', 
                 'derivative_by_composition', 'derivative_by_taking_logarithm', 'higher_derivative', 'local_minimum_maximum', 
                 'inflection_points', 'power_series_expansion']
questions = [eval(q) for q in questions_str]
def listview():
    fullhtml = '<ul>'
    for i in range(len(questions_str)):
        fullhtml += '<li>' + questions_str[i] + ':' + questions[i].name + '</li>'
    fullhtml += '</ul>'       
    IPython.display.display(IPython.display.HTML(fullhtml))
def generate():
    instances = []
    for q in questions:
        instances.append(q())
    return instances
