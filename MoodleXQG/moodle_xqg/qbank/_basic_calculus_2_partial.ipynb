# %% [markdown]
# Moodle XML Question Generator, (C) 2020 Kosaku Nagasaka (Kobe University)

# %% [markdown]
# ## モジュールファイルの生成

# %%
if __name__ == "__main__":
    import subprocess
    subprocess.run(['jupyter', 'nbconvert', '--to', 'python', '_basic_calculus_2_partial.ipynb','--output','basic_calculus_2_partial.py'])

# %% [markdown]
# # Basic Calculus 2 partial (differencial calculus for bivariate function)

# %%
if __name__ == "__main__":
    from inspect import getsourcefile
    import os.path
    import sys
    current_path = os.path.abspath(getsourcefile(lambda:0))
    current_dir = os.path.dirname(current_path)
    parent_dir = current_dir[:current_dir.rfind(os.path.sep)]
    sys.path.insert(0, parent_dir)
    import core
    import common
    core._force_to_this_lang = 'ja'
else:
    from .. import core
    from . import common

# %%
import sympy
import random
import IPython
import itertools
import copy

# %% [markdown]
# ## minor helpers

# %%
def nonzero_randint(imin, imax):
    if 0 < imin or imax < 0:
        return random.randint(imin, imax)
    else:
        return random.choice(list(set(range(imin,imax+1)).difference(set([0]))))

# %%
def nonone_randpint(imin, imax):
    if 1 < imin:
        return random.randint(imin, imax)
    else:
        return abs(random.choice(list(set(range(imin,imax+1)).difference(set([0,-1,1])))))

# %%
def flatten_list(alist):
    rlist = []
    for lis in alist:
        rlist = rlist + lis
    return rlist

# %%
def flatten_list_all(alist):
    if type(alist) is not list:
        return [alist]
    rlist = []
    for lis in alist:
        rlist = rlist + flatten_list_all(lis)
    return rlist

# %% [markdown]
# ## limit of bivariate polynomial

# %%
class limit_of_bivariate_polynomial(core.Question):
    name = '2変数多項式の極限（原則代入で求まる）'
    def __init__(self, emin=-3, emax=3, amin=-1, amax=1, nmin=0, nmax=3, tmin=2, tmax=4):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 極限を求めるxの値の範囲
        self.a_min = amin
        self.a_max = amax
        # 次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 単項式の個数の範囲
        self.term_min = tmin
        self.term_max = tmax
    def _function_generate(self, _varX, _varY):
        _poly = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = flatten_list([[[_i,_j] for _j in range(self.deg_min, self.deg_max+1)] for _i in range(self.deg_min, self.deg_max+1)])
        _terms = random.sample(_exps,k=_num_terms)        
        for _es in _terms:
            _poly += nonzero_randint(self.elem_min, self.elem_max)*_varX**_es[0]*_varY**_es[1]
        return _poly
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='2変数多項式の極限', quiz_number=_quiz_number)
        _varX = sympy.Symbol('x')
        _varY = sympy.Symbol('y')
        _f = self._function_generate(_varX, _varY)
        _a = random.choice(list(range(self.a_min, self.a_max+1)))
        _b = random.choice(list(range(self.a_min, self.a_max+1)))
        _limit = _f.subs(_varX,_a).subs(_varY,_b)
        quiz.quiz_identifier = hash(str(_f) + str(_a) + str(_b) + str(_limit))
        # 正答の選択肢の生成
        quiz.data = [_varX, _varY, _f, _a, _b, _limit]
        ans = { 'fraction': 100, 'data': _limit }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_varX, _varY, _f, _a, _b, _limit] = quiz.data
        ans['feedback'] = r'多項式関数の極限は存在します。'
        ans['data'] = r'極限は存在しない'
        answers.append(dict(ans))
        ans['feedback'] = r'多項式関数の有限点での極限は発散しません。'
        ans['data'] = sympy.S.Infinity
        answers.append(dict(ans))
        ans['feedback'] = r'多項式関数の有限点での極限は発散しません。'
        ans['data'] = -sympy.S.Infinity
        answers.append(dict(ans))
        if _limit != 0:
            ans['feedback'] = r'何か計算ミスをしていないでしょうか。再度確認を行いましょう。'
            ans['data'] = 0
            answers.append(dict(ans))
            ans['feedback'] = r'何か計算ミスをしていないでしょうか。再度確認を行いましょう。'
            ans['data'] = -_limit
            answers.append(dict(ans))
        while True:
            _incorrect_a = random.choice(list(range(self.a_min-1, self.a_max+2)))
            _incorrect_b = random.choice(list(range(self.a_min-1, self.a_max+2)))
            _incorrect_limit = _f.subs(_varX,_incorrect_a).subs(_varY,_incorrect_b)
            if abs(_incorrect_limit) != abs(_limit):
                break
        ans['feedback'] = r'何か計算ミスをしていないでしょうか。再度確認を行いましょう。'
        ans['data'] = _incorrect_limit
        answers.append(dict(ans))
        ans['feedback'] = r'何か計算ミスをしていないでしょうか。再度確認を行いましょう。'
        ans['data'] = -_incorrect_limit
        answers.append(dict(ans))        
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_varX, _varY, _f, _a, _b, _limit] = quiz.data
        _text = r'次の極限を選択してください。<br />'
        _text += r'\( \lim_{(x,y)\rightarrow(' + sympy.latex(_a) + r',' + sympy.latex(_b) + r')}' + sympy.latex(_f, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        if isinstance(ans['data'], str):
            return ans['data']
        else:
            return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = limit_of_bivariate_polynomial()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(1,1)}3 x^{3} + 2 y^{2} + 3 \)<div style="text-align:right;font-size:smaller">（問題整理番号:077）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:多項式関数の有限点での極限は発散しません。"><input type="radio" name="preview77">\( \infty \)</li><li title="点数:100"><input type="radio" name="preview77">\( 8 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview77">\( -8 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview77">\( -29 \)</li><li title="点数:0
# フィードバック:多項式関数の極限は存在します。"><input type="radio" name="preview77">極限は存在しない</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,-1)}- 2 x^{3} y - 3 x^{2} - x y^{2} - 2 y \)<div style="text-align:right;font-size:smaller">（問題整理番号:111）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview111">\( 16 \)</li><li title="点数:0
# フィードバック:多項式関数の極限は存在します。"><input type="radio" name="preview111">極限は存在しない</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview111">\( -16 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview111">\( 2 \)</li><li title="点数:100"><input type="radio" name="preview111">\( -2 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,-1)}- 3 x^{3} y^{3} + 2 x^{3} y + 3 y^{3} \)<div style="text-align:right;font-size:smaller">（問題整理番号:108）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview108">\( 3 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview108">\( -3 \)</li><li title="点数:100"><input type="radio" name="preview108">\( -4 \)</li><li title="点数:0
# フィードバック:多項式関数の有限点での極限は発散しません。"><input type="radio" name="preview108">\( -\infty \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview108">\( 4 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,-1)}x^{3} - 2 x y^{2} - 2 x y - 1 \)<div style="text-align:right;font-size:smaller">（問題整理番号:118）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview118">\( 2 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview118">\( -2 \)</li><li title="点数:100"><input type="radio" name="preview118">\( -1 \)</li><li title="点数:0
# フィードバック:多項式関数の有限点での極限は発散しません。"><input type="radio" name="preview118">\( \infty \)</li><li title="点数:0
# フィードバック:多項式関数の極限は存在します。"><input type="radio" name="preview118">極限は存在しない</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,-1)}- 3 x y^{3} + x \)<div style="text-align:right;font-size:smaller">（問題整理番号:185）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview185">\( 23 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview185">\( 4 \)</li><li title="点数:0
# フィードバック:多項式関数の有限点での極限は発散しません。"><input type="radio" name="preview185">\( \infty \)</li><li title="点数:100"><input type="radio" name="preview185">\( -4 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview185">\( -23 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,-1)}- 3 x y + x - 3 y^{3} \)<div style="text-align:right;font-size:smaller">（問題整理番号:050）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview50">\( -24 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview50">\( 1 \)</li><li title="点数:100"><input type="radio" name="preview50">\( -1 \)</li><li title="点数:0
# フィードバック:多項式関数の有限点での極限は発散しません。"><input type="radio" name="preview50">\( -\infty \)</li><li title="点数:0
# フィードバック:多項式関数の極限は存在します。"><input type="radio" name="preview50">極限は存在しない</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,1)}3 x^{3} y^{3} - x^{2} y^{3} - 3 y^{3} \)<div style="text-align:right;font-size:smaller">（問題整理番号:130）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:多項式関数の有限点での極限は発散しません。"><input type="radio" name="preview130">\( \infty \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview130">\( 0 \)</li><li title="点数:0
# フィードバック:多項式関数の有限点での極限は発散しません。"><input type="radio" name="preview130">\( -\infty \)</li><li title="点数:100"><input type="radio" name="preview130">\( -7 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview130">\( 7 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,-1)}3 x^{2} y^{2} + 3 x y^{2} - 3 x + 3 y^{2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:105）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview105">\( 3 \)</li><li title="点数:0
# フィードバック:多項式関数の有限点での極限は発散しません。"><input type="radio" name="preview105">\( \infty \)</li><li title="点数:0
# フィードバック:多項式関数の有限点での極限は発散しません。"><input type="radio" name="preview105">\( -\infty \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview105">\( -3 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview105">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,0)}- 3 x^{3} + 3 x^{2} y^{2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:180）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview180">\( -24 \)</li><li title="点数:100"><input type="radio" name="preview180">\( 0 \)</li><li title="点数:0
# フィードバック:多項式関数の有限点での極限は発散しません。"><input type="radio" name="preview180">\( \infty \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview180">\( 24 \)</li><li title="点数:0
# フィードバック:多項式関数の極限は存在します。"><input type="radio" name="preview180">極限は存在しない</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,1)}2 x^{3} y^{3} - 2 x^{3} y + 2 x y^{2} + y \)<div style="text-align:right;font-size:smaller">（問題整理番号:090）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview90">\( -5 \)</li><li title="点数:100"><i

# %%
if __name__ == "__main__":
    pass
    #qz.save('limit_of_bivariate_polynomial.xml')

# %% [markdown]
# ## limit of bivariate rational function approaches domain

# %%
class limit_of_bivariate_rational_function_approaches_domain(core.Question):
    name = '2変数有理関数の極限（原則代入で求まる定義域への極限）'
    def __init__(self, emin=-3, emax=3, amin=-1, amax=1, nmin=0, nmax=3, tmin=1, tmax=3):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 極限を求めるxの値の範囲
        self.a_min = amin
        self.a_max = amax
        # 次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 単項式の個数の範囲
        self.term_min = tmin
        self.term_max = tmax
    def _function_generate(self, _varX, _varY, _a, _b):
        _num = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = flatten_list([[[_i,_j] for _j in range(self.deg_min, self.deg_max+1)] for _i in range(self.deg_min, self.deg_max+1)])
        _terms = random.sample(_exps,k=_num_terms)        
        for _es in _terms:
            _num += nonzero_randint(self.elem_min, self.elem_max)*_varX**_es[0]*_varY**_es[1]
        _den = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = flatten_list([[[_i,_j] for _j in range(self.deg_min, self.deg_max+1)] for _i in range(self.deg_min, self.deg_max+1)])
        _terms = random.sample(_exps,k=_num_terms)        
        for _es in _terms:
            _den += nonzero_randint(self.elem_min, self.elem_max)*_varX**_es[0]*_varY**_es[1]
        if sympy.degree(_den, _varX) + sympy.degree(_den, _varY) <= 0:
            return self._function_generate(_varX, _varY, _a, _b)
        elif sympy.degree(_num, _varX) + sympy.degree(_num, _varY) <= 0:
            return self._function_generate(_varX, _varY, _a, _b)
        elif _den.subs(_varX,_a).subs(_varY,_b) == 0:
            return self._function_generate(_varX, _varY, _a, _b)
        else:
            return _num/_den
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='2変数有理関数の極限（定義域）', quiz_number=_quiz_number)
        _varX = sympy.Symbol('x')
        _varY = sympy.Symbol('y')
        _a = random.choice(list(range(self.a_min, self.a_max+1)))
        _b = random.choice(list(range(self.a_min, self.a_max+1)))
        _f = self._function_generate(_varX, _varY, _a, _b)
        _limit = _f.subs(_varX,_a).subs(_varY,_b)
        quiz.quiz_identifier = hash(str(_f) + str(_a) + str(_b) + str(_limit))
        # 正答の選択肢の生成
        quiz.data = [_varX, _varY, _f, _a, _b, _limit]
        ans = { 'fraction': 100, 'data': _limit }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_varX, _varY, _f, _a, _b, _limit] = quiz.data
        ans['feedback'] = r'有理関数の極限は，分母の零点でなければ必ず存在します。'
        ans['data'] = r'極限は存在しない'
        answers.append(dict(ans))
        ans['feedback'] = r'有理関数の有限点での極限は，分母の零点でなければ発散しません。'
        ans['data'] = sympy.S.Infinity
        answers.append(dict(ans))
        ans['feedback'] = r'有理関数の有限点での極限は，分母の零点でなければ発散しません。'
        ans['data'] = -sympy.S.Infinity
        answers.append(dict(ans))
        if _limit != 0:
            ans['feedback'] = r'何か計算ミスをしていないでしょうか。再度確認を行いましょう。'
            ans['data'] = 0
            answers.append(dict(ans))
            ans['feedback'] = r'何か計算ミスをしていないでしょうか。再度確認を行いましょう。'
            ans['data'] = -_limit
            answers.append(dict(ans))
        _num_loop = 0
        while _num_loop < 10:
            _incorrect_a = random.choice(list(range(self.a_min-1, self.a_max+2)))
            _incorrect_b = random.choice(list(range(self.a_min-1, self.a_max+2)))
            _incorrect_limit = _f.subs(_varX,_incorrect_a).subs(_varY,_incorrect_b)
            if abs(_incorrect_limit) != abs(_limit) and _incorrect_limit.is_real:
                break
            else:
                _num_loop += 1
        if _num_loop < 10:
            ans['feedback'] = r'何か計算ミスをしていないでしょうか。再度確認を行いましょう。'
            ans['data'] = _incorrect_limit
            answers.append(dict(ans))
            ans['feedback'] = r'何か計算ミスをしていないでしょうか。再度確認を行いましょう。'
            ans['data'] = -_incorrect_limit
            answers.append(dict(ans))        
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_varX, _varY, _f, _a, _b, _limit] = quiz.data
        _text = r'次の極限を選択してください。<br />'
        _text += r'\( \lim_{(x,y)\rightarrow(' + sympy.latex(_a) + r',' + sympy.latex(_b) + r')}' + sympy.latex(_f, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        if isinstance(ans['data'], str):
            return ans['data']
        else:
            return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = limit_of_bivariate_rational_function_approaches_domain()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,1)}x \)<div style="text-align:right;font-size:smaller">（問題整理番号:140）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:有理関数の極限は，分母の零点でなければ必ず存在します。"><input type="radio" name="preview140">極限は存在しない</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview140">\( \infty \)</li><li title="点数:100"><input type="radio" name="preview140">\( -1 \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview140">\( -\infty \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview140">\( 1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(1,0)}\frac{- x^{2} y^{3} + y}{3 x^{3} y^{2} + 2 x^{2} y^{3} - 1} \)<div style="text-align:right;font-size:smaller">（問題整理番号:014）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview14">\( 0 \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview14">\( -\infty \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview14">\( \frac{3}{31} \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview14">\( - \frac{3}{31} \)</li><li title="点数:0
# フィードバック:有理関数の極限は，分母の零点でなければ必ず存在します。"><input type="radio" name="preview14">極限は存在しない</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(1,0)}\frac{- x^{3} y^{3} - 2 x^{2}}{x y - 2 x} \)<div style="text-align:right;font-size:smaller">（問題整理番号:053）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview53">\( \frac{3}{2} \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview53">\( - \frac{3}{2} \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview53">\( \infty \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview53">\( -1 \)</li><li title="点数:100"><input type="radio" name="preview53">\( 1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(1,0)}\frac{3 x^{2} y^{2} + x + 2 y^{2}}{x^{3} y^{3} + 3 x^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:019）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview19">\( - \frac{1}{3} \)</li><li title="点数:100"><input type="radio" name="preview19">\( \frac{1}{3} \)</li><li title="点数:0
# フィードバック:有理関数の極限は，分母の零点でなければ必ず存在します。"><input type="radio" name="preview19">極限は存在しない</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview19">\( 0 \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview19">\( \infty \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,-1)}- \frac{3 x^{3} y^{3}}{x^{3} y^{3} - 3 x^{3} y^{2} - x^{2} y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:179）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview179">\( 1 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview179">\( 0 \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview179">\( -\infty \)</li><li title="点数:100"><input type="radio" name="preview179">\( -1 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview179">\( - \frac{6}{7} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(1,-1)}\frac{y^{3}}{- x^{2} y^{2} - 3 x^{2} y + 3} \)<div style="text-align:right;font-size:smaller">（問題整理番号:183）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:有理関数の極限は，分母の零点でなければ必ず存在します。"><input type="radio" name="preview183">極限は存在しない</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview183">\( \infty \)</li><li title="点数:100"><input type="radio" name="preview183">\( - \frac{1}{5} \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview183">\( - \frac{1}{13} \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview183">\( \frac{1}{13} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,-1)}\frac{- x^{2} + 2 x y + x}{3 x^{3} y^{3} - 3 x^{2} y - 1} \)<div style="text-align:right;font-size:smaller">（問題整理番号:057）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview57">\( - \frac{6}{31} \)</li><li title="点数:100"><input type="radio" name="preview57">\( 0 \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview57">\( -\infty \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview57">\( \infty \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview57">\( \frac{6}{31} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,1)}\frac{x y^{3} + y}{- x^{2} y + 3 x y^{3}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:111）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview111">\( \frac{3}{13} \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview111">\( - \frac{3}{13} \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview111">\( -\infty \)</li><li title="点数:100"><input type="radio" name="preview111">\( 0 \)</li><li title="点数:0
# フィードバック:有理関数の極限は，分母の零点でなければ必ず存在します。"><input type="radio" name="preview111">極限は存在しない</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,1)}\frac{x^{2} y^{2}}{- x^{3} y^{2} + 2 y} \)<div style="text-align:right;font-size:smaller">（問題整理番号:060）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview60">\( - \frac{2}{5} \)</li><li title="点数:100"><input type="radio" name="preview60">\( 0 \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview60">\( \infty \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview60">\( -\infty \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview60">\( \frac{2}{5} \)</li></ol></div></div><div style="bor

# %%
if __name__ == "__main__":
    pass
    #qz.save('limit_of_bivariate_rational_function_approaches_domain.xml')

# %% [markdown]
# ## limit of bivariate rational function approaches domain with common factor

# %%
class limit_of_bivariate_rational_function_approaches_domain_with_common_factor(core.Question):
    name = '2変数有理関数の極限（約分後，原則代入で求まる定義域への極限）'
    def __init__(self, emin=-3, emax=3, amin=-1, amax=1, nmin=0, nmax=2, tmin=1, tmax=2):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 極限を求めるxの値の範囲
        self.a_min = amin
        self.a_max = amax
        # 次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 単項式の個数の範囲
        self.term_min = tmin
        self.term_max = tmax
    def _function_generate(self, _varX, _varY, _a, _b):
        _num = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = flatten_list([[[_i,_j] for _j in range(self.deg_min, self.deg_max+1)] for _i in range(self.deg_min, self.deg_max+1)])
        _terms = random.sample(_exps,k=_num_terms)        
        for _es in _terms:
            _num += nonzero_randint(self.elem_min, self.elem_max)*_varX**_es[0]*_varY**_es[1]
        _den_nonzero = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = flatten_list([[[_i,_j] for _j in range(self.deg_min, self.deg_max+1)] for _i in range(self.deg_min, self.deg_max+1)])
        _terms = random.sample(_exps,k=_num_terms)  
        for _es in _terms:
            _den_nonzero += nonzero_randint(self.elem_min, self.elem_max)*_varX**_es[0]*_varY**_es[1]
        if _a == 0 and _b == 0:
            _den_zero = (_varX - _a)*random.choice([1,-1]) + (_varY - _b)*random.choice([1,-1])
        elif _a != 0:
            _den_zero = (_varX - _a)*random.choice([1,-1])
        elif _b != 0:
            _den_zero = (_varY - _b)*random.choice([1,-1])
        if sympy.degree(_den_nonzero, _varX) + sympy.degree(_den_nonzero, _varY) <= 0:
            return self._function_generate(_varX, _varY, _a, _b)
        elif _den_nonzero.subs(_varX,_a).subs(_varY,_b) == 0:
            return self._function_generate(_varX, _varY, _a, _b)
        else:
            return sympy.expand(_num*_den_zero)/sympy.expand(_den_nonzero*_den_zero), (_num/_den_nonzero).subs(_varX,_a).subs(_varY,_b)
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='2変数有理関数の極限（約分後，定義域）', quiz_number=_quiz_number)
        _varX = sympy.Symbol('x')
        _varY = sympy.Symbol('y')
        _a = random.choice(list(range(self.a_min, self.a_max+1)))
        _b = random.choice(list(range(self.a_min, self.a_max+1)))
        _f,_limit = self._function_generate(_varX, _varY, _a, _b)
        quiz.quiz_identifier = hash(str(_f) + str(_a) + str(_b) + str(_limit))
        # 正答の選択肢の生成
        quiz.data = [_varX, _varY, _f, _a, _b, _limit]
        ans = { 'fraction': 100, 'data': _limit }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_varX, _varY, _f, _a, _b, _limit] = quiz.data
        ans['feedback'] = r'有理関数の極限は，分母の零点でなければ必ず存在します。'
        ans['data'] = r'極限は存在しない'
        answers.append(dict(ans))
        ans['feedback'] = r'有理関数の有限点での極限は，分母の零点でなければ発散しません。'
        ans['data'] = sympy.S.Infinity
        answers.append(dict(ans))
        ans['feedback'] = r'有理関数の有限点での極限は，分母の零点でなければ発散しません。'
        ans['data'] = -sympy.S.Infinity
        answers.append(dict(ans))
        if _limit != 0:
            ans['feedback'] = r'何か計算ミスをしていないでしょうか。再度確認を行いましょう。'
            ans['data'] = 0
            answers.append(dict(ans))
            ans['feedback'] = r'何か計算ミスをしていないでしょうか。再度確認を行いましょう。'
            ans['data'] = -_limit
            answers.append(dict(ans))
        for _i in range(10):
            _incorrect_a = random.choice(list(range(self.a_min-1, self.a_max+2)))
            _incorrect_b = random.choice(list(range(self.a_min-1, self.a_max+2)))
            _incorrect_limit = _f.subs(_varX,_incorrect_a).subs(_varY,_incorrect_b)
            if abs(_incorrect_limit) != abs(_limit) and _incorrect_limit.is_real:
                break
        else:
            _incorrect_limit = _limit + random.choice([-1,1])            
            while abs(_incorrect_limit) == abs(_limit):
                _incorrect_limit += random.choice([-1,1])
        ans['feedback'] = r'何か計算ミスをしていないでしょうか。再度確認を行いましょう。'
        ans['data'] = _incorrect_limit
        answers.append(dict(ans))
        ans['feedback'] = r'何か計算ミスをしていないでしょうか。再度確認を行いましょう。'
        ans['data'] = -_incorrect_limit
        answers.append(dict(ans))        
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_varX, _varY, _f, _a, _b, _limit] = quiz.data
        _text = r'次の極限を選択してください。<br />'
        _text += r'\( \lim_{(x,y)\rightarrow(' + sympy.latex(_a) + r',' + sympy.latex(_b) + r')}' + sympy.latex(_f, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        if isinstance(ans['data'], str):
            return ans['data']
        else:
            return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = limit_of_bivariate_rational_function_approaches_domain_with_common_factor()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,1)}\frac{- x^{3} y^{2} - x^{2} y^{2} + 2 x^{2} y + 2 x y}{3 x^{2} y - 2 x y^{2} + 3 x y - 2 y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:129）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview129">\( -\infty \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview129">\( 0 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview129">\( - \frac{3}{5} \)</li><li title="点数:0
# フィードバック:有理関数の極限は，分母の零点でなければ必ず存在します。"><input type="radio" name="preview129">極限は存在しない</li><li title="点数:100"><input type="radio" name="preview129">\( \frac{3}{5} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(1,0)}\frac{- 3 x^{2} y^{2} + 3 x y^{2} + 2 x - 2}{2 x^{3} - 2 x^{2} - 2 x y^{2} + 2 y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:166）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview166">\( - \frac{1}{4} \)</li><li title="点数:100"><input type="radio" name="preview166">\( 1 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview166">\( -1 \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview166">\( \infty \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview166">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,1)}\frac{x^{2} y - x^{2}}{- 3 x^{2} y + 3 x^{2} - 3 y^{3} + 3 y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:116）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:有理関数の極限は，分母の零点でなければ必ず存在します。"><input type="radio" name="preview116">極限は存在しない</li><li title="点数:100"><input type="radio" name="preview116">\( 0 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview116">\( - \frac{1}{3} \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview116">\( -\infty \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview116">\( \frac{1}{3} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,-1)}\frac{- x - 1}{- x y - y} \)<div style="text-align:right;font-size:smaller">（問題整理番号:131）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview131">\( - \frac{1}{2} \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview131">\( 0 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview131">\( 1 \)</li><li title="点数:100"><input type="radio" name="preview131">\( -1 \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview131">\( -\infty \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,1)}\frac{2 x^{3} y - 3 x^{2} y^{2} + 2 x^{2} y - 3 x y^{2}}{3 x^{2} y^{2} + 3 x y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:009）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview9">\( - \frac{1}{3} \)</li><li title="点数:0
# フィードバック:有理関数の極限は，分母の零点でなければ必ず存在します。"><input type="radio" name="preview9">極限は存在しない</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview9">\( \infty \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview9">\( \frac{5}{3} \)</li><li title="点数:100"><input type="radio" name="preview9">\( - \frac{5}{3} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(1,1)}\frac{3 x^{3} - 2 x^{2} - x}{- x^{2} y + x y} \)<div style="text-align:right;font-size:smaller">（問題整理番号:191）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview191">\( -4 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview191">\( 4 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview191">\( -2 \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview191">\( 0 \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview191">\( \infty \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(1,1)}\frac{- 3 x^{2} + 3 x}{- 3 x^{3} y + 3 x^{2} y - 2 x y^{2} + 2 y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:019）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview19">\( 0 \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview19">\( -\infty \)</li><li title="点数:100"><input type="radio" name="preview19">\( \frac{3}{5} \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview19">\( \frac{3}{8} \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview19">\( - \frac{3}{5} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(1,1)}\frac{- 3 x^{3} y^{2} + 3 x^{2} y^{2} + x y - y}{- x^{3} y + x^{2} y - 2 x y + 2 y} \)<div style="text-align:right;font-size:smaller">（問題整理番号:196）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview196">\( \frac{2}{3} \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview196">\( \frac{23}{6} \)</li><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview196">\( - \frac{2}{3} \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview196">\( \infty \)</li><li title="点数:0
# フィードバック:有理関数の極限は，分母の零点でなければ必ず存在します。"><input type="radio" name="preview196">極限は存在しない</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,0)}\frac{- 3 x y^{2} + 3 y^{3}}{- x^{2} y^{2} + x y^{3} + 3 x - 3 y} \)<div style="text-align:right;font-size:smaller">（問題整理番号:004）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:何か計算ミスをしていないでしょうか。再度確認を行いましょう。"><input type="radio" name="preview4">\( - \frac{3}{5} \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview4">\( -\infty \)</li><li title="点数:0
# フィードバック:有理関数の有限点での極限は，分母の零点でなければ発散しません。"><input type="radio" name="preview4">\( \infty \)</li><li title=

# %%
if __name__ == "__main__":
    pass
    #qz.save('limit_of_bivariate_rational_function_approaches_domain_with_common_factor.xml')

# %% [markdown]
# ## limit of bivariate rational function approaches boundary

# %%
class limit_of_bivariate_rational_function_approaches_boundary(core.Question):
    name = '2変数有理関数の極限（定義域の境界点への極限）'
    def __init__(self, emin=-3, emax=3, amin=-1, amax=1, nmin=1, nmax=3, tmin=1, tmax=2, lrate=0.5):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 極限を求めるxの値の範囲
        self.a_min = amin
        self.a_max = amax
        # 次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 単項式の個数の範囲
        self.term_min = tmin
        self.term_max = tmax
        # 極限が存在する確率
        self.limit_exist_ratio = lrate
    def _function_generate(self, _varX, _varY, _a, _b, _is_limit_exists=None):
        if _is_limit_exists is None:
            _is_limit_exists = True if random.random() <= self.limit_exist_ratio else False
        _deg_den = random.randint(self.deg_min, self.deg_max)
        if _is_limit_exists:
            _deg_num = _deg_den + 1
        else:
            _deg_num = _deg_den
        _num = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = [[_i,_deg_num-_i] for _i in range(_deg_num+1)]
        if _num_terms < len(_exps):
            _terms = random.sample(_exps,k=_num_terms)
        else:
            _terms = _exps
        for _es in _terms:
            _num += nonzero_randint(self.elem_min, self.elem_max)*(_varX-_a)**_es[0]*(_varY-_b)**_es[1]
        _den = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = [[_i,_deg_den-_i] for _i in range(_deg_den+1)]
        if _num_terms < len(_exps):
            _terms = random.sample(_exps,k=_num_terms)
        else:
            _terms = _exps
        for _es in _terms:
            _den += nonzero_randint(self.elem_min, self.elem_max)*(_varX-_a)**_es[0]*(_varY-_b)**_es[1]
        if sympy.degree(_num, _varX)*sympy.degree(_num, _varY)*sympy.degree(_den, _varX)*sympy.degree(_den, _varY) == 0:
            return self._function_generate(_varX, _varY, _a, _b, _is_limit_exists)
        if _is_limit_exists:
            return _num, _den, 0
        else:
            _varM = sympy.Symbol('m')
            _limit = sympy.expand(sympy.cancel((_num/_den).subs(_varX,_varM).subs(_varY,_varM)))
            if _limit.is_polynomial(_varM):
                if sympy.degree(_limit, _varM) <= 0:
                    return self._function_generate(_varX, _varY, _a, _b, _is_limit_exists)
            return _num, _den, r'極限は存在しない'
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='2変数有理関数の極限（境界点）', quiz_number=_quiz_number)
        _varX = sympy.Symbol('x')
        _varY = sympy.Symbol('y')
        _a = random.choice(list(range(self.a_min, self.a_max+1)))
        _b = random.choice(list(range(self.a_min, self.a_max+1)))
        _fn, _fd, _limit = self._function_generate(_varX, _varY, _a, _b)
        quiz.quiz_identifier = hash(str(_fn) + str(_fd) + str(_a) + str(_b) + str(_limit))
        # 正答の選択肢の生成
        quiz.data = [_varX, _varY, _fn, _fd, _a, _b, _limit]
        ans = { 'fraction': 100, 'data': _limit }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_varX, _varY, _fn, _fd, _a, _b, _limit] = quiz.data
        if isinstance(_limit, str):
            ans['feedback'] = r'\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。'
            ans['data'] = 0
            answers.append(dict(ans))
            ans['data'] = sympy.S.Infinity
            answers.append(dict(ans))
            ans['data'] = -sympy.S.Infinity
            answers.append(dict(ans))
            ans['data'] = 1
            answers.append(dict(ans))
            ans['data'] = -1
            answers.append(dict(ans))
        else:
            ans['feedback'] = r'極座標変換を行うなどして，挟み込みをしてみましょう。'
            ans['data'] = r'極限は存在しない'
            answers.append(dict(ans))
            ans['data'] = sympy.S.Infinity
            answers.append(dict(ans))
            ans['data'] = -sympy.S.Infinity
            answers.append(dict(ans))
            ans['data'] = 1
            answers.append(dict(ans))
            ans['data'] = -1
            answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_varX, _varY, _fn, _fd, _a, _b, _limit] = quiz.data
        _text = r'次の極限を選択してください。<br />'
        _text += r'\( \lim_{(x,y)\rightarrow(' + sympy.latex(_a) + r',' + sympy.latex(_b) + r')}\frac{'
        _text += sympy.latex(_fn, order='lex') + r'}{' + sympy.latex(_fd, order='lex') + r'} \)'
        return _text
    def answer_text(self, ans):
        if isinstance(ans['data'], str):
            return ans['data']
        else:
            return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = limit_of_bivariate_rational_function_approaches_boundary()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(1,1)}\frac{\left(- 2 x + 2\right) \left(y - 1\right)}{3 \left(x - 1\right)^{2} - 3 \left(y - 1\right)^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:137）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。"><input type="radio" name="preview137">\( \infty \)</li><li title="点数:0
# フィードバック:\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。"><input type="radio" name="preview137">\( -\infty \)</li><li title="点数:0
# フィードバック:\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。"><input type="radio" name="preview137">\( -1 \)</li><li title="点数:100"><input type="radio" name="preview137">極限は存在しない</li><li title="点数:0
# フィードバック:\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。"><input type="radio" name="preview137">\( 1 \)</li><li title="点数:0
# フィードバック:\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。"><input type="radio" name="preview137">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,0)}\frac{y^{3} \left(2 x + 2\right) - 2 y \left(x + 1\right)^{3}}{3 y \left(x + 1\right)^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:171）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview171">\( -\infty \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview171">\( \infty \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview171">\( 1 \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview171">\( -1 \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview171">極限は存在しない</li><li title="点数:100"><input type="radio" name="preview171">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,1)}\frac{- x^{2} - \left(y - 1\right)^{2}}{- 2 x + 3 y - 3} \)<div style="text-align:right;font-size:smaller">（問題整理番号:132）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview132">\( 1 \)</li><li title="点数:100"><input type="radio" name="preview132">\( 0 \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview132">極限は存在しない</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview132">\( -1 \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview132">\( \infty \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview132">\( -\infty \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(1,1)}\frac{- 2 \left(x - 1\right)^{3} + 3 \left(y - 1\right)^{3}}{\left(- x + 1\right) \left(y - 1\right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:111）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview111">\( -1 \)</li><li title="点数:100"><input type="radio" name="preview111">\( 0 \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview111">\( \infty \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview111">\( 1 \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview111">極限は存在しない</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview111">\( -\infty \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(1,0)}\frac{y \left(x - 1\right)^{3} - 2 \left(x - 1\right)^{4}}{- y \left(x - 1\right)^{2} - 2 \left(x - 1\right)^{3}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:151）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview151">極限は存在しない</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview151">\( -\infty \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview151">\( 1 \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview151">\( \infty \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview151">\( -1 \)</li><li title="点数:100"><input type="radio" name="preview151">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,-1)}\frac{- 3 x^{3} + 2 \left(y + 1\right)^{3}}{- 2 x \left(y + 1\right)^{2} + 3 \left(y + 1\right)^{3}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:197）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。"><input type="radio" name="preview197">\( -1 \)</li><li title="点数:0
# フィードバック:\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。"><input type="radio" name="preview197">\( \infty \)</li><li title="点数:0
# フィードバック:\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。"><input type="radio" name="preview197">\( -\infty \)</li><li title="点数:100"><input type="radio" name="preview197">極限は存在しない</li><li title="点数:0
# フィードバック:\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。"><input type="radio" name="preview197">\( 0 \)</li><li title="点数:0
# フィードバック:\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。"><input type="radio" name="preview197">\( 1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,0)}\frac{x y - 3 y^{2}}{3 x - y} \)<div style="text-align:right;font-size:smaller">（問題整理番号:005）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview5">\( -1 \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview5">極限は存在しない</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview5">\( \infty \)</li><li title="点数:100"><input type="radio" name="preview5">\( 0 \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview5">\( 1 \)</li><li title="点数:0
# フィードバック:極座標変換を行うなどして，挟み込みをしてみましょう。"><input type="radio" name="preview5">\( -\infty \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(-1,-1)}\frac{- 3 \left(x + 1\right)^{2} - 2 \left(y + 1\right)^{2}}{\left(- 3 x - 3\right) \left(y + 1\right) + 3 \left(y + 1\right)^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:100）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。"><input type="radio" name="preview100">\( 0 \)</li><li title="点数:0
# フィードバック:\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。"><input type="radio" name="preview100">\( 1 \)</li><li title="点数:100"><input type="radio" name="preview100">極限は存在しない</li><li

# %%
if __name__ == "__main__":
    pass
    #qz.save('limit_of_bivariate_rational_function_approaches_boundary.xml')

# %% [markdown]
# ## limit with sin(x+y) and log(1+x+y) over (x+y)

# %%
class limit_with_sin_or_log_over_xpy(core.Question):
    name = '2変数有理関数の極限（分解でsinやlogの1変数に帰着）'
    def __init__(self, emin=-3, emax=3, amin=0, amax=0, nmin=0, nmax=1, tmin=1, tmax=2):
        # 生成する個々の数の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 極限を求めるxの値の範囲
        self.a_min = amin
        self.a_max = amax
        # 次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 単項式の個数の範囲
        self.term_min = tmin
        self.term_max = tmax
        # 極限が存在する確率（境界点への極限計算の場合における）
        self.limit_exist_ratio = 0.5
    def _function_generate(self, _varX, _varY, _a, _b):
        _c = nonzero_randint(self.elem_min, self.elem_max)
        if random.random() <= 0.5:
            _pre_num = sympy.sin(_c*(_varX-_a) + _c*(_varY-_b))
            _pre_den = _c*(_varX-_a) + _c*(_varY-_b)
        else:
            _pre_num = sympy.log(1+_c*(_varX-_a) + _c*(_varY-_b))
            _pre_den = _c*(_varX-_a) + _c*(_varY-_b)
        _t = random.choice(['poly','ratd', 'ratf', 'ratb'])
        if _t == 'poly':
            _num, _den, _limit = self._function_generate_polynomial(_varX, _varY, _a, _b)
        elif _t == 'ratd':
            _num, _den, _limit = self._function_generate_rational_domain(_varX, _varY, _a, _b)
        elif _t == 'ratf':
            _num, _den, _limit = self._function_generate_rational_factor(_varX, _varY, _a, _b)
        else:
            _num, _den, _limit = self._function_generate_rational_boundary(_varX, _varY, _a, _b)
        return sympy.expand(_num*_pre_num), sympy.expand(_den*_pre_den), _limit            
    def _function_generate_polynomial(self, _varX, _varY, _a, _b):
        _poly = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = flatten_list([[[_i,_j] for _j in range(self.deg_min, self.deg_max+1)] for _i in range(self.deg_min, self.deg_max+1)])
        _terms = random.sample(_exps,k=_num_terms)        
        for _es in _terms:
            _poly += nonzero_randint(self.elem_min, self.elem_max)*_varX**_es[0]*_varY**_es[1]
        return _poly, 1, _poly.subs(_varX,_a).subs(_varY,_b)        
    def _function_generate_rational_domain(self, _varX, _varY, _a, _b):
        _num = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = flatten_list([[[_i,_j] for _j in range(self.deg_min, self.deg_max+1)] for _i in range(self.deg_min, self.deg_max+1)])
        _terms = random.sample(_exps,k=_num_terms)        
        for _es in _terms:
            _num += nonzero_randint(self.elem_min, self.elem_max)*_varX**_es[0]*_varY**_es[1]
        _den = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = flatten_list([[[_i,_j] for _j in range(self.deg_min, self.deg_max+1)] for _i in range(self.deg_min, self.deg_max+1)])
        _terms = random.sample(_exps,k=_num_terms)        
        for _es in _terms:
            _den += nonzero_randint(self.elem_min, self.elem_max)*_varX**_es[0]*_varY**_es[1]
        if sympy.degree(_den, _varX) + sympy.degree(_den, _varY) <= 0:
            return self._function_generate_rational_domain(_varX, _varY, _a, _b)
        elif sympy.degree(_num, _varX) + sympy.degree(_num, _varY) <= 0:
            return self._function_generate_rational_domain(_varX, _varY, _a, _b)
        elif _den.subs(_varX,_a).subs(_varY,_b) == 0:
            return self._function_generate_rational_domain(_varX, _varY, _a, _b)
        else:
            return _num, _den, _num.subs(_varX,_a).subs(_varY,_b)/_den.subs(_varX,_a).subs(_varY,_b)
    def _function_generate_rational_factor(self, _varX, _varY, _a, _b):
        _num = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = flatten_list([[[_i,_j] for _j in range(self.deg_min, self.deg_max+1)] for _i in range(self.deg_min, self.deg_max+1)])
        _terms = random.sample(_exps,k=_num_terms)        
        for _es in _terms:
            _num += nonzero_randint(self.elem_min, self.elem_max)*_varX**_es[0]*_varY**_es[1]
        _den_nonzero = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = flatten_list([[[_i,_j] for _j in range(self.deg_min, self.deg_max+1)] for _i in range(self.deg_min, self.deg_max+1)])
        _terms = random.sample(_exps,k=_num_terms)  
        for _es in _terms:
            _den_nonzero += nonzero_randint(self.elem_min, self.elem_max)*_varX**_es[0]*_varY**_es[1]
        if _a == 0 and _b == 0:
            _den_zero = (_varX - _a)*random.choice([1,-1]) + (_varY - _b)*random.choice([1,-1])
        elif _a != 0:
            _den_zero = (_varX - _a)*random.choice([1,-1])
        elif _b != 0:
            _den_zero = (_varY - _b)*random.choice([1,-1])
        if sympy.degree(_den_nonzero, _varX) + sympy.degree(_den_nonzero, _varY) <= 0:
            return self._function_generate_rational_factor(_varX, _varY, _a, _b)
        elif _den_nonzero.subs(_varX,_a).subs(_varY,_b) == 0:
            return self._function_generate_rational_factor(_varX, _varY, _a, _b)
        else:
            return sympy.expand(_num*_den_zero), sympy.expand(_den_nonzero*_den_zero), (_num/_den_nonzero).subs(_varX,_a).subs(_varY,_b)
    def _function_generate_rational_boundary(self, _varX, _varY, _a, _b, _is_limit_exists=None):
        if _is_limit_exists is None:
            _is_limit_exists = True if random.random() <= self.limit_exist_ratio else False
        _deg_den = random.randint(self.deg_min, self.deg_max)
        if _is_limit_exists:
            _deg_num = _deg_den + 1
        else:
            _deg_num = _deg_den
        _num = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = [[_i,_deg_num-_i] for _i in range(_deg_num+1)]
        if _num_terms < len(_exps):
            _terms = random.sample(_exps,k=_num_terms)
        else:
            _terms = _exps
        for _es in _terms:
            _num += nonzero_randint(self.elem_min, self.elem_max)*(_varX-_a)**_es[0]*(_varY-_b)**_es[1]
        _den = 0
        _num_terms = random.randint(self.term_min, self.term_max)
        _exps = [[_i,_deg_den-_i] for _i in range(_deg_den+1)]
        if _num_terms < len(_exps):
            _terms = random.sample(_exps,k=_num_terms)
        else:
            _terms = _exps
        for _es in _terms:
            _den += nonzero_randint(self.elem_min, self.elem_max)*(_varX-_a)**_es[0]*(_varY-_b)**_es[1]
        if sympy.degree(_num, _varX)*sympy.degree(_num, _varY)*sympy.degree(_den, _varX)*sympy.degree(_den, _varY) == 0:
            return self._function_generate_rational_boundary(_varX, _varY, _a, _b, _is_limit_exists)
        if _is_limit_exists:
            return _num, _den, 0
        else:
            _varM = sympy.Symbol('m')
            _limit = sympy.expand(sympy.cancel((_num/_den).subs(_varX,_varM).subs(_varY,_varM)))
            if _limit.is_polynomial(_varM):
                if sympy.degree(_limit, _varM) <= 0:
                    return self._function_generate_rational_boundary(_varX, _varY, _a, _b, _is_limit_exists)
            return _num, _den, r'極限は存在しない'
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='2変数有理関数の極限（sinやlogに帰着）', quiz_number=_quiz_number)
        _varX = sympy.Symbol('x')
        _varY = sympy.Symbol('y')
        _a = random.choice(list(range(self.a_min, self.a_max+1)))
        _b = random.choice(list(range(self.a_min, self.a_max+1)))
        _num, _den, _limit = self._function_generate(_varX, _varY, _a, _b)
        quiz.quiz_identifier = hash(str(_num) + str(_den) + str(_a) + str(_b) + str(_limit))
        # 正答の選択肢の生成
        quiz.data = [_varX, _varY, _num, _den, _a, _b, _limit]
        ans = { 'fraction': 100, 'data': _limit }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_varX, _varY, _num, _den, _a, _b, _limit] = quiz.data
        if isinstance(_limit, str):
            ans['feedback'] = r'因数分解などで分離した上で，\( y=mx \)などの変換を行い，本当に，近づけ方によらずに一定の値に近づくのかを確認しましょう。'
            ans['data'] = 0
            answers.append(dict(ans))
            ans['data'] = sympy.S.Infinity
            answers.append(dict(ans))
            ans['data'] = -sympy.S.Infinity
            answers.append(dict(ans))
            ans['data'] = 1
            answers.append(dict(ans))
            ans['data'] = -1
            answers.append(dict(ans))
        else:
            ans['feedback'] = r'因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。'
            ans['data'] = r'極限は存在しない'
            answers.append(dict(ans))
            ans['data'] = sympy.S.Infinity
            answers.append(dict(ans))
            ans['data'] = -sympy.S.Infinity
            answers.append(dict(ans))
            ans['data'] = 1
            answers.append(dict(ans))
            ans['data'] = -1
            answers.append(dict(ans))
            if _limit != 0:
                ans['data'] = -_limit
                answers.append(dict(ans))
                ans['data'] = 1/_limit
                answers.append(dict(ans))
                ans['data'] = -1/_limit
                answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_varX, _varY, _num, _den, _a, _b, _limit] = quiz.data
        _text = r'次の極限を選択してください。<br />'
        _text += r'\( \lim_{(x,y)\rightarrow(' + sympy.latex(_a) + r',' + sympy.latex(_b) + r')}\frac{'
        _text += sympy.latex(_num, order='lex') + r'}{' + sympy.latex(_den, order='lex') + r'} \)'
        return _text
    def answer_text(self, ans):
        if isinstance(ans['data'], str):
            return ans['data']
        else:
            return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = limit_with_sin_or_log_over_xpy()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,0)}\frac{2 x y \sin{\left(3 x + 3 y \right)} - 3 x \sin{\left(3 x + 3 y \right)} + 2 y^{2} \sin{\left(3 x + 3 y \right)} - 3 y \sin{\left(3 x + 3 y \right)}}{9 x^{3} y + 18 x^{2} y^{2} + 6 x^{2} + 9 x y^{3} + 12 x y + 6 y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:199）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview199">\( - \frac{3}{2} \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview199">\( \infty \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview199">\( 1 \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview199">\( -\infty \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview199">\( -1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,0)}\frac{3 x y \log{\left(x + y + 1 \right)} - 3 y^{2} \log{\left(x + y + 1 \right)}}{2 x^{3} + x^{2} - 2 x y^{2} - y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:173）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview173">\( 1 \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview173">\( -1 \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview173">極限は存在しない</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview173">\( \infty \)</li><li title="点数:100"><input type="radio" name="preview173">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,0)}\frac{x y \sin{\left(3 x + 3 y \right)} + 2 y^{2} \sin{\left(3 x + 3 y \right)}}{- 9 x^{2} + 9 y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:008）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview8">極限は存在しない</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview8">\( -1 \)</li><li title="点数:100"><input type="radio" name="preview8">\( 0 \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview8">\( \infty \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview8">\( -\infty \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,0)}\frac{3 x y \sin{\left(x + y \right)} + y \sin{\left(x + y \right)}}{- x - y} \)<div style="text-align:right;font-size:smaller">（問題整理番号:045）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview45">\( 0 \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview45">\( 1 \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview45">極限は存在しない</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview45">\( -\infty \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview45">\( \infty \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,0)}\frac{- 2 x^{2} \log{\left(2 x + 2 y + 1 \right)} + 5 x y \log{\left(2 x + 2 y + 1 \right)} - 3 y^{2} \log{\left(2 x + 2 y + 1 \right)}}{6 x^{2} y + 2 x^{2} - 6 y^{3} - 2 y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:087）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview87">\( 1 \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview87">\( -1 \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview87">極限は存在しない</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview87">\( \infty \)</li><li title="点数:100"><input type="radio" name="preview87">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,0)}\frac{x^{2} y \sin{\left(2 x + 2 y \right)} - x y^{2} \sin{\left(2 x + 2 y \right)} - 2 x \sin{\left(2 x + 2 y \right)} + 2 y \sin{\left(2 x + 2 y \right)}}{2 x^{3} y + 4 x^{2} - 2 x y^{3} - 4 y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:123）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview123">\( -\infty \)</li><li title="点数:100"><input type="radio" name="preview123">\( -1 \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview123">\( 1 \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview123">\( \infty \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview123">極限は存在しない</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,0)}\frac{- 2 \log{\left(3 x + 3 y + 1 \right)}}{3 x + 3 y} \)<div style="text-align:right;font-size:smaller">（問題整理番号:195）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview195">\( -\infty \)</li><li title="点数:100"><input type="radio" name="preview195">\( -2 \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview195">\( \infty \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview195">\( -1 \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview195">\( - \frac{1}{2} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の極限を選択してください。<br />\( \lim_{(x,y)\rightarrow(0,0)}\frac{\log{\left(x + y + 1 \right)}}{x + y} \)<div style="text-align:right;font-size:smaller">（問題整理番号:100）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="radio" name="preview100">\( -1 \)</li><li title="点数:100"><input type="radio" name="preview100">\( 1 \)</li><li title="点数:0
# フィードバック:因数分解などで分離した上で，代入操作や式の形によっては極座標変換などで挟み込みなどを検討してみましょう。"><input type="ra

# %%
if __name__ == "__main__":
    pass
    #qz.save('limit_with_sin_or_log_over_xpy.xml')

# %% [markdown]
# ## PartialDifferentiableFunction class for the following quizzes

# %%
class PartialDifferentiableFunction():
    _constA = sympy.Symbol('A') # non-zero integer
    _constB = sympy.Symbol('B') # non-zero integer
    _n = sympy.Symbol('n') # positive integer
    _m = sympy.Symbol('m') # positive integer > 1
    _k = sympy.Symbol('k') # positive integer < _m
    _x = sympy.Symbol('x')
    _y = sympy.Symbol('y')
    _z = sympy.Symbol('z')
    # format: [f, [df/dx, df/dy], [incorrect dfs by x, incorrect dfs by y]] 
    _term_types = ['x', 'y', 'xy']
    _term_defs = dict()
    _term_defs['x'] = [_constA*_x**_n, [_n*_constA*_x**(_n-1),0], [[_constA*_x**_n,_n*_constA*_x**_n,0], [_n*_constA*_x**(_n-1)]]]
    _term_defs['y'] = [_constA*_y**_n, [0,_n*_constA*_y**(_n-1)], [[_n*_constA*_y**(_n-1)], [_constA*_y**_n, _n*_constA*_y**_n,0]]]
    _term_defs['xy'] = [_constA*_x**_m*_y**_k, [_m*_constA*_x**(_m-1)*_y**_k,_k*_constA*_x**_m*_y**(_k-1)], [[_k*_constA*_x**_m*_y**(_k-1),_m*_k*_constA*_x**(_m-1)*_y**(_k-1)],[_m*_constA*_x**(_m-1)*_y**_k,_m*_k*_constA*_x**(_m-1)*_y**(_k-1)]]]
    # format: [f, df, incorrect dfs] 
    _composition_types = ['monomial', 'polynomial', 'rational', 'sine', 'cosine', 'natural_exponent']
    _composition_defs = dict()
    _composition_defs['constant'] = [_constA, 0, [_constA, 1]]
    _composition_defs['monomial'] = [_z, 1, [_z, 0]]
    _composition_defs['polynomial'] = [_z**2+_constA*_z+_constB, 2*_z+_constA, [_z+_constA,_z,2*_z**2+_constA*_z]]
    _composition_defs['rational'] = [(_z+_constA)/(_constB*_z), -_constA/(_constB*_z**2), [_constA/(_constB*_z**2), _constA/(_constB*_z)]]
    _composition_defs['sine'] = [sympy.sin(_z), sympy.cos(_z), [sympy.sin(_z), -sympy.cos(_z)]]
    _composition_defs['cosine'] = [sympy.cos(_z), -sympy.sin(_z), [sympy.cos(_z), sympy.sin(_z)]]
    _composition_defs['natural_exponent'] = [sympy.exp(_z), sympy.exp(_z), [sympy.exp(_z-1)]]
    # func = scalar*composition
    # composition = elemental_func @@ terms
    def __init__(self, emin=-3, emax=3, nmin=1, nmax=2, tmin=1, tmax=2, mrate=0.3):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 生成する次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 合成前の多項式に表れる単項式の個数
        self.term_min = tmin
        self.term_max = tmax
        # それぞれの積の微分法の確率
        self.multiplication_ratio = mrate
        # internals
        self.function_internal = 0
        self.function = 0
    # func = scalar*composition | scalar*multiplication
    # multiplication = composition*composition
    # composition = elemental_func @@ terms
    _expression_types = ['summation', 'scalar', 'composition', 'multiplication']
    _incorrect_reasons = ['formula', 'sign', 'composition', 'scalar']
    def generate_function(self):
        _scalar = nonzero_randint(self.elem_min, self.elem_max)
        if random.random() <= self.multiplication_ratio:
            _types = ['monomial', random.choice(self._composition_types[1:])]
            _func = ['scalar', _scalar, self._generate_multiplication(_types)]
        else:
            _func = ['scalar', _scalar, self._generate_composition()]
        self.function_internal = _func
        self.function = self._get_function(self.function_internal)
        if self.function.is_real:
            self.generate_function()
    # multiplication = composition*composition
    def _generate_multiplication(self, _types):
        _func1 = self._generate_composition(_types[0])
        _func2 = self._generate_composition(_types[1])
        return ['multiplication', _func1, _func2]
    # composition = elemental_func @@ terms
    def _generate_composition(self, _type=None):
        if _type is None:
            _type = random.choice(self._composition_types)
        _cfunc = self._generate_elemental_func(_type)
        _tfunc = self._generate_terms()
        return ['composition', _cfunc, _tfunc]
    def _mysubs(self, target, var, repl):
        if sympy.sympify(target).is_real:
            return target
        elif len(var) == 1:
            return target.subs(var[0], repl[0])
        else:
            return self._mysubs(target.subs(var[0], repl[0]), var[1:], repl[1:])
    def _generate_elemental_func(self, _type):
        _vars = [self._constA, self._constB, self._n, self._m, self._k]
        _m = random.randint(max(2,self.deg_min), max(2,self.deg_max))
        _k = random.randint(1, _m-1)
        _repl = [nonzero_randint(self.elem_min, self.elem_max), nonzero_randint(self.elem_min, self.elem_max), 
                 abs(nonzero_randint(self.deg_min, self.deg_max)), _m-_k, _k]
        _cfunc = self._composition_defs[_type]
        _cfunc = [self._mysubs(_cfunc[0], _vars, _repl), 
                  self._mysubs(_cfunc[1], _vars, _repl), 
                  [self._mysubs(_f, _vars, _repl) for _f in _cfunc[2]]]
        return _cfunc
    def _generate_terms(self):
        _nt = random.randint(self.term_min, self.term_max)
        _tfunc = ['summation']
        for _i in range(_nt):
            _vars = [self._constA, self._constB, self._n, self._m, self._k]
            _m = random.randint(max(2,self.deg_min), max(2,self.deg_max))
            _k = random.randint(1, _m-1)
            _repl = [nonzero_randint(self.elem_min, self.elem_max), nonzero_randint(self.elem_min, self.elem_max), 
                     abs(nonzero_randint(self.deg_min, self.deg_max)), _m-_k, _k]
            _type = random.choice(self._term_types)
            _mfunc = self._term_defs[_type]
            _mfunc = [self._mysubs(_mfunc[0], _vars, _repl), 
                      [self._mysubs(_f, _vars, _repl) for _f in _mfunc[1]],
                      [[self._mysubs(_f, _vars, _repl) for _f in _fs] for _fs in _mfunc[2]]]
            _tfunc.append(_mfunc)
        return _tfunc
    def _get_function(self, _func):
        _recursive_call = self._get_function
        # ['summation', 'scalar', 'composition', 'multiplication']
        if _func[0] == 'summation':
            _summand = 0
            for _f in _func[1:]:
                _summand = _summand + _recursive_call(_f)
            return _summand
        elif _func[0] == 'scalar':
            return _func[1] * _recursive_call(_func[2])
        elif _func[0] == 'composition':
            return _recursive_call(_func[1]).subs(self._z, _recursive_call(_func[2]))
        elif _func[0] == 'multiplication':
            return _recursive_call(_func[1]) * _recursive_call(_func[2])
        else:
            return _func[0]
    def get_function(self):
        if self.function_internal == 0:
            self.generate_function()
        return self.function    
    def _get_derivative(self, _func):
        _recursive_call = self._get_derivative
        # ['summation', 'scalar', 'composition', 'multiplication']
        if _func[0] == 'summation':
            _summand = [0,0]
            for _f in _func[1:]:
                _rest = _recursive_call(_f)
                for _i in range(2):
                    _summand[_i] = _summand[_i] + _rest[_i]
            return _summand
        elif _func[0] == 'scalar':
            return [_func[1] * _f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _dz = self._mysubs(_func[1][1], [self._z], [self._get_function(_func[2])])
            return [_f*_dz for _f in _recursive_call(_func[2])]
        elif _func[0] == 'multiplication':
            _fl = [_f * self._get_function(_func[2]) for _f in _recursive_call(_func[1])]
            _fr = [self._get_function(_func[1]) * _f for _f in _recursive_call(_func[2])]
            return [_fl[0] + _fr[0], _fl[1] + _fr[1]]
        else:
            return _func[1]
    def get_derivative(self):
        if self.function == 0:
            self.generate_function()
        return self._get_derivative(self.function_internal)
    def get_higher_derivative(self, dvars):
        if self.function == 0:
            self.generate_function()
        if len(dvars) <= 0:
            return self.get_function()
        else:
            _df = self.get_derivative()
            if dvars[0] == 'x':
                _df = _df[0]
            else:
                _df = _df[1]
            for _c in dvars[1:]:
                if _c == 'x':
                    _df = sympy.diff(_df, self._x)
                else:
                    _df = sympy.diff(_df, self._y)
            return _df
    def _get_incorrect_Xderivatives_by_formula(self, _func):
        _recursive_call = self._get_incorrect_Xderivatives_by_formula
        # ['summation', 'scalar', 'composition', 'multiplication']
        if _func[0] == 'summation':
            _summand = [0]
            for _f in _func[1:]:
                _dfs = _recursive_call(_f)
                _new_summand = []
                for _df in _dfs:
                    _new_summand = _new_summand + [ _s + _df for _s in _summand]
                _summand = _new_summand
            return _summand
        elif _func[0] == 'scalar':
            return [_func[1] * _f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _dz = self._mysubs(_func[1][1], [self._z], [self._get_function(_func[2])])
            return [_f*_dz for _f in _recursive_call(_func[2])]
        elif _func[0] == 'multiplication':
            _fls = [_f * self._get_function(_func[2]) for _f in _recursive_call(_func[1])]
            _frs = [self._get_function(_func[1]) * _f for _f in _recursive_call(_func[2])]
            _funcs = []
            for _fl in _fls:
                for _fr in _frs:
                    _funcs.append(_fl+_fr)
            return _funcs
        else:
            return _func[2][0]
    def _get_incorrect_Yderivatives_by_formula(self, _func):
        _recursive_call = self._get_incorrect_Yderivatives_by_formula
        # ['summation', 'scalar', 'composition', 'multiplication']
        if _func[0] == 'summation':
            _summand = [0]
            for _f in _func[1:]:
                _dfs = _recursive_call(_f)
                _new_summand = []
                for _df in _dfs:
                    _new_summand = _new_summand + [ _s + _df for _s in _summand]
                _summand = _new_summand
            return _summand
        elif _func[0] == 'scalar':
            return [_func[1] * _f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _dz = self._mysubs(_func[1][1], [self._z], [self._get_function(_func[2])])
            return [_f*_dz for _f in _recursive_call(_func[2])]
        elif _func[0] == 'multiplication':
            _fls = [_f * self._get_function(_func[2]) for _f in _recursive_call(_func[1])]
            _frs = [self._get_function(_func[1]) * _f for _f in _recursive_call(_func[2])]
            _funcs = []
            for _fl in _fls:
                for _fr in _frs:
                    _funcs.append(_fl+_fr)
            return _funcs
        else:
            return _func[2][1]
    def _get_incorrect_Xderivatives_by_sign(self, _func):
        _recursive_call = self._get_incorrect_Xderivatives_by_sign
        # ['summation', 'scalar', 'composition', 'multiplication']
        if _func[0] == 'summation':
            _summand = [0]
            for _f in _func[1:]:
                _dfs = _recursive_call(_f)
                _new_summand = []
                for _df in _dfs:
                    _new_summand = _new_summand + [ _s + random.choice([-1,1])*_df for _s in _summand]
                _summand = _new_summand
            return _summand
        elif _func[0] == 'scalar':
            return [_func[1] * _f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _dz = self._mysubs(_func[1][1], [self._z], [self._get_function(_func[2])])
            return [_f*_dz for _f in _recursive_call(_func[2])]
        elif _func[0] == 'multiplication':
            _fls = [_f * self._get_function(_func[2]) for _f in _recursive_call(_func[1])]
            _frs = [self._get_function(_func[1]) * _f for _f in _recursive_call(_func[2])]
            _funcs = []
            for _fl in _fls:
                for _fr in _frs:
                    _funcs.append(_fl-_fr)
            return _funcs
        else:
            return [_func[1][0]]
    def _get_incorrect_Yderivatives_by_sign(self, _func):
        _recursive_call = self._get_incorrect_Yderivatives_by_sign
        # ['summation', 'scalar', 'composition', 'multiplication']
        if _func[0] == 'summation':
            _summand = [0]
            for _f in _func[1:]:
                _dfs = _recursive_call(_f)
                _new_summand = []
                for _df in _dfs:
                    _new_summand = _new_summand + [ _s + random.choice([-1,1])*_df for _s in _summand]
                _summand = _new_summand
            return _summand
        elif _func[0] == 'scalar':
            return [_func[1] * _f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _dz = self._mysubs(_func[1][1], [self._z], [self._get_function(_func[2])])
            return [_f*_dz for _f in _recursive_call(_func[2])]
        elif _func[0] == 'multiplication':
            _fls = [_f * self._get_function(_func[2]) for _f in _recursive_call(_func[1])]
            _frs = [self._get_function(_func[1]) * _f for _f in _recursive_call(_func[2])]
            _funcs = []
            for _fl in _fls:
                for _fr in _frs:
                    _funcs.append(_fl-_fr)
            return _funcs
        else:
            return [_func[1][1]]
    def _get_incorrect_Xderivatives_by_composition(self, _func):
        _recursive_call = self._get_incorrect_Xderivatives_by_composition
        # ['summation', 'scalar', 'composition', 'multiplication']
        if _func[0] == 'summation':
            _summand = [0]
            for _f in _func[1:]:
                _dfs = _recursive_call(_f)
                _new_summand = []
                for _df in _dfs:
                    _new_summand = _new_summand + [ _s + _df for _s in _summand]
                _summand = _new_summand
            return _summand
        elif _func[0] == 'scalar':
            return [_func[1] * _f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _dz = self._mysubs(_func[1][1], [self._z], [self._get_function(_func[2])])
            return _recursive_call(_func[2]) + [_dz]
        elif _func[0] == 'multiplication':
            _fls = [_f * self._get_function(_func[2]) for _f in _recursive_call(_func[1])]
            _frs = [self._get_function(_func[1]) * _f for _f in _recursive_call(_func[2])]
            _funcs = []
            for _fl in _fls:
                for _fr in _frs:
                    _funcs.append(_fl+_fr)
            return _funcs
        else:
            return [_func[1][0]]
    def _get_incorrect_Yderivatives_by_composition(self, _func):
        _recursive_call = self._get_incorrect_Yderivatives_by_composition
        # ['summation', 'scalar', 'composition', 'multiplication']
        if _func[0] == 'summation':
            _summand = [0]
            for _f in _func[1:]:
                _dfs = _recursive_call(_f)
                _new_summand = []
                for _df in _dfs:
                    _new_summand = _new_summand + [ _s + _df for _s in _summand]
                _summand = _new_summand
            return _summand
        elif _func[0] == 'scalar':
            return [_func[1] * _f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _dz = self._mysubs(_func[1][1], [self._z], [self._get_function(_func[2])])
            return _recursive_call(_func[2]) + [_dz]
        elif _func[0] == 'multiplication':
            _fls = [_f * self._get_function(_func[2]) for _f in _recursive_call(_func[1])]
            _frs = [self._get_function(_func[1]) * _f for _f in _recursive_call(_func[2])]
            _funcs = []
            for _fl in _fls:
                for _fr in _frs:
                    _funcs.append(_fl+_fr)
            return _funcs
        else:
            return [_func[1][1]]
    def _get_incorrect_Xderivatives_by_scalar(self, _func):
        _recursive_call = self._get_incorrect_Xderivatives_by_scalar
        # ['summation', 'scalar', 'composition', 'multiplication']
        if _func[0] == 'summation':
            _summand = [0]
            for _f in _func[1:]:
                _dfs = _recursive_call(_f)
                _new_summand = []
                for _df in _dfs:
                    _new_summand = _new_summand + [ _s + _df for _s in _summand]
                _summand = _new_summand
            return _summand
        elif _func[0] == 'scalar':
            return [_f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _dz = self._mysubs(_func[1][1], [self._z], [self._get_function(_func[2])])
            return [_f*_dz for _f in _recursive_call(_func[2])]
        elif _func[0] == 'multiplication':
            _fls = [_f * self._get_function(_func[2]) for _f in _recursive_call(_func[1])]
            _frs = [self._get_function(_func[1]) * _f for _f in _recursive_call(_func[2])]
            _funcs = []
            for _fl in _fls:
                for _fr in _frs:
                    _funcs.append(_fl+_fr)
            return _funcs
        else:
            return [_func[1][0]]
    def _get_incorrect_Yderivatives_by_scalar(self, _func):
        _recursive_call = self._get_incorrect_Yderivatives_by_scalar
        # ['summation', 'scalar', 'composition', 'multiplication']
        if _func[0] == 'summation':
            _summand = [0]
            for _f in _func[1:]:
                _dfs = _recursive_call(_f)
                _new_summand = []
                for _df in _dfs:
                    _new_summand = _new_summand + [ _s + _df for _s in _summand]
                _summand = _new_summand
            return _summand
        elif _func[0] == 'scalar':
            return [_f for _f in _recursive_call(_func[2])]
        elif _func[0] == 'composition':
            _dz = self._mysubs(_func[1][1], [self._z], [self._get_function(_func[2])])
            return [_f*_dz for _f in _recursive_call(_func[2])]
        elif _func[0] == 'multiplication':
            _fls = [_f * self._get_function(_func[2]) for _f in _recursive_call(_func[1])]
            _frs = [self._get_function(_func[1]) * _f for _f in _recursive_call(_func[2])]
            _funcs = []
            for _fl in _fls:
                for _fr in _frs:
                    _funcs.append(_fl+_fr)
            return _funcs
        else:
            return [_func[1][1]]
    def _not_same_check(self, value):
        if not value.is_real:
            return False
        if value > 1.0e-4:
            return True
        return False
    def _incorrect_Xderivarives_only(self, _dfs):
        _funcs = []
        _correct_df = self.get_derivative()[0]
        _correct_df0 = self._mysubs(_correct_df, [self._x, self._y], [0, 0])
        _correct_df1 = self._mysubs(_correct_df, [self._x, self._y], [-1, 1])
        _correct_df2 = self._mysubs(_correct_df, [self._x, self._y], [1, -1])
        for _df in _dfs:
            if _df in _funcs:
                continue
            if self._not_same_check(abs(sympy.N(_correct_df0 - self._mysubs(_df, [self._x, self._y], [0, 0])))):
                _funcs.append(_df)
            elif self._not_same_check(abs(sympy.N(_correct_df1 - self._mysubs(_df, [self._x, self._y], [-1, 1])))):
                _funcs.append(_df)
            elif self._not_same_check(abs(sympy.N(_correct_df2 - self._mysubs(_df, [self._x, self._y], [1, -1])))):
                _funcs.append(_df)
        return _funcs
    def _incorrect_Yderivarives_only(self, _dfs):
        _funcs = []
        _correct_df = self.get_derivative()[1]
        _correct_df0 = self._mysubs(_correct_df, [self._x, self._y], [0, 0])
        _correct_df1 = self._mysubs(_correct_df, [self._x, self._y], [-1, 1])
        _correct_df2 = self._mysubs(_correct_df, [self._x, self._y], [1, -1])
        for _df in _dfs:
            if _df in _funcs:
                continue
            if self._not_same_check(abs(sympy.N(_correct_df0 - self._mysubs(_df, [self._x, self._y], [0, 0])))):
                _funcs.append(_df)
            elif self._not_same_check(abs(sympy.N(_correct_df1 - self._mysubs(_df, [self._x, self._y], [-1, 1])))):
                _funcs.append(_df)
            elif self._not_same_check(abs(sympy.N(_correct_df2 - self._mysubs(_df, [self._x, self._y], [1, -1])))):
                _funcs.append(_df)
        return _funcs
    def get_incorrect_Xderivatives(self, _type=None):
        if self.function == 0:
            self.generate_function()
        if _type is None:
            _type = random.choice(self._incorrect_reasons)
        if _type == 'formula':
            _dfs = self._get_incorrect_Xderivatives_by_formula(self.function_internal)
        elif _type == 'sign':
            _dfs = self._get_incorrect_Xderivatives_by_sign(self.function_internal)
        elif _type == 'composition':
            _dfs = self._get_incorrect_Xderivatives_by_composition(self.function_internal)
        elif _type == 'scalar':
            _dfs = self._get_incorrect_Xderivatives_by_scalar(self.function_internal)
        return self._incorrect_Xderivarives_only(_dfs)
    def get_incorrect_Yderivatives(self, _type=None):
        if self.function == 0:
            self.generate_function()
        if _type is None:
            _type = random.choice(self._incorrect_reasons)
        if _type == 'formula':
            _dfs = self._get_incorrect_Yderivatives_by_formula(self.function_internal)
        elif _type == 'sign':
            _dfs = self._get_incorrect_Yderivatives_by_sign(self.function_internal)
        elif _type == 'composition':
            _dfs = self._get_incorrect_Yderivatives_by_composition(self.function_internal)
        elif _type == 'scalar':
            _dfs = self._get_incorrect_Yderivatives_by_scalar(self.function_internal)
        return self._incorrect_Yderivarives_only(_dfs)
    def _incorrect_higher_derivarives_only(self, _dfs, dvars):
        _funcs = []
        _correct_df = self.get_higher_derivative(dvars)
        _correct_df0 = self._mysubs(_correct_df, [self._x, self._y], [0, 0])
        _correct_df1 = self._mysubs(_correct_df, [self._x, self._y], [-1, 1])
        _correct_df2 = self._mysubs(_correct_df, [self._x, self._y], [1, -1])
        for _df in _dfs:
            if _df in _funcs:
                continue
            if self._not_same_check(abs(sympy.N(_correct_df0 - self._mysubs(_df, [self._x, self._y], [0, 0])))):
                _funcs.append(_df)
            elif self._not_same_check(abs(sympy.N(_correct_df1 - self._mysubs(_df, [self._x, self._y], [-1, 1])))):
                _funcs.append(_df)
            elif self._not_same_check(abs(sympy.N(_correct_df2 - self._mysubs(_df, [self._x, self._y], [1, -1])))):
                _funcs.append(_df)
        return _funcs
    def get_incorrect_higher_derivatives_by_dvars(self, dvars):
        _dfs = []
        _nx = dvars.count(r'x')
        _ny = dvars.count(r'y')
        for _ix in range(0,len(dvars)+1):
            for _iy in range(0,len(dvars)+1):
                if _ix + _iy > len(dvars):
                    continue
                _dvars = r''
                for _i in range(_ix):
                    _dvars += r'x'
                for _i in range(_iy):
                    _dvars += r'y'
                _dfs.append(self.get_higher_derivative(_dvars))
        return _dfs        
    def get_incorrect_higher_derivatives(self, dvars, _type=None):
        if self.function == 0:
            self.generate_function()
        if _type is None:
            _type = random.choice(self._incorrect_reasons)
        if _type == 'dvars':
            _dfs = self.get_incorrect_higher_derivatives_by_dvars(dvars)
        elif _type == 'formula':
            _dfs = self._get_incorrect_Xderivatives_by_formula(self.function_internal)
            _dfs = _dfs + self._get_incorrect_Yderivatives_by_formula(self.function_internal)
        elif _type == 'sign':
            _dfs = self._get_incorrect_Xderivatives_by_sign(self.function_internal)
            _dfs = _dfs + self._get_incorrect_Yderivatives_by_sign(self.function_internal)
        elif _type == 'composition':
            _dfs = self._get_incorrect_Xderivatives_by_composition(self.function_internal)
            _dfs = _dfs + self._get_incorrect_Yderivatives_by_composition(self.function_internal)
        elif _type == 'scalar':
            _dfs = self._get_incorrect_Xderivatives_by_scalar(self.function_internal)
            _dfs = _dfs + self._get_incorrect_Yderivatives_by_scalar(self.function_internal)
        return self._incorrect_higher_derivarives_only(_dfs, dvars)

# %%
if __name__ == "__main__":
    df = PartialDifferentiableFunction()
    df.generate_function()
    display(df.function_internal)
    display(df.get_function())
    _dfs = df.get_derivative()
    display(_dfs[0])
    display(_dfs[1])
    display(df.get_incorrect_Xderivatives())
    display(df.get_incorrect_Yderivatives())
    display(df.get_higher_derivative("xy"))
    display(df.get_incorrect_higher_derivatives("xy"))
# Out:
# ['scalar',
#  2,
#  ['composition',
#   [-(z - 2)/(3*z), -2/(3*z**2), [2/(3*z**2), 2/(3*z)]],
#   ['summation', [3*x**2*y, [6*x*y, 3*x**2], [[3*x**2, 6*x], [6*x*y, 6*x]]]]]]
# -2*(3*x**2*y - 2)/(9*x**2*y)
# -8/(9*x**3*y)
# -4/(9*x**2*y**2)
# [-4/(9*x**2*y**2), -8/(9*x**3*y**2)]
# [4/(9*x**2*y**2)]
# 8/(9*x**3*y**2)
# [-4/(9*x**2*y**2), -8/(9*x**3*y**2), -8/(9*x**3*y)]

# %% [markdown]
# ## partial derivative

# %%
class partial_derivative(core.Question):
    name = '偏導関数'
    def __init__(self, emin=-3, emax=3, nmin=1, nmax=2, tmin=1, tmax=2, mrate=0.3):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 生成する次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 合成前の多項式に表れる単項式の個数
        self.term_min = tmin
        self.term_max = tmax
        # それぞれの積の微分法の確率
        self.multiplication_ratio = mrate
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='偏導関数', quiz_number=_quiz_number)
        df = PartialDifferentiableFunction(emin=self.elem_min, emax=self.elem_max, nmin=self.deg_min, nmax=self.deg_max, 
                                           tmin=self.term_min, tmax=self.term_max, mrate=self.multiplication_ratio)
        _func = df.get_function()
        quiz.quiz_identifier = hash(str(_func))
        # 正答の選択肢の生成
        _df = df.get_derivative()
        quiz.data = [_func, _df, df]
        ans = { 'fraction': 100, 'data': _df }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_func, _df, df] = quiz.data
        # 'formula', 'sign', 'composition', 'scalar'
        ans['feedback'] = r'変数の取り違えや，基本的な関数の導関数の公式を確認してください。'
        for _incorrectX in df.get_incorrect_Xderivatives('formula') + [_df[0]]:
            for _incorrectY in df.get_incorrect_Yderivatives('formula') + [_df[1]]:
                if _df[0] != _incorrectX or _df[1] != _incorrectY:
                    ans['data'] = [_incorrectX, _incorrectY]
                    answers.append(dict(ans))
        ans['feedback'] = r'符号に注意して計算を行ってください。'
        for _incorrectX in df.get_incorrect_Xderivatives('sign') + [_df[0]]:
            for _incorrectY in df.get_incorrect_Yderivatives('sign') + [_df[1]]:
                if _df[0] != _incorrectX or _df[1] != _incorrectY:
                    ans['data'] = [_incorrectX, _incorrectY]
                    answers.append(dict(ans))
        ans['feedback'] = r'係数などのかけ忘れなどに注意してください。'
        for _incorrectX in df.get_incorrect_Xderivatives('scalar') + [_df[0]]:
            for _incorrectY in df.get_incorrect_Yderivatives('scalar') + [_df[1]]:
                if _df[0] != _incorrectX or _df[1] != _incorrectY:
                    ans['data'] = [_incorrectX, _incorrectY]
                    answers.append(dict(ans))
        ans['feedback'] = r'各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。'
        for _incorrectX in df.get_incorrect_Xderivatives('composition') + [_df[0]]:
            for _incorrectY in df.get_incorrect_Yderivatives('composition') + [_df[1]]:
                if _df[0] != _incorrectX or _df[1] != _incorrectY:
                    ans['data'] = [_incorrectX, _incorrectY]
                    answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_func, _df, df] = quiz.data
        _text = r'次の関数\( f(x,y) \)の1階の偏導関数を選択してください。'
        _text += r'<br />\( f(x,y)=' + sympy.latex(_func, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        _text = r'\( \frac{\partial f}{\partial x}=' +  sympy.latex(ans['data'][0], order='lex')
        _text += r',\;\frac{\partial f}{\partial y}=' +  sympy.latex(ans['data'][1], order='lex') + r' \)'
        return _text

# %%
if __name__ == "__main__":
    q = partial_derivative(emin=-3, emax=3, nmin=2, nmax=3, tmin=1, tmax=1, mrate=0.0)
    q.name = r'偏導関数（比較的簡単なもの）'
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の1階の偏導関数を選択してください。<br />\( f(x,y)=- \frac{x y + 3}{2 x y} \)<div style="text-align:right;font-size:smaller">（問題整理番号:121）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview121">\( \frac{\partial f}{\partial x}=\frac{3}{2 x^{2} y},\;\frac{\partial f}{\partial y}=\frac{3}{2 x^{2} y} \)</li><li title="点数:0
# フィードバック:係数などのかけ忘れなどに注意してください。"><input type="radio" name="preview121">\( \frac{\partial f}{\partial x}=- \frac{3}{2 x^{2} y},\;\frac{\partial f}{\partial y}=\frac{3}{2 x y^{2}} \)</li><li title="点数:100"><input type="radio" name="preview121">\( \frac{\partial f}{\partial x}=\frac{3}{2 x^{2} y},\;\frac{\partial f}{\partial y}=\frac{3}{2 x y^{2}} \)</li><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview121">\( \frac{\partial f}{\partial x}=\frac{3}{2 x^{2} y^{2}},\;\frac{\partial f}{\partial y}=\frac{3}{2 x^{2} y^{2}} \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview121">\( \frac{\partial f}{\partial x}=\frac{3}{2 x^{2} y^{2}},\;\frac{\partial f}{\partial y}=- x \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の1階の偏導関数を選択してください。<br />\( f(x,y)=\sin{\left(x y \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:055）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview55">\( \frac{\partial f}{\partial x}=- \cos{\left(x y \right)},\;\frac{\partial f}{\partial y}=x \)</li><li title="点数:0
# フィードバック:係数などのかけ忘れなどに注意してください。"><input type="radio" name="preview55">\( \frac{\partial f}{\partial x}=- y \cos{\left(x y \right)},\;\frac{\partial f}{\partial y}=x \cos{\left(x y \right)} \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview55">\( \frac{\partial f}{\partial x}=y,\;\frac{\partial f}{\partial y}=x \cos{\left(x y \right)} \)</li><li title="点数:100"><input type="radio" name="preview55">\( \frac{\partial f}{\partial x}=y \cos{\left(x y \right)},\;\frac{\partial f}{\partial y}=x \cos{\left(x y \right)} \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview55">\( \frac{\partial f}{\partial x}=y \cos{\left(x y \right)},\;\frac{\partial f}{\partial y}=x \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の1階の偏導関数を選択してください。<br />\( f(x,y)=9 y^{4} - 6 y^{2} + 2 \)<div style="text-align:right;font-size:smaller">（問題整理番号:009）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview9">\( \frac{\partial f}{\partial x}=6 y \left(6 y^{2} - 2\right),\;\frac{\partial f}{\partial y}=0 \)</li><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview9">\( \frac{\partial f}{\partial x}=6 y \left(6 y^{2} - 2\right),\;\frac{\partial f}{\partial y}=3 y^{2} \left(6 y^{2} - 2\right) \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview9">\( \frac{\partial f}{\partial x}=6 y^{2} - 2,\;\frac{\partial f}{\partial y}=6 y^{2} - 2 \)</li><li title="点数:100"><input type="radio" name="preview9">\( \frac{\partial f}{\partial x}=0,\;\frac{\partial f}{\partial y}=6 y \left(6 y^{2} - 2\right) \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview9">\( \frac{\partial f}{\partial x}=0,\;\frac{\partial f}{\partial y}=6 y \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の1階の偏導関数を選択してください。<br />\( f(x,y)=- \frac{x y^{2} + 3}{x y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:108）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview108">\( \frac{\partial f}{\partial x}=\frac{3}{x^{2} y^{2}},\;\frac{\partial f}{\partial y}=\frac{6}{x^{2} y^{3}} \)</li><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview108">\( \frac{\partial f}{\partial x}=\frac{6}{x^{2} y^{3}},\;\frac{\partial f}{\partial y}=\frac{3}{x^{2} y^{2}} \)</li><li title="点数:100"><input type="radio" name="preview108">\( \frac{\partial f}{\partial x}=\frac{3}{x^{2} y^{2}},\;\frac{\partial f}{\partial y}=\frac{6}{x y^{3}} \)</li><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview108">\( \frac{\partial f}{\partial x}=\frac{6}{x y^{3}},\;\frac{\partial f}{\partial y}=\frac{3}{x^{2} y^{2}} \)</li><li title="点数:0
# フィードバック:係数などのかけ忘れなどに注意してください。"><input type="radio" name="preview108">\( \frac{\partial f}{\partial x}=\frac{1}{x^{2} y^{2}},\;\frac{\partial f}{\partial y}=\frac{2}{x y^{3}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の1階の偏導関数を選択してください。<br />\( f(x,y)=- 3 x^{4} - 9 x^{2} - 6 \)<div style="text-align:right;font-size:smaller">（問題整理番号:090）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview90">\( \frac{\partial f}{\partial x}=- 6 x \left(2 x^{2} + 3\right),\;\frac{\partial f}{\partial y}=- 6 x \left(2 x^{2} + 3\right) \)</li><li title="点数:100"><input type="radio" name="preview90">\( \frac{\partial f}{\partial x}=- 6 x \left(2 x^{2} + 3\right),\;\frac{\partial f}{\partial y}=0 \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview90">\( \frac{\partial f}{\partial x}=- 6 x^{2} - 9,\;\frac{\partial f}{\partial y}=- 6 x^{2} - 9 \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview90">\( \frac{\partial f}{\partial x}=- 6 x \left(2 x^{2} + 3\right),\;\frac{\partial f}{\partial y}=- 6 x^{2} - 9 \)</li><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview90">\( \frac{\partial f}{\partial x}=- 3 x^{2} \left(2 x^{2} + 3\right),\;\frac{\partial f}{\partial y}=- 6 x \left(2 x^{2} + 3\right) \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の1階の偏導関数を選択してください。<br />\( f(x,y)=- \frac{- 3 x^{3} + 1}{3 x^{3}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:044）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview44">\( \frac{\partial f}{\partial x}=\frac{1}{x^{4}},\;\frac{\partial f}{\partial y}=0 \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview44">\( \frac{\partial f}{\partial x}=- \frac{1}{9 x^{6}},\;\frac{\partial f}{\partial y}=0 \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview44">\( \frac{\partial f}{\partial x}=- 18 x^{2},\;\frac{\partial f}{\partial y}=0 \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview44">\( \frac{\partial f}{\partial x}=- 18 x^{2},\;\frac{\partial f}{\partial y}=- \frac{1}{9 x^{6}} \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview44">\( \frac{\partial f}{\partial x}=- \frac{1}{9 x^{6}},\;\frac{\partial f}{\partial y}=- \frac{1}{9 x^{6}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1

# %%
if __name__ == "__main__":
    pass
    #qz.save('partial_derivative.xml')

# %%
if __name__ == "__main__":
    q = partial_derivative(emin=-2, emax=2, nmin=2, nmax=2, tmin=1, tmax=1, mrate=1.0)
    q.name = r'偏導関数（比較的複雑なもの）'
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の1階の偏導関数を選択してください。<br />\( f(x,y)=- 2 x y \left(4 x^{4} + 2 x^{2} - 1\right) \)<div style="text-align:right;font-size:smaller">（問題整理番号:188）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview188">\( \frac{\partial f}{\partial x}=8 x^{2} y \left(- 4 x^{2} - 1\right) - 2 y \left(4 x^{4} + 2 x^{2} - 1\right),\;\frac{\partial f}{\partial y}=- 2 x \left(4 x^{4} + 2 x^{2} - 1\right) \)</li><li title="点数:0
# フィードバック:係数などのかけ忘れなどに注意してください。"><input type="radio" name="preview188">\( \frac{\partial f}{\partial x}=8 x^{2} y \left(- 4 x^{2} - 1\right) - 2 y \left(4 x^{4} + 2 x^{2} - 1\right),\;\frac{\partial f}{\partial y}=- x \left(4 x^{4} + 2 x^{2} - 1\right) \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview188">\( \frac{\partial f}{\partial x}=8 x^{2} y - 2 y \left(4 x^{4} + 2 x^{2} - 1\right),\;\frac{\partial f}{\partial y}=- 2 x y \left(- 4 x^{2} - 1\right) - 2 x \left(4 x^{4} + 2 x^{2} - 1\right) \)</li><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview188">\( \frac{\partial f}{\partial x}=8 x^{2} y \left(- 4 x^{2} - 1\right) - 2 y \left(4 x^{4} + 2 x^{2} - 1\right),\;\frac{\partial f}{\partial y}=- 8 x^{4} + 8 x^{2} y \left(- 4 x^{2} - 1\right) - 4 x^{2} + 2 \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview188">\( \frac{\partial f}{\partial x}=8 x^{2} y - 2 y \left(4 x^{4} + 2 x^{2} - 1\right),\;\frac{\partial f}{\partial y}=8 x^{4} + 4 x^{2} - 2 x y \left(- 4 x^{2} - 1\right) - 2 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の1階の偏導関数を選択してください。<br />\( f(x,y)=- 2 x y \cos{\left(x y \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:165）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview165">\( \frac{\partial f}{\partial x}=2 x y \sin{\left(x y \right)} - 2 x \cos{\left(x y \right)},\;\frac{\partial f}{\partial y}=2 x y^{2} \sin{\left(x y \right)} - 2 \cos{\left(x y \right)} \)</li><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview165">\( \frac{\partial f}{\partial x}=2 x^{2} y \sin{\left(x y \right)} - 2 \cos{\left(x y \right)},\;\frac{\partial f}{\partial y}=2 x y \sin{\left(x y \right)} - 2 \cos{\left(x y \right)} \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview165">\( \frac{\partial f}{\partial x}=- 2 x y \sin{\left(x y \right)} - 2 y \cos{\left(x y \right)},\;\frac{\partial f}{\partial y}=2 x^{2} y - \cos{\left(x y \right)} \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview165">\( \frac{\partial f}{\partial x}=2 x y^{2} - \cos{\left(x y \right)},\;\frac{\partial f}{\partial y}=- 2 x y \sin{\left(x y \right)} - \cos{\left(x y \right)} \)</li><li title="点数:100"><input type="radio" name="preview165">\( \frac{\partial f}{\partial x}=2 x y^{2} \sin{\left(x y \right)} - 2 y \cos{\left(x y \right)},\;\frac{\partial f}{\partial y}=2 x^{2} y \sin{\left(x y \right)} - 2 x \cos{\left(x y \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の1階の偏導関数を選択してください。<br />\( f(x,y)=4 x^{2} \sin{\left(x^{2} \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:170）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview170">\( \frac{\partial f}{\partial x}=4 x^{2} \cos{\left(x^{2} \right)} + 8 x \sin{\left(x^{2} \right)},\;\frac{\partial f}{\partial y}=2 \sin{\left(x^{2} \right)} \)</li><li title="点数:100"><input type="radio" name="preview170">\( \frac{\partial f}{\partial x}=8 x^{3} \cos{\left(x^{2} \right)} + 8 x \sin{\left(x^{2} \right)},\;\frac{\partial f}{\partial y}=0 \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview170">\( \frac{\partial f}{\partial x}=4 x^{2} \cos{\left(x^{2} \right)} + 2 \sin{\left(x^{2} \right)},\;\frac{\partial f}{\partial y}=4 x^{2} \cos{\left(x^{2} \right)} \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview170">\( \frac{\partial f}{\partial x}=4 x^{2} \cos{\left(x^{2} \right)} + 8 x \sin{\left(x^{2} \right)},\;\frac{\partial f}{\partial y}=4 x^{2} \cos{\left(x^{2} \right)} + 2 \sin{\left(x^{2} \right)} \)</li><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview170">\( \frac{\partial f}{\partial x}=4 x^{4} \cos{\left(x^{2} \right)},\;\frac{\partial f}{\partial y}=0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の1階の偏導関数を選択してください。<br />\( f(x,y)=- y^{2} e^{2 x y} \)<div style="text-align:right;font-size:smaller">（問題整理番号:132）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview132">\( \frac{\partial f}{\partial x}=- 2 y^{3} e^{2 x y},\;\frac{\partial f}{\partial y}=- 2 x y^{2} - 2 y e^{2 x y} \)</li><li title="点数:100"><input type="radio" name="preview132">\( \frac{\partial f}{\partial x}=- 2 y^{3} e^{2 x y},\;\frac{\partial f}{\partial y}=- 2 x y^{2} e^{2 x y} - 2 y e^{2 x y} \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview132">\( \frac{\partial f}{\partial x}=- 2 y^{3},\;\frac{\partial f}{\partial y}=- y^{2} e^{2 x y} - 2 y e^{2 x y} \)</li><li title="点数:0
# フィードバック:符号に注意して計算を行ってください。"><input type="radio" name="preview132">\( \frac{\partial f}{\partial x}=2 y^{3} e^{2 x y},\;\frac{\partial f}{\partial y}=- 2 x y^{2} e^{2 x y} - 2 y e^{2 x y} \)</li><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview132">\( \frac{\partial f}{\partial x}=- 2 y^{2} e^{2 x y} - 2 y e^{2 x y},\;\frac{\partial f}{\partial y}=- 2 y^{3} e^{2 x y} - 2 y^{2} e^{2 x y} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の1階の偏導関数を選択してください。<br />\( f(x,y)=2 x y \cos{\left(y^{2} \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:112）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview112">\( \frac{\partial f}{\partial x}=2 y \cos{\left(y^{2} \right)},\;\frac{\partial f}{\partial y}=2 x y \sin{\left(y^{2} \right)} + 2 \cos{\left(y^{2} \right)} \)</li><li title="点数:100"><input type="radio" name="preview112">\( \frac{\partial f}{\partial x}=2 y \cos{\left(y^{2} \right)},\;\frac{\partial f}{\partial y}=- 4 x y^{2} \sin{\left(y^{2} \right)} + 2 x \cos{\left(y^{2} \right)} \)</li><li title="点数:0
# フィードバック:変数の取り違えや，基本的な関数の導関数の公式を確認してください。"><input type="radio" name="preview112">\( \frac{\partial f}{\partial x}=- 4 x y^{2} \sin{\left(y^{2} \right)} + 2 \cos{\left(y^{2} \right)},\;\frac{\partial f}{\partial y}=- 4 x y^{3} \sin{\left(y^{2} \right)} + 2 y \cos{\left(y^{2} \right)} \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview112">\( \frac{\partial f}{\partial x}=2 x y \sin{\left(y^{2} \right)} + 2 \cos{\left(y^{2} \right)},\;\frac{\partial f}{\partial y}=2 x y \sin{\left(y^{2} \right)} + 2 \cos{\left(y^{2} \right)} \)</li><li title="点数:0
# フィードバック:各種の微分法などを確認しましょう。取り違えや取りこぼしがあります。"><input type="radio" name="preview11

# %%
if __name__ == "__main__":
    pass
    #qz.save('partial_derivative_2.xml')

# %% [markdown]
# ## partial higher derivative

# %%
class partial_higher_derivative(core.Question):
    name = '高階偏導関数'
    def __init__(self, emin=-3, emax=3, nmin=1, nmax=2, tmin=1, tmax=2, mrate=0.3, hmin=2, hmax=3):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 生成する次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 合成前の多項式に表れる単項式の個数
        self.term_min = tmin
        self.term_max = tmax
        # それぞれの積の微分法の確率
        self.multiplication_ratio = mrate
        # 何階の高階偏導関数を求めるか
        self.nth_min = hmin
        self.nth_max = hmax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='高階偏導関数', quiz_number=_quiz_number)
        df = PartialDifferentiableFunction(emin=self.elem_min, emax=self.elem_max, nmin=self.deg_min, nmax=self.deg_max, 
                                           tmin=self.term_min, tmax=self.term_max, mrate=self.multiplication_ratio)
        _func = df.get_function()
        _n = random.randint(self.nth_min, self.nth_max)
        _dvars = r''
        for _i in range(_n):
            _dvars += random.choice([r'x', r'y'])
        quiz.quiz_identifier = hash(str(_func) + str(_dvars))
        # 正答の選択肢の生成
        _df = df.get_higher_derivative(_dvars)
        quiz.data = [_func, _df, df, _dvars]
        ans = { 'fraction': 100, 'data': _df }
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_func, _df, df, _dvars] = quiz.data
        ans['feedback'] = r'高階の偏微分なので，指定された変数で順次偏微分してください。'
        for _incorrect in df.get_incorrect_higher_derivatives(_dvars, 'dvars'):
                ans['data'] = _incorrect
                answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_func, _df, df, _dvars] = quiz.data
        _text = r'次の関数\( f(x,y) \)の高階偏導関数\( f_{' + _dvars + r'} \)を選択してください。'
        _text += r'<br />\( f(x,y)=' + sympy.latex(_func, order='lex') + r' \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' +  sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = partial_higher_derivative(emin=-3, emax=3, nmin=2, nmax=3, tmin=1, tmax=1, mrate=0.0, hmin=2, hmax=2)
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の高階偏導関数\( f_{yy} \)を選択してください。<br />\( f(x,y)=\frac{3 x y + 3}{x y} \)<div style="text-align:right;font-size:smaller">（問題整理番号:093）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview93">\( - \frac{3}{x y^{2}} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview93">\( \frac{3 x y + 3}{x y} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview93">\( \frac{3}{x^{2} y^{2}} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview93">\( - \frac{3}{x^{2} y} \)</li><li title="点数:100"><input type="radio" name="preview93">\( \frac{6}{x y^{3}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の高階偏導関数\( f_{yy} \)を選択してください。<br />\( f(x,y)=- 3 \cos{\left(x y^{2} \right)} \)<div style="text-align:right;font-size:smaller">（問題整理番号:087）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview87">\( 12 x^{2} y^{2} \cos{\left(x y^{2} \right)} + 6 x \sin{\left(x y^{2} \right)} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview87">\( 3 y^{2} \sin{\left(x y^{2} \right)} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview87">\( - 3 \cos{\left(x y^{2} \right)} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview87">\( 6 x y \sin{\left(x y^{2} \right)} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview87">\( 3 y^{4} \cos{\left(x y^{2} \right)} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の高階偏導関数\( f_{xy} \)を選択してください。<br />\( f(x,y)=2 e^{- 2 y^{3}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:170）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview170">\( 72 y^{4} e^{- 2 y^{3}} - 24 y e^{- 2 y^{3}} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview170">\( 2 e^{- 2 y^{3}} \)</li><li title="点数:100"><input type="radio" name="preview170">\( 0 \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview170">\( - 12 y^{2} e^{- 2 y^{3}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の高階偏導関数\( f_{yy} \)を選択してください。<br />\( f(x,y)=2 e^{y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:044）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview44">\( 2 e^{y^{2}} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview44">\( 4 y e^{y^{2}} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview44">\( 0 \)</li><li title="点数:100"><input type="radio" name="preview44">\( 8 y^{2} e^{y^{2}} + 4 e^{y^{2}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の高階偏導関数\( f_{yy} \)を選択してください。<br />\( f(x,y)=4 x^{4} y^{2} + 2 x^{2} y + 2 \)<div style="text-align:right;font-size:smaller">（問題整理番号:186）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview186">\( 4 x^{4} y^{2} + 2 x^{2} y + 2 \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview186">\( 2 x^{2} \left(4 x^{2} y + 1\right) \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview186">\( 16 x^{3} y + 4 x \left(4 x^{2} y + 1\right) \)</li><li title="点数:100"><input type="radio" name="preview186">\( 8 x^{4} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview186">\( 32 x^{2} y^{2} + 4 y \left(4 x^{2} y + 1\right) \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の高階偏導関数\( f_{xy} \)を選択してください。<br />\( f(x,y)=\frac{2 \left(y^{2} + 1\right)}{y^{2}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:154）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview154">\( - \frac{4}{y^{3}} \)</li><li title="点数:100"><input type="radio" name="preview154">\( 0 \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview154">\( \frac{12}{y^{4}} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview154">\( \frac{2 \left(y^{2} + 1\right)}{y^{2}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の高階偏導関数\( f_{yx} \)を選択してください。<br />\( f(x,y)=- \frac{2 x^{3} - 3}{3 x^{3}} \)<div style="text-align:right;font-size:smaller">（問題整理番号:001）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview1">\( 0 \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview1">\( \frac{12}{x^{5}} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview1">\( - \frac{2 x^{3} - 3}{3 x^{3}} \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview1">\( - \frac{3}{x^{4}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の高階偏導関数\( f_{yy} \)を選択してください。<br />\( f(x,y)=- 27 x^{4} + 9 x^{2} - 6 \)<div style="text-align:right;font-size:smaller">（問題整理番号:028）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview28">\( - 324 x^{2} + 18 \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview28">\( - 27 x^{4} + 9 x^{2} - 6 \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview28">\( - 18 x \left(6 x^{2} - 1\right) \)</li><li title="点数:100"><input type="radio" name="preview28">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の高階偏導関数\( f_{xx} \)を選択してください。<br />\( f(x,y)=18 x^{2} y^{2} - 6 x y - 4 \)<div style="text-align:right;font-size:smaller">（問題整理番号:136）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview136">\( 18 x^{2} y^{2} - 6 x y - 4 \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview136">\( 72 x y - 6 \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview136">\( - 6 y \left(- 6 x y + 1\right) \)</li><li title="点数:0
# フィードバック:高階の偏微分なので，指定された変数で順次偏微分してください。"><input type="radio" name="preview136">\( - 6 x \left(- 6 x y + 1\right) \)</li><li title="点数:100"><input type="radio" name="preview136">\( 36 y^{2} \)</li></ol></div></div><div style="border: t

# %%
if __name__ == "__main__":
    pass
    #qz.save('partial_higher_derivative.xml')

# %% [markdown]
# ## extremum condition

# %%
class extremum_condition(core.Question):
    name = '極値を取るための必要十分条件'
    def __init__(self, emin=-10, emax=10):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='極値の必要十分条件', quiz_number=_quiz_number)
        _a = random.randint(self.elem_min, self.elem_max)
        _b = random.randint(self.elem_min, self.elem_max)
        _fx = random.choice([0,0,0,0,0,1])*random.randint(self.elem_min, self.elem_max)
        _fy = random.choice([0,0,0,0,0,1])*random.randint(self.elem_min, self.elem_max)
        _fxx = nonzero_randint(self.elem_min, self.elem_max)
        _fyy = random.randint(self.elem_min, self.elem_max)
        _fxy = random.randint(sympy.floor(self.elem_min/5), sympy.ceiling(self.elem_max/5))
        _dxy = _fxx*_fyy-_fxy**2
        quiz.quiz_identifier = hash(str(_a) + str(_b) + str(_fx) + str(_fy) + str(_fxx) + str(_fyy) + str(_fxy) + str(_dxy))
        # 正答の選択肢の生成
        if _dxy < 0 or _fx != 0 or _fy != 0:
            _ans = 'no'
        elif _dxy > 0:
            if _fxx > 0:
                _ans = 'min'
            else:
                _ans = 'max'
        else:
            _ans = 'dontknow'        
        quiz.data = [_a, _b, _fx, _fy, _fxx, _fyy, _fxy, _dxy, _ans]
        ans = { 'fraction': 100, 'data': [_a, _b, _ans]}
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_a, _b, _fx, _fy, _fxx, _fyy, _fxy, _dxy, _ans] = quiz.data
        ans['feedback'] = r'極値を取るための必要条件と十分条件をそれぞれ確認してください。'
        if _ans != 'no':
            ans['data'] = [_a, _b, 'no']
            answers.append(dict(ans))
        if _ans != 'min':
            ans['data'] = [_a, _b, 'min']
            answers.append(dict(ans))
        if _ans != 'max':
            ans['data'] = [_a, _b, 'max']
            answers.append(dict(ans))
        if _ans != 'dontknow':
            ans['data'] = [_a, _b, 'dontknow']
            answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_a, _b, _fx, _fy, _fxx, _fyy, _fxy, _dxy, _ans] = quiz.data
        _text = r'ある\( C^2 \)級の関数\( f(x,y) \)は，点\( (a,b)=(' + sympy.latex(_a) + r',' + sympy.latex(_b) + r') \)において，'
        _text += r'それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />'
        _text += r'\( f_{x}(a,b)=' + sympy.latex(_fx) + r',\;'
        _text += r'f_{y}(a,b)=' + sympy.latex(_fy) + r',\;'
        _text += r'f_{xx}(a,b)=' + sympy.latex(_fxx) + r',\;'
        _text += r'f_{yy}(a,b)=' + sympy.latex(_fyy) + r',\;'
        _text += r'f_{xy}(a,b)=' + sympy.latex(_fxy) + r' \)'
        return _text
    def answer_text(self, ans):
        [_a, _b, _ans] = ans['data']
        _text = r'関数\( f(x,y) \)は点\( (a,b)=(' + sympy.latex(_a) + r',' + sympy.latex(_b) + r') \)で，'
        if _ans == 'no':
            _text += r'極値を取らない。'
        elif _ans == 'max':
            _text += r'極大値を取る。'
        elif _ans == 'min':
            _text += r'極小値を取る。'
        else:
            _text += r'極値を取るかは確定できない。'
        return _text

# %%
if __name__ == "__main__":
    q = extremum_condition()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある\( C^2 \)級の関数\( f(x,y) \)は，点\( (a,b)=(7,-2) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f_{x}(a,b)=-9,\;f_{y}(a,b)=0,\;f_{xx}(a,b)=-4,\;f_{yy}(a,b)=-5,\;f_{xy}(a,b)=-1 \)<div style="text-align:right;font-size:smaller">（問題整理番号:006）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview6">関数\( f(x,y) \)は点\( (a,b)=(7,-2) \)で，極小値を取る。</li><li title="点数:100"><input type="radio" name="preview6">関数\( f(x,y) \)は点\( (a,b)=(7,-2) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview6">関数\( f(x,y) \)は点\( (a,b)=(7,-2) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview6">関数\( f(x,y) \)は点\( (a,b)=(7,-2) \)で，極値を取るかは確定できない。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある\( C^2 \)級の関数\( f(x,y) \)は，点\( (a,b)=(10,-1) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f_{x}(a,b)=0,\;f_{y}(a,b)=-4,\;f_{xx}(a,b)=8,\;f_{yy}(a,b)=1,\;f_{xy}(a,b)=-1 \)<div style="text-align:right;font-size:smaller">（問題整理番号:131）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview131">関数\( f(x,y) \)は点\( (a,b)=(10,-1) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview131">関数\( f(x,y) \)は点\( (a,b)=(10,-1) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview131">関数\( f(x,y) \)は点\( (a,b)=(10,-1) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview131">関数\( f(x,y) \)は点\( (a,b)=(10,-1) \)で，極値を取るかは確定できない。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある\( C^2 \)級の関数\( f(x,y) \)は，点\( (a,b)=(10,8) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f_{x}(a,b)=0,\;f_{y}(a,b)=0,\;f_{xx}(a,b)=-1,\;f_{yy}(a,b)=1,\;f_{xy}(a,b)=2 \)<div style="text-align:right;font-size:smaller">（問題整理番号:086）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview86">関数\( f(x,y) \)は点\( (a,b)=(10,8) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview86">関数\( f(x,y) \)は点\( (a,b)=(10,8) \)で，極値を取るかは確定できない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview86">関数\( f(x,y) \)は点\( (a,b)=(10,8) \)で，極小値を取る。</li><li title="点数:100"><input type="radio" name="preview86">関数\( f(x,y) \)は点\( (a,b)=(10,8) \)で，極値を取らない。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある\( C^2 \)級の関数\( f(x,y) \)は，点\( (a,b)=(-2,9) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f_{x}(a,b)=0,\;f_{y}(a,b)=0,\;f_{xx}(a,b)=-3,\;f_{yy}(a,b)=10,\;f_{xy}(a,b)=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:111）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview111">関数\( f(x,y) \)は点\( (a,b)=(-2,9) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview111">関数\( f(x,y) \)は点\( (a,b)=(-2,9) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview111">関数\( f(x,y) \)は点\( (a,b)=(-2,9) \)で，極値を取るかは確定できない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview111">関数\( f(x,y) \)は点\( (a,b)=(-2,9) \)で，極大値を取る。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある\( C^2 \)級の関数\( f(x,y) \)は，点\( (a,b)=(9,-3) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f_{x}(a,b)=0,\;f_{y}(a,b)=0,\;f_{xx}(a,b)=4,\;f_{yy}(a,b)=-1,\;f_{xy}(a,b)=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:125）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview125">関数\( f(x,y) \)は点\( (a,b)=(9,-3) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview125">関数\( f(x,y) \)は点\( (a,b)=(9,-3) \)で，極値を取るかは確定できない。</li><li title="点数:100"><input type="radio" name="preview125">関数\( f(x,y) \)は点\( (a,b)=(9,-3) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview125">関数\( f(x,y) \)は点\( (a,b)=(9,-3) \)で，極小値を取る。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある\( C^2 \)級の関数\( f(x,y) \)は，点\( (a,b)=(4,8) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f_{x}(a,b)=9,\;f_{y}(a,b)=0,\;f_{xx}(a,b)=10,\;f_{yy}(a,b)=0,\;f_{xy}(a,b)=-1 \)<div style="text-align:right;font-size:smaller">（問題整理番号:122）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview122">関数\( f(x,y) \)は点\( (a,b)=(4,8) \)で，極値を取るかは確定できない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview122">関数\( f(x,y) \)は点\( (a,b)=(4,8) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview122">関数\( f(x,y) \)は点\( (a,b)=(4,8) \)で，極大値を取る。</li><li title="点数:100"><input type="radio" name="preview122">関数\( f(x,y) \)は点\( (a,b)=(4,8) \)で，極値を取らない。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある\( C^2 \)級の関数\( f(x,y) \)は，点\( (a,b)=(-2,-4) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f_{x}(a,b)=-1,\;f_{y}(a,b)=0,\;f_{xx}(a,b)=7,\;f_{yy}(a,b)=-2,\;f_{xy}(a,b)=-2 \)<div style="text-align:right;font-size:smaller">（問題整理番号:157）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview157">関数\( f(x,y) \)は点\( (a,b)=(-2,-4) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview157">関数\( f(x,y) \)は点\( (a,b)=(-2,-4) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview157">関数\( f(x,y) \)は点\( (a,b)=(-2,-4) \)で，極値を取るかは確定できない。</li><li title="点数:100"><input type="radio" name="preview157">関数\( f(x,y) \)は点\( (a,b)=(-2,-4) \)で，極値を取らない。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある\( C^2 \)級の関数\( f(x,y) \)は，点\( (a,b)=(10,-8) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f_{x}(a,b)=0,\;f_{y}(a,b)=0,\;f_{xx}(a,b)=4,\;f_{yy}(a,b)=-4,\;f_{xy}(a,b)=2 \)<div style="text-align:right;font-size:smaller">（問題整理番号:118）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview118">関数\( f(x,y) \)は点\( (a,b)=(10,-8) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview118">関数\( f(x,y) \)は点\( (a,b)=(10,-8) \)で，極小値を取る。</li><li title="点数:100"><input type="radio" name="preview118">関数\( f(x,y) \)は点\( (a,b)=(10,-8) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview118">関数\( f(x,y) \)は点\( (a,b)=(10,-8) \)で，極値を取るかは確定できない。</li></ol></div></div><div style="border: thin solid #00

# %%
if __name__ == "__main__":
    pass
    #qz.save('extremum_condition.xml')

# %% [markdown]
# ## extremum of polynomial of total degree 2

# %%
class extremum_of_polynomial(core.Question):
    name = '極値（全次数が2次の2変数多項式の場合の極値問題）'
    def __init__(self, emin=-4, emax=4):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='極値（2変数多項式）', quiz_number=_quiz_number)
        _x = sympy.Symbol('x')
        _y = sympy.Symbol('y')
        _t = random.choice([1,2,3,4])
        _c00 = random.randint(self.elem_min, self.elem_max)
        _c10 = random.randint(self.elem_min, self.elem_max)
        _c11 = random.randint(self.elem_min, self.elem_max)
        _c01 = random.randint(self.elem_min, self.elem_max)
        if _t == 1:
            _f = 4*_c00 + 4*_c10*_x - _x**2 + _c11**2*_x**2 + 4*_c01*_y + 4*_c11*_x*_y + 4*_y**2
            _a = 2*_c10 - _c01*_c11
            _b = (-_c01 - 2*_c10*_c11 + _c01*_c11**2)/sympy.Integer(2)
        elif _t == 2:
            _f = 4*_c00 + 4*_c10*_x + _x**2 - _c11**2*_x**2 + 4*_c01*_y + 4*_c11*_x*_y - 4*_y**2
            _a = -2*_c10 - _c01*_c11
            _b = (_c01 - 2*_c10*_c11 - _c01*_c11**2)/sympy.Integer(2)
        elif _t == 3:
            _f = 4*_c00 + 4*_c10*_x + _x**2 + _c11**2*_x**2 + 4*_c01*_y + 4*_c11*_x*_y + 4*_y**2
            _a = -2*_c10 + _c01*_c11
            _b = (-_c01 + 2*_c10*_c11 - _c01*_c11**2)/sympy.Integer(2)
        else:
            _f = 4*_c00 + 4*_c10*_x - _x**2 - _c11**2*_x**2 + 4*_c01*_y + 4*_c11*_x*_y - 4*_y**2
            _a = 2*_c10 + _c01*_c11
            _b = (_c01 + 2*_c10*_c11 + _c01*_c11**2)/sympy.Integer(2)
        quiz.quiz_identifier = hash(str(_a) + str(_b) + str(_f))
        # 正答の選択肢の生成
        _fxx = sympy.diff(_f,_x,_x).subs(_x,_a).subs(_y,_b)
        _fyy = sympy.diff(_f,_y,_y).subs(_x,_a).subs(_y,_b)
        _fxy = sympy.diff(_f,_x,_y).subs(_x,_a).subs(_y,_b)
        _dxy = _fxx*_fyy-_fxy**2        
        if _dxy < 0:
            _ans = 'no'
        elif _dxy > 0:
            if _fxx > 0:
                _ans = 'min'
            else:
                _ans = 'max'
        else:
            _ans = 'dontknow'        
        quiz.data = [_a, _b, _f, _x, _y, _fxx, _fyy, _fxy, _dxy, _ans]
        ans = { 'fraction': 100, 'data': [_a, _b, _ans]}
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_a, _b, _f, _x, _y, _fxx, _fyy, _fxy, _dxy, _ans] = quiz.data
        ans['feedback'] = r'極値を取るための必要条件と十分条件をそれぞれ確認してください。'
        if _ans != 'no':
            ans['data'] = [_a, _b, 'no']
            answers.append(dict(ans))
        if _ans != 'min':
            ans['data'] = [_a, _b, 'min']
            answers.append(dict(ans))
        if _ans != 'max':
            ans['data'] = [_a, _b, 'max']
            answers.append(dict(ans))
        if _ans != 'dontknow':
            ans['data'] = [_a, _b, 'dontknow']
            answers.append(dict(ans))
        _fx = sympy.diff(_f,_x)
        _fy = sympy.diff(_f,_y)
        _ia = random.randint(self.elem_min, self.elem_max)
        _ib = random.randint(self.elem_min, self.elem_max)
        while _fx.subs(_x,_ia).subs(_y,_ib) == 0:
            _ia = random.randint(self.elem_min, self.elem_max)
            _ib = random.randint(self.elem_min, self.elem_max)
        ans['data'] = [_ia, _ib, 'min']
        answers.append(dict(ans))
        ans['data'] = [_ia, _ib, 'max']
        answers.append(dict(ans))
        ans['data'] = [_ia, _ib, 'dontknow']
        answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_a, _b, _f, _x, _y, _fxx, _fyy, _fxy, _dxy, _ans] = quiz.data
        _text = r'次の関数\( f(x,y) \)の極値に関して最も適切な選択肢を選んでください。<br />'
        _text += r'\( f(x,y)=' + sympy.latex(_f) + r' \)'
        return _text
    def answer_text(self, ans):
        [_a, _b, _ans] = ans['data']
        _text = r'関数\( f(x,y) \)は点\( (a,b)=(' + sympy.latex(_a) + r',' + sympy.latex(_b) + r') \)で，'
        if _ans == 'no':
            _text += r'極値を取らない。'
        elif _ans == 'max':
            _text += r'極大値を取る。'
        elif _ans == 'min':
            _text += r'極小値を取る。'
        else:
            _text += r'極値を取るかは確定できない。'
        return _text

# %%
if __name__ == "__main__":
    q = extremum_of_polynomial()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の極値に関して最も適切な選択肢を選んでください。<br />\( f(x,y)=- x^{2} + 8 x - 4 y^{2} + 12 y \)<div style="text-align:right;font-size:smaller">（問題整理番号:059）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview59">関数\( f(x,y) \)は点\( (a,b)=(0,-1) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview59">関数\( f(x,y) \)は点\( (a,b)=(4,\frac{3}{2}) \)で，極小値を取る。</li><li title="点数:100"><input type="radio" name="preview59">関数\( f(x,y) \)は点\( (a,b)=(4,\frac{3}{2}) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview59">関数\( f(x,y) \)は点\( (a,b)=(0,-1) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview59">関数\( f(x,y) \)は点\( (a,b)=(4,\frac{3}{2}) \)で，極値を取るかは確定できない。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の極値に関して最も適切な選択肢を選んでください。<br />\( f(x,y)=- 2 x^{2} - 4 x y + 4 x - 4 y^{2} + 12 y - 12 \)<div style="text-align:right;font-size:smaller">（問題整理番号:073）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview73">関数\( f(x,y) \)は点\( (a,b)=(-1,2) \)で，極値を取るかは確定できない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview73">関数\( f(x,y) \)は点\( (a,b)=(-1,2) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview73">関数\( f(x,y) \)は点\( (a,b)=(-2,-1) \)で，極値を取るかは確定できない。</li><li title="点数:100"><input type="radio" name="preview73">関数\( f(x,y) \)は点\( (a,b)=(-1,2) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview73">関数\( f(x,y) \)は点\( (a,b)=(-1,2) \)で，極小値を取る。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の極値に関して最も適切な選択肢を選んでください。<br />\( f(x,y)=15 x^{2} + 16 x y + 4 y^{2} + 4 y - 8 \)<div style="text-align:right;font-size:smaller">（問題整理番号:061）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview61">関数\( f(x,y) \)は点\( (a,b)=(-4,\frac{15}{2}) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview61">関数\( f(x,y) \)は点\( (a,b)=(2,-4) \)で，極値を取るかは確定できない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview61">関数\( f(x,y) \)は点\( (a,b)=(-4,\frac{15}{2}) \)で，極値を取るかは確定できない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview61">関数\( f(x,y) \)は点\( (a,b)=(2,-4) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview61">関数\( f(x,y) \)は点\( (a,b)=(-4,\frac{15}{2}) \)で，極小値を取る。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の極値に関して最も適切な選択肢を選んでください。<br />\( f(x,y)=- 5 x^{2} + 8 x y - 12 x - 4 y^{2} - 4 y + 16 \)<div style="text-align:right;font-size:smaller">（問題整理番号:186）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview186">関数\( f(x,y) \)は点\( (a,b)=(-8,- \frac{17}{2}) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview186">関数\( f(x,y) \)は点\( (a,b)=(-8,- \frac{17}{2}) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview186">関数\( f(x,y) \)は点\( (a,b)=(-1,-1) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview186">関数\( f(x,y) \)は点\( (a,b)=(-1,-1) \)で，極値を取るかは確定できない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview186">関数\( f(x,y) \)は点\( (a,b)=(-1,-1) \)で，極大値を取る。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の極値に関して最も適切な選択肢を選んでください。<br />\( f(x,y)=3 x^{2} - 8 x y + 12 x + 4 y^{2} - 8 y - 8 \)<div style="text-align:right;font-size:smaller">（問題整理番号:180）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview180">関数\( f(x,y) \)は点\( (a,b)=(2,3) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview180">関数\( f(x,y) \)は点\( (a,b)=(2,3) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview180">関数\( f(x,y) \)は点\( (a,b)=(3,-3) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview180">関数\( f(x,y) \)は点\( (a,b)=(2,3) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview180">関数\( f(x,y) \)は点\( (a,b)=(3,-3) \)で，極大値を取る。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の極値に関して最も適切な選択肢を選んでください。<br />\( f(x,y)=- 8 x^{2} + 12 x y - 8 x - 4 y^{2} - 16 y + 16 \)<div style="text-align:right;font-size:smaller">（問題整理番号:137）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview137">関数\( f(x,y) \)は点\( (a,b)=(16,22) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview137">関数\( f(x,y) \)は点\( (a,b)=(-2,1) \)で，極値を取るかは確定できない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview137">関数\( f(x,y) \)は点\( (a,b)=(16,22) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview137">関数\( f(x,y) \)は点\( (a,b)=(16,22) \)で，極値を取るかは確定できない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview137">関数\( f(x,y) \)は点\( (a,b)=(-2,1) \)で，極大値を取る。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の極値に関して最も適切な選択肢を選んでください。<br />\( f(x,y)=10 x^{2} + 12 x y - 4 x + 4 y^{2} + 8 \)<div style="text-align:right;font-size:smaller">（問題整理番号:020）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview20">関数\( f(x,y) \)は点\( (a,b)=(2,-3) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview20">関数\( f(x,y) \)は点\( (a,b)=(2,-3) \)で，極値を取るかは確定できない。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview20">関数\( f(x,y) \)は点\( (a,b)=(4,0) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview20">関数\( f(x,y) \)は点\( (a,b)=(2,-3) \)で，極大値を取る。</li><li title="点数:100"><input type="radio" name="preview20">関数\( f(x,y) \)は点\( (a,b)=(2,-3) \)で，極小値を取る。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y) \)の極値に関して最も適切な選択肢を選んでください。<br />\( f(x,y)=15 x^{2} - 16 x y - 4 x + 4 y^{2} - 4 y - 16 \)<div style="text-align:right;font-size:smaller">（問題整理番号:140）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:極値を取るための必要条件と十分条件をそれぞれ確認してください。"><input type="radio" name="preview140">関数\( f(x,y) \)は点\( (a,b)=(-6,- \frac{23}{2}) \)で，極値を取るかは確定できない。</li><li title="点数:0
# フィードバック:極値を取

# %%
if __name__ == "__main__":
    pass
    #qz.save('extremum_of_polynomial.xml')

# %% [markdown]
# ## Lagrangian multipliers

# %%
class Lagrangian_multipliers(core.Question):
    name = 'ラグランジュの未定乗数法（解くべき方程式の確認）'
    def __init__(self, emin=-3, emax=3, nmin=0, nmax=3, tmin=1, tmax=3):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 生成する個々の次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 生成する単項式の個数の範囲
        self.term_min = tmin
        self.term_max = tmax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='ラグランジュの未定乗数法', quiz_number=_quiz_number)
        _x = sympy.Symbol('x')
        _y = sympy.Symbol('y')
        _r = sympy.Symbol('lambda')
        while True:
            _f = 0
            _nt = random.randint(self.term_min, self.term_max)
            _deg = []
            for _i in range(_nt+1):
                for _j in range(_nt+1):
                    if _i + _j <= _nt:
                        _deg.append([_i,_j])
            for _ds in random.sample(_deg,k=_nt):
                _f += nonzero_randint(self.elem_min, self.elem_max)*_x**_ds[0]*_y**_ds[1]
            _phi = 0
            _nt = random.randint(self.term_min, self.term_max)
            _deg = []
            for _i in range(_nt+1):
                for _j in range(_nt+1):
                    if _i + _j <= _nt:
                        _deg.append([_i,_j])
            for _ds in random.sample(_deg,k=_nt):
                _phi += nonzero_randint(self.elem_min, self.elem_max)*_x**_ds[0]*_y**_ds[1]
            _fx = sympy.diff(_f,_x)
            _fy = sympy.diff(_f,_y)
            _phix = sympy.diff(_phi,_x)
            _phiy = sympy.diff(_phi,_y)
            if _fx != _fy and _fx != _phix and _fx != _phiy and _fy != _phix and _fy != _phiy and _phix != _phiy and _f != 0 and _phi != 0 and not _phi.is_real:
                break
        quiz.quiz_identifier = hash(str(_f) + str(_phi))
        # 正答の選択肢の生成
        quiz.data = [_f, _x, _y, _phi, _r, _fx, _fy, _phix, _phiy]
        ans = { 'fraction': 100, 'data': [_fx, _fy, _phi, _phix, _phiy]}
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_f, _x, _y, _phi, _r, _fx, _fy, _phix, _phiy] = quiz.data
        ans['feedback'] = r'ラグランジュの未定乗数法に関して，教科書や資料を見直してください。'
        ans['data'] = [_fx, _fy, _phi, _phiy, _phix]
        answers.append(dict(ans))
        ans['data'] = [_fy, _fx, _phi, _phix, _phiy]
        answers.append(dict(ans))
        ans['data'] = [_fx, _fy, _f, _phix, _phiy]
        answers.append(dict(ans))
        ans['data'] = [_fx, _fy, _phix, _phi, _phiy]
        answers.append(dict(ans))
        ans['data'] = [_fx, _fy, _phiy, _phix, _phi]
        answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_f, _x, _y, _phi, _r, _fx, _fy, _phix, _phiy] = quiz.data
        _text = r'次の関数\( f(x,y),\;\varphi(x,y) \)に対して，制約条件\( \varphi(x,y)=0 \)のもとで，\( f(x,y) \)が極値を取る点を調べるために解くべき方程式として適切なものを選んでください。<br />'
        _text += r'\( f(x,y)=' + sympy.latex(_f) + r',\;\varphi(x,y)=' + sympy.latex(_phi) + r' \)'
        return _text
    def answer_text(self, ans):
        [_fx, _fy, _phi, _phix, _phiy] = ans['data']
        _text = r'\( \left\{\begin{array}{l}'
        if _fx != 0 or _phix != 0:
            _text += sympy.latex(_fx) + r'-\lambda\times\left(' + sympy.latex(_phix) + r'\right)=0\\' 
        if _fy != 0 or _phiy != 0:
            _text += sympy.latex(_fy) + r'-\lambda\times\left(' + sympy.latex(_phiy) + r'\right)=0\\' 
        if _phi != 0:
            _text += sympy.latex(_phi) + r'=0' 
        _text += r'\end{array}\right. \)'
        return _text

# %%
if __name__ == "__main__":
    q = Lagrangian_multipliers()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y),\;\varphi(x,y) \)に対して，制約条件\( \varphi(x,y)=0 \)のもとで，\( f(x,y) \)が極値を取る点を調べるために解くべき方程式として適切なものを選んでください。<br />\( f(x,y)=3 x^{2} + 3 y^{2} - 2,\;\varphi(x,y)=- 3 y \)<div style="text-align:right;font-size:smaller">（問題整理番号:088）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview88">\( \left\{\begin{array}{l}6 x-\lambda\times\left(0\right)=0\\6 y-\lambda\times\left(-3\right)=0\\- 3 y=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview88">\( \left\{\begin{array}{l}6 x-\lambda\times\left(0\right)=0\\6 y-\lambda\times\left(-3\right)=0\\3 x^{2} + 3 y^{2} - 2=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview88">\( \left\{\begin{array}{l}6 x-\lambda\times\left(- 3 y\right)=0\\6 y-\lambda\times\left(-3\right)=0\\\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview88">\( \left\{\begin{array}{l}6 x-\lambda\times\left(-3\right)=0\\6 y-\lambda\times\left(0\right)=0\\- 3 y=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview88">\( \left\{\begin{array}{l}6 y-\lambda\times\left(0\right)=0\\6 x-\lambda\times\left(-3\right)=0\\- 3 y=0\end{array}\right. \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y),\;\varphi(x,y) \)に対して，制約条件\( \varphi(x,y)=0 \)のもとで，\( f(x,y) \)が極値を取る点を調べるために解くべき方程式として適切なものを選んでください。<br />\( f(x,y)=x,\;\varphi(x,y)=x y + 2 y^{2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:062）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview62">\( \left\{\begin{array}{l}0-\lambda\times\left(y\right)=0\\1-\lambda\times\left(x + 4 y\right)=0\\x y + 2 y^{2}=0\end{array}\right. \)</li><li title="点数:100"><input type="radio" name="preview62">\( \left\{\begin{array}{l}1-\lambda\times\left(y\right)=0\\0-\lambda\times\left(x + 4 y\right)=0\\x y + 2 y^{2}=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview62">\( \left\{\begin{array}{l}1-\lambda\times\left(x y + 2 y^{2}\right)=0\\0-\lambda\times\left(x + 4 y\right)=0\\y=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview62">\( \left\{\begin{array}{l}1-\lambda\times\left(y\right)=0\\0-\lambda\times\left(x + 4 y\right)=0\\x=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview62">\( \left\{\begin{array}{l}1-\lambda\times\left(x + 4 y\right)=0\\0-\lambda\times\left(y\right)=0\\x y + 2 y^{2}=0\end{array}\right. \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y),\;\varphi(x,y) \)に対して，制約条件\( \varphi(x,y)=0 \)のもとで，\( f(x,y) \)が極値を取る点を調べるために解くべき方程式として適切なものを選んでください。<br />\( f(x,y)=x + 2,\;\varphi(x,y)=3 x^{3} + 3 x y + 2 y \)<div style="text-align:right;font-size:smaller">（問題整理番号:137）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview137">\( \left\{\begin{array}{l}1-\lambda\times\left(3 x + 2\right)=0\\0-\lambda\times\left(9 x^{2} + 3 y\right)=0\\3 x^{3} + 3 x y + 2 y=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview137">\( \left\{\begin{array}{l}1-\lambda\times\left(9 x^{2} + 3 y\right)=0\\0-\lambda\times\left(3 x + 2\right)=0\\x + 2=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview137">\( \left\{\begin{array}{l}0-\lambda\times\left(9 x^{2} + 3 y\right)=0\\1-\lambda\times\left(3 x + 2\right)=0\\3 x^{3} + 3 x y + 2 y=0\end{array}\right. \)</li><li title="点数:100"><input type="radio" name="preview137">\( \left\{\begin{array}{l}1-\lambda\times\left(9 x^{2} + 3 y\right)=0\\0-\lambda\times\left(3 x + 2\right)=0\\3 x^{3} + 3 x y + 2 y=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview137">\( \left\{\begin{array}{l}1-\lambda\times\left(9 x^{2} + 3 y\right)=0\\0-\lambda\times\left(3 x^{3} + 3 x y + 2 y\right)=0\\3 x + 2=0\end{array}\right. \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y),\;\varphi(x,y) \)に対して，制約条件\( \varphi(x,y)=0 \)のもとで，\( f(x,y) \)が極値を取る点を調べるために解くべき方程式として適切なものを選んでください。<br />\( f(x,y)=x^{3} - y^{3} + 3,\;\varphi(x,y)=3 x \)<div style="text-align:right;font-size:smaller">（問題整理番号:058）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview58">\( \left\{\begin{array}{l}- 3 y^{2}-\lambda\times\left(3\right)=0\\3 x^{2}-\lambda\times\left(0\right)=0\\3 x=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview58">\( \left\{\begin{array}{l}3 x^{2}-\lambda\times\left(3\right)=0\\- 3 y^{2}-\lambda\times\left(3 x\right)=0\\\end{array}\right. \)</li><li title="点数:100"><input type="radio" name="preview58">\( \left\{\begin{array}{l}3 x^{2}-\lambda\times\left(3\right)=0\\- 3 y^{2}-\lambda\times\left(0\right)=0\\3 x=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview58">\( \left\{\begin{array}{l}3 x^{2}-\lambda\times\left(3\right)=0\\- 3 y^{2}-\lambda\times\left(0\right)=0\\x^{3} - y^{3} + 3=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview58">\( \left\{\begin{array}{l}3 x^{2}-\lambda\times\left(3 x\right)=0\\- 3 y^{2}-\lambda\times\left(0\right)=0\\3=0\end{array}\right. \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次の関数\( f(x,y),\;\varphi(x,y) \)に対して，制約条件\( \varphi(x,y)=0 \)のもとで，\( f(x,y) \)が極値を取る点を調べるために解くべき方程式として適切なものを選んでください。<br />\( f(x,y)=3 x,\;\varphi(x,y)=- 2 x^{2} y + 3 x y + 3 y^{2} \)<div style="text-align:right;font-size:smaller">（問題整理番号:164）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview164">\( \left\{\begin{array}{l}0-\lambda\times\left(- 4 x y + 3 y\right)=0\\3-\lambda\times\left(- 2 x^{2} + 3 x + 6 y\right)=0\\- 2 x^{2} y + 3 x y + 3 y^{2}=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview164">\( \left\{\begin{array}{l}3-\lambda\times\left(- 4 x y + 3 y\right)=0\\0-\lambda\times\left(- 2 x^{2} + 3 x + 6 y\right)=0\\3 x=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview164">\( \left\{\begin{array}{l}3-\lambda\times\left(- 2 x^{2} + 3 x + 6 y\right)=0\\0-\lambda\times\left(- 4 x y + 3 y\right)=0\\- 2 x^{2} y + 3 x y + 3 y^{2}=0\end{array}\right. \)</li><li title="点数:0
# フィードバック:ラグランジュの未定乗数法に関して，教科書や資料を見直してください。"><input type="radio" name="preview164">\( \left\{\begin{array}{l}3-\lambda\times\left(- 4 x y + 3 y\right)=0\\0-\lambda\times\left(- 2 x^{2} y + 3 x y + 3 y^{2}\right)=0\\- 2 x^{2} + 3 x + 6 y=0\end{array}\right. \)</li><li title="点数:100"><input type="radio" name="preview164">\( \left\{\begin{array}{l}3-\lambda\times\left(- 4 x y + 3 y\right)=0\\0-\l

# %%
if __name__ == "__main__":
    pass
    #qz.save('Lagrangian_multipliers.xml')

# %% [markdown]
# ## derivative of implicit function

# %%
class derivative_of_implicit_function(core.Question):
    name = '陰関数の導関数（陰関数定理）'
    def __init__(self, emin=-3, emax=3, nmin=0, nmax=3, tmin=1, tmax=3):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 生成する個々の次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 生成する単項式の個数の範囲
        self.term_min = tmin
        self.term_max = tmax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='陰関数の導関数', quiz_number=_quiz_number)
        _x = sympy.Symbol('x')
        _y = sympy.Symbol('y')
        while True:
            _f = 0
            _nt = random.randint(self.term_min, self.term_max)
            _deg = []
            for _i in range(_nt+1):
                for _j in range(_nt+1):
                    if _i + _j <= _nt:
                        _deg.append([_i,_j])
            for _ds in random.sample(_deg,k=_nt):
                _f += nonzero_randint(self.elem_min, self.elem_max)*_x**_ds[0]*_y**_ds[1]
            _fx = sympy.diff(_f,_x)
            _fy = sympy.diff(_f,_y)
            if _fx != _fy and _f != 0 and _fx != 0 and _fy != 0:
                break
        quiz.quiz_identifier = hash(str(_f))
        # 正答の選択肢の生成
        quiz.data = [_f, _x, _y, _fx, _fy]
        ans = { 'fraction': 100, 'data': -_fx/_fy}
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_f, _x, _y, _fx, _fy] = quiz.data
        if sympy.expand(_fx + _fx*_fy) != 0:
            ans['feedback'] = r'陰関数定理を確認しましょう。'
            ans['data'] = _fx
            answers.append(dict(ans))
        if sympy.expand(_fx + _fy*_fy) != 0:
            ans['feedback'] = r'陰関数定理を確認しましょう。'
            ans['data'] = _fy
            answers.append(dict(ans))
        ans['feedback'] = r'陰関数定理を確認しましょう。符号がおかしい可能性があります。'
        ans['data'] = _fx/_fy
        answers.append(dict(ans))
        ans['feedback'] = r'陰関数定理を確認しましょう。偏導関数の上下を確認しましょう。'
        ans['data'] = -_fy/_fx
        answers.append(dict(ans))
        ans['feedback'] = r'陰関数定理を確認しましょう。符号や偏導関数の上下を確認しましょう。'
        ans['data'] = _fy/_fx
        answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_f, _x, _y, _fx, _fy] = quiz.data
        _text = r'次式で定義される陰関数\( f(x,y)=0 \)に関して，その導関数\( \frac{dy}{dx} \)を求めてください。<br />'
        _text += r'\( f(x,y)=' + sympy.latex(_f) + r'=0 \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' + sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = derivative_of_implicit_function()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その導関数\( \frac{dy}{dx} \)を求めてください。<br />\( f(x,y)=x + 3 y^{2}=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:039）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。偏導関数の上下を確認しましょう。"><input type="radio" name="preview39">\( - 6 y \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview39">\( 1 \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview39">\( 6 y \)</li><li title="点数:100"><input type="radio" name="preview39">\( - \frac{1}{6 y} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。符号がおかしい可能性があります。"><input type="radio" name="preview39">\( \frac{1}{6 y} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その導関数\( \frac{dy}{dx} \)を求めてください。<br />\( f(x,y)=x y + 3 y^{3} + y^{2}=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:090）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。符号がおかしい可能性があります。"><input type="radio" name="preview90">\( \frac{y}{x + 9 y^{2} + 2 y} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview90">\( y \)</li><li title="点数:100"><input type="radio" name="preview90">\( - \frac{y}{x + 9 y^{2} + 2 y} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。偏導関数の上下を確認しましょう。"><input type="radio" name="preview90">\( \frac{- x - 9 y^{2} - 2 y}{y} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview90">\( x + 9 y^{2} + 2 y \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その導関数\( \frac{dy}{dx} \)を求めてください。<br />\( f(x,y)=- 3 x^{2} y - y - 1=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:088）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview88">\( - 6 x y \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview88">\( - 3 x^{2} - 1 \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。偏導関数の上下を確認しましょう。"><input type="radio" name="preview88">\( - \frac{3 x^{2} + 1}{6 x y} \)</li><li title="点数:100"><input type="radio" name="preview88">\( \frac{6 x y}{- 3 x^{2} - 1} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。符号や偏導関数の上下を確認しましょう。"><input type="radio" name="preview88">\( - \frac{- 3 x^{2} - 1}{6 x y} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その導関数\( \frac{dy}{dx} \)を求めてください。<br />\( f(x,y)=2 x y + 2 y^{2}=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:200）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。符号がおかしい可能性があります。"><input type="radio" name="preview200">\( \frac{2 y}{2 x + 4 y} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview200">\( 2 y \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。偏導関数の上下を確認しましょう。"><input type="radio" name="preview200">\( \frac{- 2 x - 4 y}{2 y} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview200">\( 2 x + 4 y \)</li><li title="点数:100"><input type="radio" name="preview200">\( - \frac{2 y}{2 x + 4 y} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その導関数\( \frac{dy}{dx} \)を求めてください。<br />\( f(x,y)=3 x^{3} - 3 x y - 2=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:084）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。符号や偏導関数の上下を確認しましょう。"><input type="radio" name="preview84">\( - \frac{3 x}{9 x^{2} - 3 y} \)</li><li title="点数:100"><input type="radio" name="preview84">\( - \frac{- 9 x^{2} + 3 y}{3 x} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview84">\( - 3 x \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。符号がおかしい可能性があります。"><input type="radio" name="preview84">\( - \frac{9 x^{2} - 3 y}{3 x} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。偏導関数の上下を確認しましょう。"><input type="radio" name="preview84">\( \frac{3 x}{9 x^{2} - 3 y} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その導関数\( \frac{dy}{dx} \)を求めてください。<br />\( f(x,y)=3 x y - 3 y^{2}=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:087）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview87">\( 3 x - 6 y \)</li><li title="点数:100"><input type="radio" name="preview87">\( - \frac{3 y}{3 x - 6 y} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。偏導関数の上下を確認しましょう。"><input type="radio" name="preview87">\( \frac{- 3 x + 6 y}{3 y} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview87">\( 3 y \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。符号がおかしい可能性があります。"><input type="radio" name="preview87">\( \frac{3 y}{3 x - 6 y} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その導関数\( \frac{dy}{dx} \)を求めてください。<br />\( f(x,y)=- 2 x y - 3 x=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:113）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。符号がおかしい可能性があります。"><input type="radio" name="preview113">\( - \frac{- 2 y - 3}{2 x} \)</li><li title="点数:100"><input type="radio" name="preview113">\( - \frac{2 y + 3}{2 x} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。偏導関数の上下を確認しましょう。"><input type="radio" name="preview113">\( \frac{2 x}{- 2 y - 3} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。符号や偏導関数の上下を確認しましょう。"><input type="radio" name="preview113">\( - \frac{2 x}{- 2 y - 3} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview113">\( - 2 x \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その導関数\( \frac{dy}{dx} \)を求めてください。<br />\( f(x,y)=2 x y + y^{2}=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:074）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。符号や偏導関数の上下を確認しましょう。"><input type="radio" name="preview74">\( \frac{2 x + 2 y}{2 y} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview74">\( 2 y \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。符号がおかしい可能性があります。"><input type="radio" name="preview74">\( \frac{2 y}{2 x + 2 y} \)</li><li title="点数:100"><input type="radio" name="preview74">\( - \frac{2 y}{2 x + 2 y} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。偏導関数の上下を確認しましょう。"><input type="radio" name="preview74">\( \frac{- 2 x - 2 y}{2 y} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その導関数\( \frac{dy}{dx} \)を求めてください。<br />\( f(x,y)=- 2 x^{2} + 2 x + 2 y=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:069）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。符号や偏導関数の上下を確認しましょう。"><input type="radio" name="preview69">\( \frac{2}{- 4 x + 2} \)</li><li title="点数:0
# フィードバック:陰関数定理を確認しましょう。"><input type="radio" name="preview69">\( - 4 x + 2 \)</li><li title="点数:100"><input type="radio" name="preview69">\( 2 x - 1 \)</li><li title="点数:0
# フィード

# %%
if __name__ == "__main__":
    pass
    #qz.save('derivative_of_implicit_function.xml')

# %% [markdown]
# ## second derivative of implicit function

# %%
class second_derivative_of_implicit_function(core.Question):
    name = '陰関数の2階導関数（陰関数定理）'
    def __init__(self, emin=-3, emax=3, nmin=1, nmax=2, tmin=1, tmax=2):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
        # 生成する個々の次数の範囲
        self.deg_min = nmin
        self.deg_max = nmax
        # 生成する単項式の個数の範囲
        self.term_min = tmin
        self.term_max = tmax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='陰関数の2階導関数', quiz_number=_quiz_number)
        _x = sympy.Symbol('x')
        _y = sympy.Symbol('y')
        while True:
            _f = 0
            _nt = random.randint(self.term_min, self.term_max)
            _deg = []
            for _i in range(_nt+1):
                for _j in range(_nt+1):
                    if _i + _j <= _nt:
                        _deg.append([_i,_j])
            for _ds in random.sample(_deg,k=_nt):
                _f += nonzero_randint(self.elem_min, self.elem_max)*_x**_ds[0]*_y**_ds[1]
            _fx = sympy.diff(_f,_x)
            _fy = sympy.diff(_f,_y)
            if _fx != _fy and _f != 0 and _fx != 0 and _fy != 0:
                break
        _fxx = sympy.diff(_f,_x,_x)
        _fyy = sympy.diff(_f,_y,_y)
        _fxy = sympy.diff(_f,_x,_y)
        quiz.quiz_identifier = hash(str(_f))
        # 正答の選択肢の生成
        quiz.data = [_f, _x, _y, _fx, _fy, _fxx, _fyy, _fxy]
        _ans = sympy.expand(2*_fx*_fy*_fxy-_fx*_fx*_fyy-_fy*_fy*_fxx)
        ans = { 'fraction': 100, 'data': _ans/_fy**3}
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_f, _x, _y, _fx, _fy, _fxx, _fyy, _fxy] = quiz.data
        _num = sympy.expand(2*_fx*_fy*_fxy-_fx*_fx*_fyy-_fy*_fy*_fxx)
        if _num != 0:
            ans['feedback'] = r'資料や教科書を確認しましょう。符号を取り違えている可能性があります。'
            ans['data'] = -_num/_fy**3
            answers.append(dict(ans))
        if _fx != _fy:
            ans['feedback'] = r'資料や教科書を確認しましょう。偏導関数の一部を取り違えている可能性があります。'
            ans['data'] = _num/_fx**3
            answers.append(dict(ans))
        if _num != 0 and _fx != _fy:
            ans['feedback'] = r'資料や教科書を確認しましょう。偏導関数の一部や符号を取り違えている可能性があります。'
            ans['data'] = -_num/_fx**3
            answers.append(dict(ans))
        _incorrect_num = sympy.expand(2*_fx*_fy*_fxy+_fx*_fx*_fyy+_fy*_fy*_fxx)
        if _num != _incorrect_num:
            ans['feedback'] = r'資料や教科書を確認しましょう。符号を取り違えている可能性があります。'
            ans['data'] = _incorrect_num/_fy**3
            answers.append(dict(ans))
        if _num != -_incorrect_num:
            ans['feedback'] = r'資料や教科書を確認しましょう。符号を取り違えている可能性があります。'
            ans['data'] = -_incorrect_num/_fy**3
            answers.append(dict(ans))
        if sympy.expand(_num*_fx**3-_incorrect_num*_fy**3) != 0:
            ans['feedback'] = r'資料や教科書を確認しましょう。色々と取り違えている可能性があります。'
            ans['data'] = _incorrect_num/_fx**3
            answers.append(dict(ans))
        if sympy.expand(_num*_fx**3+_incorrect_num*_fy**3) != 0:
            ans['feedback'] = r'資料や教科書を確認しましょう。色々と取り違えている可能性があります。'
            ans['data'] = -_incorrect_num/_fx**3
            answers.append(dict(ans))            
        answers = common.answer_union(answers)
        while len(answers) < size:
            ans['feedback'] = r'資料や教科書を確認しましょう。色々と取り違えている可能性があります。'
            ans['data'] = random.randint(self.elem_min, self.elem_max)
            answers.append(dict(ans))   
            answers = common.answer_union(answers)            
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_f, _x, _y, _fx, _fy, _fxx, _fyy, _fxy] = quiz.data
        _text = r'次式で定義される陰関数\( f(x,y)=0 \)に関して，その2階導関数\( \frac{d^2y}{dx^2} \)を求めてください。<br />'
        _text += r'\( f(x,y)=' + sympy.latex(_f) + r'=0 \)'
        return _text
    def answer_text(self, ans):
        return r'\( ' + sympy.latex(ans['data'], order='lex') + r' \)'

# %%
if __name__ == "__main__":
    q = second_derivative_of_implicit_function()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その2階導関数\( \frac{d^2y}{dx^2} \)を求めてください。<br />\( f(x,y)=2 x y - y^{2}=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:170）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview170">\( \frac{16 x y - 8 y^{2}}{\left(2 x - 2 y\right)^{3}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview170">\( \frac{- 16 x y + 24 y^{2}}{8 y^{3}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。符号を取り違えている可能性があります。"><input type="radio" name="preview170">\( \frac{16 x y - 24 y^{2}}{\left(2 x - 2 y\right)^{3}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview170">\( \frac{16 x y - 24 y^{2}}{8 y^{3}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。偏導関数の一部を取り違えている可能性があります。"><input type="radio" name="preview170">\( \frac{16 x y - 8 y^{2}}{8 y^{3}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その2階導関数\( \frac{d^2y}{dx^2} \)を求めてください。<br />\( f(x,y)=2 x - y=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:193）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview193">\( -3 \)</li><li title="点数:100"><input type="radio" name="preview193">\( 0 \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview193">\( 3 \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview193">\( -2 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その2階導関数\( \frac{d^2y}{dx^2} \)を求めてください。<br />\( f(x,y)=x y + 2 y=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:092）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview92">\( 0 \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。偏導関数の一部を取り違えている可能性があります。"><input type="radio" name="preview92">\( \frac{2 x y + 4 y}{y^{3}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。偏導関数の一部や符号を取り違えている可能性があります。"><input type="radio" name="preview92">\( \frac{- 2 x y - 4 y}{y^{3}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。符号を取り違えている可能性があります。"><input type="radio" name="preview92">\( \frac{- 2 x y - 4 y}{\left(x + 2\right)^{3}} \)</li><li title="点数:100"><input type="radio" name="preview92">\( \frac{2 x y + 4 y}{\left(x + 2\right)^{3}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その2階導関数\( \frac{d^2y}{dx^2} \)を求めてください。<br />\( f(x,y)=- 3 x + y=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:136）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview136">\( 2 \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview136">\( -3 \)</li><li title="点数:100"><input type="radio" name="preview136">\( 0 \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview136">\( -1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その2階導関数\( \frac{d^2y}{dx^2} \)を求めてください。<br />\( f(x,y)=3 x y - 1=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:199）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview199">\( -3 \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。符号を取り違えている可能性があります。"><input type="radio" name="preview199">\( - \frac{2 y}{x^{2}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。偏導関数の一部や符号を取り違えている可能性があります。"><input type="radio" name="preview199">\( - \frac{2 x}{y^{2}} \)</li><li title="点数:100"><input type="radio" name="preview199">\( \frac{2 y}{x^{2}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。偏導関数の一部を取り違えている可能性があります。"><input type="radio" name="preview199">\( \frac{2 x}{y^{2}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その2階導関数\( \frac{d^2y}{dx^2} \)を求めてください。<br />\( f(x,y)=3 x^{2} + 2 y=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:138）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。偏導関数の一部や符号を取り違えている可能性があります。"><input type="radio" name="preview138">\( \frac{1}{9 x^{3}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。偏導関数の一部を取り違えている可能性があります。"><input type="radio" name="preview138">\( - \frac{1}{9 x^{3}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。符号を取り違えている可能性があります。"><input type="radio" name="preview138">\( 3 \)</li><li title="点数:100"><input type="radio" name="preview138">\( -3 \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview138">\( 1 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その2階導関数\( \frac{d^2y}{dx^2} \)を求めてください。<br />\( f(x,y)=2 x^{2} + 2 y^{2}=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:086）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。偏導関数の一部や符号を取り違えている可能性があります。"><input type="radio" name="preview86">\( \frac{64 x^{2} + 64 y^{2}}{64 x^{3}} \)</li><li title="点数:100"><input type="radio" name="preview86">\( \frac{- 64 x^{2} - 64 y^{2}}{64 y^{3}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。符号を取り違えている可能性があります。"><input type="radio" name="preview86">\( \frac{64 x^{2} + 64 y^{2}}{64 y^{3}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。偏導関数の一部を取り違えている可能性があります。"><input type="radio" name="preview86">\( \frac{- 64 x^{2} - 64 y^{2}}{64 x^{3}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview86">\( 0 \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その2階導関数\( \frac{d^2y}{dx^2} \)を求めてください。<br />\( f(x,y)=3 x y - 3=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:126）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。符号を取り違えている可能性があります。"><input type="radio" name="preview126">\( - \frac{2 y}{x^{2}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview126">\( 2 \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。偏導関数の一部や符号を取り違えている可能性があります。"><input type="radio" name="preview126">\( - \frac{2 x}{y^{2}} \)</li><li title="点数:100"><input type="radio" name="preview126">\( \frac{2 y}{x^{2}} \)</li><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。偏導関数の一部を取り違えている可能性があります。"><input type="radio" name="preview126">\( \frac{2 x}{y^{2}} \)</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">次式で定義される陰関数\( f(x,y)=0 \)に関して，その2階導関数\( \frac{d^2y}{dx^2} \)を求めてください。<br />\( f(x,y)=- x - 2 y=0 \)<div style="text-align:right;font-size:smaller">（問題整理番号:131）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:資料や教科書を確認しましょう。色々と取り違えている可能性があります。"><input type="radio" name="preview131">\( 3 \)</li><li title="点数:0
# フ

# %%
if __name__ == "__main__":
    pass
    #qz.save('second_derivative_of_implicit_function.xml')

# %% [markdown]
# ## extremum condition of implicit function

# %%
class extremum_condition_of_implicit_function(core.Question):
    name = '陰関数が極値を取るための条件'
    def __init__(self, emin=-10, emax=10):
        # 生成する個々の係数等の範囲
        self.elem_min = emin
        self.elem_max = emax
    def question_generate(self, _quiz_number=0):
        quiz = core.Quiz(name='陰関数の極値の条件', quiz_number=_quiz_number)
        _a = random.randint(self.elem_min, self.elem_max)
        _b = random.randint(self.elem_min, self.elem_max)
        _fx = random.choice([0,0,0,0,0,1])*random.randint(self.elem_min, self.elem_max)
        _fy = random.choice([1,1,1,1,1,0])*random.randint(self.elem_min, self.elem_max)
        _fxx = nonzero_randint(self.elem_min, self.elem_max)
        quiz.quiz_identifier = hash(str(_a) + str(_b) + str(_fx) + str(_fy) + str(_fxx))
        # 正答の選択肢の生成
        if _fy == 0:
            _ans = 'nodef'
        elif _fx != 0:
            _ans = 'no'
        elif _fxx*_fy < 0:
            _ans = 'min'
        else:
            _ans = 'max'
        quiz.data = [_a, _b, _fx, _fy, _fxx, _ans]
        ans = { 'fraction': 100, 'data': [_a, _b, _ans]}
        quiz.answers.append(ans)
        return quiz        
    def correct_answers_generate(self, quiz, size=1):
        # 正答を個別には作らないので何もしない
        pass
    def incorrect_answers_generate(self, quiz, size=4):
        answers = []
        ans = { 'fraction': 0 }
        [_a, _b, _fx, _fy, _fxx, _ans] = quiz.data
        ans['feedback'] = r'資料や教科書で極値を取るための陰関数の条件を確認してください。'
        if _ans != 'no':
            ans['data'] = [_a, _b, 'no']
            answers.append(dict(ans))
        if _ans != 'min':
            ans['data'] = [_a, _b, 'min']
            answers.append(dict(ans))
        if _ans != 'max':
            ans['data'] = [_a, _b, 'max']
            answers.append(dict(ans))
        if _ans != 'nodef':
            ans['data'] = [_a, _b, 'nodef']
            answers.append(dict(ans))
        answers = common.answer_union(answers)
        if len(answers) >= size:
            return random.sample(answers,k=size)
        return answers    
    def question_text(self, quiz):
        [_a, _b, _fx, _fy, _fxx, _ans] = quiz.data
        _text = r'ある陰関数\( f(x,y)=0 \)は，点\( (a,b)=(' + sympy.latex(_a) + r',' + sympy.latex(_b) + r') \)において，'
        _text += r'それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />'
        _text += r'\( f(a,b)=0,\;'
        _text += r'f_{x}(a,b)=' + sympy.latex(_fx) + r',\;'
        _text += r'f_{y}(a,b)=' + sympy.latex(_fy) + r',\;'
        _text += r'f_{xx}(a,b)=' + sympy.latex(_fxx) + r' \)'
        return _text
    def answer_text(self, ans):
        [_a, _b, _ans] = ans['data']
        _text = r'陰関数\( f(x,y) \)は点\( (a,b)=(' + sympy.latex(_a) + r',' + sympy.latex(_b) + r') \)で，'
        if _ans == 'no':
            _text += r'極値を取らない。'
        elif _ans == 'max':
            _text += r'極大値を取る。'
        elif _ans == 'min':
            _text += r'極小値を取る。'
        else:
            _text += r'陰関数定理の条件を満たさない。'
        return _text

# %%
if __name__ == "__main__":
    q = extremum_condition_of_implicit_function()
    qz = core.generate(q, size=200, category=q.name)
    qz.preview(size=25)
# Out:
# <div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある陰関数\( f(x,y)=0 \)は，点\( (a,b)=(-5,-8) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f(a,b)=0,\;f_{x}(a,b)=0,\;f_{y}(a,b)=10,\;f_{xx}(a,b)=-9 \)<div style="text-align:right;font-size:smaller">（問題整理番号:049）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview49">陰関数\( f(x,y) \)は点\( (a,b)=(-5,-8) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview49">陰関数\( f(x,y) \)は点\( (a,b)=(-5,-8) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview49">陰関数\( f(x,y) \)は点\( (a,b)=(-5,-8) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview49">陰関数\( f(x,y) \)は点\( (a,b)=(-5,-8) \)で，陰関数定理の条件を満たさない。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある陰関数\( f(x,y)=0 \)は，点\( (a,b)=(-7,-2) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f(a,b)=0,\;f_{x}(a,b)=0,\;f_{y}(a,b)=-3,\;f_{xx}(a,b)=-7 \)<div style="text-align:right;font-size:smaller">（問題整理番号:005）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview5">陰関数\( f(x,y) \)は点\( (a,b)=(-7,-2) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview5">陰関数\( f(x,y) \)は点\( (a,b)=(-7,-2) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview5">陰関数\( f(x,y) \)は点\( (a,b)=(-7,-2) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview5">陰関数\( f(x,y) \)は点\( (a,b)=(-7,-2) \)で，陰関数定理の条件を満たさない。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある陰関数\( f(x,y)=0 \)は，点\( (a,b)=(3,-2) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f(a,b)=0,\;f_{x}(a,b)=0,\;f_{y}(a,b)=10,\;f_{xx}(a,b)=-7 \)<div style="text-align:right;font-size:smaller">（問題整理番号:123）</div><ol style="list-style-type:none"><li title="点数:100"><input type="radio" name="preview123">陰関数\( f(x,y) \)は点\( (a,b)=(3,-2) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview123">陰関数\( f(x,y) \)は点\( (a,b)=(3,-2) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview123">陰関数\( f(x,y) \)は点\( (a,b)=(3,-2) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview123">陰関数\( f(x,y) \)は点\( (a,b)=(3,-2) \)で，陰関数定理の条件を満たさない。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある陰関数\( f(x,y)=0 \)は，点\( (a,b)=(8,1) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f(a,b)=0,\;f_{x}(a,b)=0,\;f_{y}(a,b)=9,\;f_{xx}(a,b)=-3 \)<div style="text-align:right;font-size:smaller">（問題整理番号:036）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview36">陰関数\( f(x,y) \)は点\( (a,b)=(8,1) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview36">陰関数\( f(x,y) \)は点\( (a,b)=(8,1) \)で，陰関数定理の条件を満たさない。</li><li title="点数:100"><input type="radio" name="preview36">陰関数\( f(x,y) \)は点\( (a,b)=(8,1) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview36">陰関数\( f(x,y) \)は点\( (a,b)=(8,1) \)で，極大値を取る。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある陰関数\( f(x,y)=0 \)は，点\( (a,b)=(-6,-7) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f(a,b)=0,\;f_{x}(a,b)=0,\;f_{y}(a,b)=8,\;f_{xx}(a,b)=-10 \)<div style="text-align:right;font-size:smaller">（問題整理番号:069）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview69">陰関数\( f(x,y) \)は点\( (a,b)=(-6,-7) \)で，極値を取らない。</li><li title="点数:100"><input type="radio" name="preview69">陰関数\( f(x,y) \)は点\( (a,b)=(-6,-7) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview69">陰関数\( f(x,y) \)は点\( (a,b)=(-6,-7) \)で，陰関数定理の条件を満たさない。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview69">陰関数\( f(x,y) \)は点\( (a,b)=(-6,-7) \)で，極大値を取る。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある陰関数\( f(x,y)=0 \)は，点\( (a,b)=(5,0) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f(a,b)=0,\;f_{x}(a,b)=5,\;f_{y}(a,b)=3,\;f_{xx}(a,b)=-10 \)<div style="text-align:right;font-size:smaller">（問題整理番号:083）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview83">陰関数\( f(x,y) \)は点\( (a,b)=(5,0) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview83">陰関数\( f(x,y) \)は点\( (a,b)=(5,0) \)で，陰関数定理の条件を満たさない。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview83">陰関数\( f(x,y) \)は点\( (a,b)=(5,0) \)で，極大値を取る。</li><li title="点数:100"><input type="radio" name="preview83">陰関数\( f(x,y) \)は点\( (a,b)=(5,0) \)で，極値を取らない。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある陰関数\( f(x,y)=0 \)は，点\( (a,b)=(-4,2) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f(a,b)=0,\;f_{x}(a,b)=0,\;f_{y}(a,b)=7,\;f_{xx}(a,b)=-6 \)<div style="text-align:right;font-size:smaller">（問題整理番号:166）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview166">陰関数\( f(x,y) \)は点\( (a,b)=(-4,2) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview166">陰関数\( f(x,y) \)は点\( (a,b)=(-4,2) \)で，陰関数定理の条件を満たさない。</li><li title="点数:100"><input type="radio" name="preview166">陰関数\( f(x,y) \)は点\( (a,b)=(-4,2) \)で，極小値を取る。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview166">陰関数\( f(x,y) \)は点\( (a,b)=(-4,2) \)で，極値を取らない。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある陰関数\( f(x,y)=0 \)は，点\( (a,b)=(-8,2) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f(a,b)=0,\;f_{x}(a,b)=0,\;f_{y}(a,b)=8,\;f_{xx}(a,b)=7 \)<div style="text-align:right;font-size:smaller">（問題整理番号:034）</div><ol style="list-style-type:none"><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview34">陰関数\( f(x,y) \)は点\( (a,b)=(-8,2) \)で，極値を取らない。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview34">陰関数\( f(x,y) \)は点\( (a,b)=(-8,2) \)で，極小値を取る。</li><li title="点数:100"><input type="radio" name="preview34">陰関数\( f(x,y) \)は点\( (a,b)=(-8,2) \)で，極大値を取る。</li><li title="点数:0
# フィードバック:資料や教科書で極値を取るための陰関数の条件を確認してください。"><input type="radio" name="preview34">陰関数\( f(x,y) \)は点\( (a,b)=(-8,2) \)で，陰関数定理の条件を満たさない。</li></ol></div></div><div style="border: thin solid #000000; padding: 1em"><div title="フィードバック:
# 正答フィードバック:あなたの答えは正解です。
# 部分フィードバック:あたなの答えは部分的に正解です。
# 誤答フィードバック:あたなの答えは正しくありません。">ある陰関数\( f(x,y)=0 \)は，点\( (a,b)=(8,-9) \)において，それぞれ次のような条件を満たしています。極値に関して最も適切な選択肢を選んでください。<br />\( f

# %%
if __name__ == "__main__":
    pass
    #qz.save('extremum_condition_of_implicit_function.xml')

# %% [markdown]
# ## dummy

# %% [markdown]
# # All the questions

# %%
questions_str = ['limit_of_bivariate_polynomial', 'limit_of_bivariate_rational_function_approaches_domain', 
                 'limit_of_bivariate_rational_function_approaches_domain_with_common_factor', 
                 'limit_of_bivariate_rational_function_approaches_boundary', 'limit_with_sin_or_log_over_xpy',
                 'partial_derivative', 'partial_higher_derivative', 'extremum_condition', 'extremum_of_polynomial', 
                 'Lagrangian_multipliers', 'derivative_of_implicit_function', 'second_derivative_of_implicit_function', 
                 'extremum_condition_of_implicit_function']
questions = [eval(q) for q in questions_str]
def listview():
    fullhtml = '<ul>'
    for i in range(len(questions_str)):
        fullhtml += '<li>' + questions_str[i] + ':' + questions[i].name + '</li>'
    fullhtml += '</ul>'       
    IPython.display.display(IPython.display.HTML(fullhtml))
def generate():
    instances = []
    for q in questions:
        instances.append(q())
    return instances
